# %% [markdown]
# # I'll be breaking the code into blocks by assignment
# What I had to do for this first assignment was get the artists in a given week, find out the genre for each artist, and then apply those findings to the overall weekly listening to find the share of total listens that each genre had during a given week. The hard part was finding a variable to quantify in this API, however the genre share is a way to see the overall trend that occurs in a given genre and not just how much this individual listens to a given artist.

# %%
import requests
import pandas as pd
import numpy as np

url = "http://ws.audioscrobbler.com/2.0/" #Url base for the API, used in my future F strings as inputs, F strings are awesome
YOUR_API_KEY = '915b23d080ae463f6850ac8cec3aefb6' #my API key,
artist='Cher'
#_________________________________________________________________________________________________________________________________________
#BLOCK 1.1 - Prime Data, find how many weeks and how to grab tags
#This below block gives me both the tag grabber for each of the artists I'm looking at as well as the weeks I'm counting. This is important
#because I'm looking to do a for loop in a for loop, essentially the main loop is going to cycle weeks and grab the listening data for that 
#week, the second loop is going to cycle between either the top 250 artists or the length of the amount of artists, whichever is smaller
#in order to get the weeks I need 'charts', in order to get the top tag and classify each artist I need 'toptagget', cher is my placeholder
toptagsreq=requests.get(f'{url}?method=artist.gettoptags&artist={artist}&api_key={YOUR_API_KEY}&format=json')
# gets the top tag for an artist specified in the F STRING {ARTIST} blob, if i change the artist in the line at the beginning it will change from cher
toptagget=toptagsreq.json() 
#returns our JSON for the request of the artist tags, I removed the print from this final submission, but it is in assignment 1
chartrequest=requests.get(f'{url}?method=tag.getweeklychartlist&tag=rock&api_key={YOUR_API_KEY}&format=json') 
charts=chartrequest.json()
#toptagget gets changed in the loop that gets the tags, I'm just calling it here so I can reference it at a later point down the line.

#_________________________________________________________________________________________________________________________________________
#BLOCK 1.2 - Get Artists for Weeks
#This entire loop essentially looks at each week of listening data that we have, and within that week, pulls all the artists up to 250
# and puts them into a master list, for every week. This master list 100% has duplicates but I erase them at a later point (BLOCK 3)
#listylist prints my list, I know you said you didnt want prints so I just turned it into a comment and moved it up here

chartnum=0 
# Begins my counter for the loop to see what week we are in
listylist=[] 
#creates an empty list for the artists to go in later
for i in charts['weeklychartlist']['chart']: 
    #Begins putting us through the large loop of getting weekly data
    fromloop = charts['weeklychartlist']['chart'][chartnum]['from'] 
    #sets beginning of date search
    toloop = charts['weeklychartlist']['chart'][chartnum]['to'] 
    #sets end of date search
    weeklisteningdata = requests.get(f'{url}?method=user.getweeklyartistchart&user=rj&api_key={YOUR_API_KEY}&format=json&to={toloop}&from={fromloop}') 
    #gets my data for the URL that I'm looking at 
    rjdata=weeklisteningdata.json() 
    #this gets the json data that I can parse through and find the lists of artists for every week
    for j in range(0, min(250, len(rjdata['weeklyartistchart']['artist']))): 
        #sets my criteria that for a range between 0 and either 250 or the length of the data (whichever is lower), append the artist to the lsit
        listylist.append(rjdata['weeklyartistchart']['artist'][j]['name']) 
        #Puts all of the artists into the master list, titled 'listylist'
        print(rjdata['weeklyartistchart']['artist'][j]['name'],chartnum) #this line isn't necessary, just lets me see the artists I'm dealing with and how many
    chartnum+=1 #advances the chart number counter 1 item, moves onto the next week 
#Breaking here so if you run and something explodes you can stop the kernel at this block.
# Out:
# Aerosmith 0
# Metallica 0
# Miles Davis 0
# Guns N' Roses 0
# Dream Theater 0
# R.E.M. 0
# Radiohead 0
# Moby 0
# Joe Satriani 0
# Led Zeppelin 0
# Counting Crows 0
# Free 0
# Red Hot Chili Peppers 0
# Jimi Hendrix 0
# Badly Drawn Boy 0
# The Rolling Stones 0
# Portishead 0
# Matchbox Twenty 0
# Jamiroquai 0
# The Beatles 0
# Goo Goo Dolls 0
# Ben Folds Five 0
# Dido 0
# Eels 0
# Stevie Wonder 0
# The Jimi Hendrix Experience 0
# David Bowie 0
# Dire Straits 0
# Rage Against the Machine 0
# A Perfect Circle 0
# Dan Reed Network 0
# Beck 0
# Nine Inch Nails 0
# Ben Harper 0
# Fun Lovin' Criminals 0
# Barenaked Ladies 0
# Jeff Buckley 0
# Norah Jones 0
# Buckcherry 0
# Foo Fighters 0
# King's X 0
# The Doors 0
# The Police 0
# Queen 0
# (hed) Planet Earth 0
# The Cure 0
# U2 0
# Bruce Springsteen 0
# Nirvana 0
# The Smashing Pumpkins 0
# Pink Floyd 0
# Coldplay 0
# Herbie Hancock 0
# The Classic Chill Out Album 0
# Air 0
# Lenny Kravitz 0
# The Velvet Underground 0
# Beth Orton 0
# Judas Priest 0
# Tom Waits 0
# Deep Purple 0
# Desert Sessions 0
# Pearl Jam 0
# Weezer 0
# Rammstein 0
# Neil Young 0
# Def Leppard 0
# Fugees 0
# Nickelback 0
# Pink 0
# Massive Attack 0
# Various Artists 0
# The Kleptones 0
# Feeder 0
# Linkin Park 0
# Blur 0
# Muse 0
# Nick Cave and the Bad Seeds 0
# Frank Sinatra 0
# Van Morrison 0
# Sonic Youth 0
# James Taylor 0
# No Doubt 0
# Diana Krall 0
# Level 42 0
# Mr. Big 0
# Everclear 0
# Frankie Goes to Hollywood 0
# Bob Marley 0
# Santana 0
# The White Stripes 0
# Bob Dylan 0
# Jools Holland 0
# PJ Harvey 0
# Audioslave 0
# Creed 0
# Dave Weckl 0
# Nina Simone 0
# Stereolab 0
# 3 Doors Down 0
# Chet Baker 0
# Dizzy Gillespie 0
# George Michael 0
# Marcus Miller 0
# Pixies 0
# Bob Seger 0
# Disturbed 0
# Electric Wizard 0
# Elvis Presley 0
# Eric Clapton 0
# Weather Report 0
# Faith No More 0
# Fleetwood Mac 0
# Roachford 0
# System of a Down 0
# A 0
# Quincy Jones 0
# Ella Fitzgerald 0
# John Mayer 0
# Morcheeba 0
# James Brown 0
# Ash 0
# Nick Drake 0
# Zero 7 0
# Beastie Boys 0
# Black Sabbath 0
# Lou Reed 0
# Michael Jackson 0
# Oleander 0
# Talking Heads 0
# [unknown] 0
# John Coltrane 0
# Simon & Garfunkel 0
# Cutting Crew 0
# Depeche Mode 0
# Madonna 0
# Neal Morse 0
# Pantera 0
# Alanis Morissette 0
# Pavement 0
# Soundgarden 0
# The Wallflowers 0
# De La Soul 0
# The Divine Comedy 0
# Boards of Canada 0
# David Lee Roth 0
# John Patitucci 0
# Meat Loaf 0
# Cream 0
# Tindersticks 0
# Collective Soul 0
# One Minute Silence 0
# Crash Test Dummies 0
# Elvis Costello 0
# Incubus 0
# Kraftwerk 0
# Liquid Tension Experiment 0
# Placebo 0
# Yngwie Malmsteen 0
# B.B. King & Eric Clapton 0
# Bryan Adams 0
# Eagles 0
# Firebird 0
# Lynyrd Skynyrd 0
# The Beta Band 0
# The Who 0
# Alice Cooper 0
# Autechre 0
# Bon Jovi 0
# Brian Eno 0
# Phil Collins Big Band 0
# The Verve 0
# Tower of Power 0
# Yo La Tengo 0
# Curtis Mayfield 0
# Peter Gabriel 0
# Steve Vai 0
# Chick Corea 0
# EVE 6 0
# Garbage 0
# Natalie Merchant 0
# AC/DC 0
# Aretha Franklin 0
# Billie Holiday 0
# Django Reinhardt 0
# my bloody valentine 0
# Oasis 0
# Sting 0
# Best Jazz Ever 0
# Bruce Dickinson 0
# Enuff Z'Nuff 0
# Iggy Pop 0
# Madness 0
# The Byrds 0
# The Clash 0
# Derek & Clive 0
# Spiritualized 0
# Whitesnake 0
# Eva Cassidy 0
# Johann Sebastian Bach 0
# Steppenwolf 0
# Supreme Beings of Leisure 0
# Suzie Higgie 0
# The Stone Roses 0
# Thievery Corporation 0
# Tracy Chapman 0
# Anastacia 0
# Aphex Twin 0
# Leonard Cohen 0
# The Jon Spencer Blues Explosion 0
# The Stranglers 0
# Brant Bjork 0
# Prince 0
# Sublime 0
# Tok Tok Tok 0
# Dr. John 0
# Gorillaz 0
# Hootie & The Blowfish 0
# Joni Mitchell & James Taylor 0
# Jurassic 5 0
# Staind 0
# Tenacious D 0
# The Battle of Los Angeles 0
# The Fall 0
# The James Taylor Quartet 0
# Travis 0
# Ani DiFranco 0
# Björk 0
# DumDums 0
# Kid Rock 0
# Marilyn Manson 0
# Suzanne Vega 0
# The Cranberries 0
# Belle and Sebastian 0
# Elliott Smith 0
# Eminem 0
# Fiona Apple 0
# Moloko 0
# Natalie Imbruglia 0
# Sigur Rós 0
# Steve Miller Band 0
# The Future Sound of London 0
# Buena Vista Social Club 0
# David Hudson and Friends 0
# DJ Krush 0
# Doves 0
# Eurythmics 0
# Live 0
# Serge Gainsbourg 0
# The Hollies 0
# Mr. Big 1
# Liquid Tension Experiment 1
# Joe Satriani 1
# Kings of Leon 1
# Audioslave 1
# Level 42 1
# Muse 1
# Nirvana 1
# Red Hot Chili Peppers 1
# Steppenwolf 1
# 3 Doors Down 1
# Blind Guardian 1
# Charles Mingus 1
# Coldplay 1
# Deep Purple 1
# Derek & Clive 1
# Diana Krall 1
# Dire Straits 1
# Dizzy Gillespie 1
# Eva Cassidy 1
# Fear Factory 1
# Fleetwood Mac 1
# Foo Fighters 1
# Iron Maiden 1
# Jaco Pastorius 1
# Jimi Hendrix 1
# Joy Division 1
# Led Zeppelin 1
# Megadeth 1
# Pain of Salvation 1
# Queensrÿche 1
# Radiohead 1
# Shaman 1
# Silverchair 1
# Slayer 1
# Smith 1
# The Byrds 1
# The Electric Prunes 1
# The Jimi Hendrix Experience 1
# The Quantic Soul Orchestra 1
# U2 1
# Van Morrison 1
# Miles Davis 2
# Desert Sessions 2
# King's X 2
# Buckcherry 2
# Def Leppard 2
# Dream Theater 2
# Joe Satriani 2
# Mr. Big 2
# B.B. King & Eric Clapton 2
# Crusaders 2
# Grassroots 2
# The Delfonics 2
# Tok Tok Tok 4
# Grandmaster Flash and The Furious Five 4
# Run-D.M.C. 4
# Guns N' Roses 5
# Mr. Big 5
# Starsailor 5
# Tok Tok Tok 5
# David Bowie 5
# Keane 5
# Steve Vai 5
# Lenny Kravitz 6
# Red Hot Chili Peppers 7
# Aerosmith 7
# Led Zeppelin 7
# Alice Cooper 7
# Backyard Babies 7
# Bruce Dickinson 7
# David Gray 7
# dEUS 7
# Echo & the Bunnymen 7
# Eels 7
# Eminem 7
# Enigma 7
# HammerFall 7
# Kula Shaker 7
# Megadeth 7
# Oasis 7
# Primal Scream 7
# Queen 7
# The Beatles 7
# The Cure 7
# Buckcherry 8
# Aerosmith 8
# Miles Davis 8
# Kyuss 8
# Dream Theater 8
# Coldplay 8
# Tito & Tarantula 8
# Alice Cooper 8
# James Taylor 8
# Jimi Hendrix 8
# Dave Matthews Band 8
# Eurythmics 8
# Pink Floyd 8
# Queen 8
# R.E.M. 8
# Sting 8
# Uncle Seth 8
# Alice in Chains 8
# Beth Orton 8
# Cream 8
# Creedence Clearwater Revival 8
# Daft Punk 8
# David Bowie 8
# Disturbed 8
# Fleetwood Mac 8
# Metallica 8
# Moby 8
# ABBA 8
# AFI 8
# Air 8
# Audioslave 8
# Big Brother & The Holding Company 8
# Black Rebel Motorcycle Club 8
# Bruce Dickinson 8
# Bruce Springsteen 8
# Bryan Adams 8
# Cake 8
# Christina Aguilera 8
# Crazy Town 8
# Deep Purple 8
# Eagles 8
# Echo & the Bunnymen 8
# Electric Six 8
# Elvis Costello 8
# EVE 6 8
# Faith No More 8
# Foo Fighters 8
# Fun Lovin' Criminals 8
# Halo 8
# Hawkwind 8
# Iggy Pop 8
# Iron Maiden 8
# Ivy 8
# John Vanderslice 8
# Kula Shaker 8
# Led Zeppelin 8
# Levellers 8
# Limp Bizkit 8
# Lynyrd Skynyrd 8
# Madonna 8
# Marillion 8
# Marilyn Manson 8
# Megadeth 8
# My Chemical Romance 8
# New Order 8
# Oasis 8
# One Minute Silence 8
# Pantera 8
# Queens of the Stone Age 8
# Red Hot Chili Peppers 8
# Roxy Music 8
# Santana 8
# Sash! 8
# Skindred 8
# Skunk Anansie 8
# Slayer 8
# Soulfly 8
# Soundgarden 8
# Tabu Ley 8
# The Beatles 8
# The Cars 8
# The Police 8
# The Small Faces 8
# The Vines 8
# The Zutons 8
# Yellowcard 8
# Yes 8
# The Kleptones 9
# Tok Tok Tok 9
# Grandaddy 9
# Sunny Day Real Estate 9
# Beck 9
# Billy Joel 9
# Cat Power 9
# Eagles 9
# Faust 9
# Gallon Drunk 9
# Gomez 9
# Piano Magic 9
# PJ Harvey 9
# Red Hot Chili Peppers 9
# U2 9
# 36 Crazyfists 9
# Aerosmith 9
# Alice in Chains 9
# Ben Christophers 9
# Biz Markie 9
# Black Sabbath 9
# Bob Marley & The Wailers 9
# Bobby Vinton 9
# Bochum Welt 9
# Cake 9
# Charles Trénet 9
# Coldplay 9
# David Broza 9
# David Gray 9
# Deftones 9
# Dido 9
# Dirty Three 9
# Dream Theater 9
# Enya 9
# Evanescence 9
# Everything But the Girl 9
# Failure 9
# Fatboy Slim 9
# Fear Factory 9
# Flim 9
# Frankie Valli And The Four Seasons 9
# Guided by Voices 9
# Hatebreed 9
# HIM 9
# Howlin` Maggie 9
# Iced Earth 9
# Indigo Girls 9
# Jamiroquai 9
# JC Chasez 9
# Jimmy Buffett 9
# Judas Priest 9
# Kate Bush 9
# Kylie Minogue 9
# Lene Marlin 9
# Lilys 9
# Linkin Park 9
# Madonna 9
# Mercury Rev 9
# Michelle Branch 9
# Muse 9
# Neil Young 9
# Nickelback 9
# Nina Simone 9
# No Doubt 9
# Norah Jones 9
# Oasis 9
# Parliament 9
# Pavement 9
# Peace Orchestra 9
# Penguin Cafe Orchestra 9
# Pinback 9
# Queens of the Stone Age 9
# R.E.M. 9
# Rammstein 9
# Rush 9
# Sex Pistols 9
# Shawn Colvin 9
# Shawn Mullins 9
# Something Corporate 9
# Steely Dan 9
# Stevie Wonder 9
# Styrofoam 9
# Swollen Members 9
# System of a Down 9
# Teknotika 9
# The Ataris 9
# The Darkness 9
# The Kinks 9
# The Magnetic Fields 9
# The Microphones 9
# The Offspring 9
# The Shins 9
# The Vines 9
# Theatre of Tragedy 9
# Therion 9
# Tori Amos 9
# Trail of Tears 9
# Unwritten Law 9
# Various Artists 9
# Weezer 9
# Whiskeytown 9
# Wilco 9
# Yellowjackets 9
# Nine Inch Nails 11
# Nirvana 11
# R.E.M. 11
# The Doors 11
# The Kleptones 11
# test artist 1 11
# The Smashing Pumpkins 11
# Albert Collins 11
# Avantasia 11
# Ayreon 11
# Beastie Boys 11
# Betty Wright 11
# blink-182 11
# Cream 11
# Devin Townsend 11
# Dream Theater 11
# Elmore James 11
# Eric Clapton 11
# Evergrey 11
# Guy Barker 11
# Guy Davis 11
# Jefferson Airplane 11
# Joe Lynn Turner 11
# Joe Satriani 11
# John Abercrombie 11
# John Mayall 11
# Johnny Winter 11
# Junior Wells 11
# Kamelot 11
# Leo Kottke 11
# Louisiana Red 11
# Marillion 11
# Moskovskaya 11
# Nightwish 11
# Omara Portuondo 11
# Pain of Salvation 11
# Robert Johnson 11
# Rush 11
# Savatage 11
# Savoy Brown 11
# Sonata Arctica 11
# Sue Foley 11
# Ten Years After 11
# The Last Poets 11
# Therion 11
# Yngwie Malmsteen 11
# Bloc Party 12
# Iron Maiden 12
# Bob Seger 12
# Boston 12
# Cat Power 12
# Counting Crows 12
# Crosby, Stills, Nash & Young 12
# Def Leppard 12
# Emerson, Lake & Palmer 12
# Firehouse 12
# Giant Sand 12
# John Mellencamp 12
# Journey 12
# Kansas 12
# Lynyrd Skynyrd 12
# Megadeth 12
# Metallica 12
# Palace 12
# Portishead 12
# Red Hot Chili Peppers 12
# Scorpions 12
# Spoon 12
# Stevie Ray Vaughan 12
# The Angels of Light 12
# The Doobie Brothers 12
# Will Oldham 12
# Weezer 13
# Rachael Yamagata 13
# James Brown 13
# Otis Redding 13
# Aerosmith 13
# Guns N' Roses 13
# Van Halen 13
# Creed 13
# Kingdom Come 13
# Lynyrd Skynyrd 13
# Metallica 13
# Nirvana 13
# Red Hot Chili Peppers 13
# Paul McCartney & Wings 13
# A Perfect Circle 13
# Dire Straits 13
# Everclear 13
# Incubus 13
# Less Than Jake 13
# Nigel Kennedy 13
# Reel Big Fish 13
# Semisonic 13
# Snow Patrol 13
# The Beatles 13
# The Presidents of the United States of America 13
# The Rolling Stones 13
# Thunder 13
# WANDS 13
# Metallica 14
# Radiohead 14
# Van Halen 14
# Linkin Park 14
# Weezer 14
# Abdullah Ibrahim 14
# AC/DC 14
# Alice Coltrane 14
# Alice Cooper 14
# Anouk 14
# Art Pepper 14
# Billie Holiday 14
# Bloc Party 14
# Blur 14
# Bruce Springsteen 14
# Carla Bley 14
# Charles Mingus 14
# Charlie Parker 14
# Deep Purple 14
# Descendents 14
# Disturbed 14
# Elliott Smith 14
# Enuff Z'Nuff 14
# Eric Dolphy 14
# Erik Truffaz 14
# Evanescence 14
# Franz Ferdinand 14
# Freddie Hubbard 14
# Fun Lovin' Criminals 14
# Goo Goo Dolls 14
# Grandaddy 14
# Green Day 14
# Jack Johnson 14
# Jimmy Eat World 14
# John Mellencamp 14
# Madeleine Peyroux 14
# Madlib 14
# Madness 14
# Muse 14
# Norah Jones 14
# Oasis 14
# Ooberman 14
# Paul Motian 14
# Pearl Jam 14
# Peter Gabriel 14
# Pink 14
# Pink Floyd 14
# Queens of the Stone Age 14
# Red Hot Chili Peppers 14
# Richie Sambora 14
# Robbie Williams 14
# Slayer 14
# Supertramp 14
# System of a Down 14
# Tenacious D 14
# The Allman Brothers Band 14
# The Cure 14
# The Darkness 14
# The Killers 14
# The Pogues 14
# The Strokes 14
# The Tragically Hip 14
# The White Stripes 14
# Tony Williams 14
# Tori Amos 14
# U2 14
# Ben Kweller 15
# Gorillaz 15
# Tok Tok Tok 15
# Audioslave 15
# Barenaked Ladies 15
# Ben Folds Five 15
# blink-182 15
# Bush 15
# Creed 15
# Creedence Clearwater Revival 15
# Disturbed 15
# Everclear 15
# Faith No More 15
# Goo Goo Dolls 15
# Green Day 15
# Lynyrd Skynyrd 15
# Matchbox Twenty 15
# Metallica 15
# Nine Inch Nails 15
# Pixies 15
# Portishead 15
# Queens of the Stone Age 15
# Rachael Yamagata 15
# Radiohead 15
# Red Hot Chili Peppers 15
# Stone Temple Pilots 15
# Sublime 15
# The Beatles 15
# The Flaming Lips 15
# The Offspring 15
# The Smashing Pumpkins 15
# Tool 15
# Weezer 15
# Zwan 15
# The Flaming Lips 16
# AC/DC 16
# Air 16
# Counting Crows 16
# The Wallflowers 16
# Aerosmith 17
# blink-182 17
# Bruce Springsteen 17
# Calexico 17
# Dido 17
# Dream Theater 17
# Eagles 17
# Faith No More 17
# Jimi Hendrix 17
# Kings of Leon 17
# Led Zeppelin 17
# Lou Reed 17
# Metallica 17
# Ministry 17
# Muse 17
# Peaches 17
# Pearl Jam 17
# Pink Floyd 17
# Queen 17
# Radiohead 17
# Rage Against the Machine 17
# Red Hot Chili Peppers 17
# Robert Miles 17
# Stereolab 17
# The Beatles 17
# The Cranberries 17
# The Wildhearts 17
# Zero 7 17
# Buckcherry 19
# Tom Lehrer 19
# Red Hot Chili Peppers 20
# Ben Folds Five 20
# Counting Crows 20
# Led Zeppelin 20
# Metallica 20
# Jimi Hendrix 20
# Eric Clapton 20
# Foo Fighters 20
# R.E.M. 20
# Stevie Ray Vaughan 20
# The Rolling Stones 20
# Guns N' Roses 20
# Jamiroquai 20
# Monty Python 20
# Santana 20
# The Jimi Hendrix Experience 20
# Alien Sex Fiend 20
# American Head Charge 20
# B.B. King & Eric Clapton 20
# Badly Drawn Boy 20
# Ben Harper 20
# Brant Bjork 20
# Buckcherry 20
# Cream 20
# Derek and the Dominos 20
# Dream Theater 20
# Faust 20
# Fun Lovin' Criminals 20
# Johnny Carroll 20
# Pat Metheny 20
# Rage Against the Machine 20
# Sleeper 20
# Stiphane Pompouganc 20
# Suede 20
# The Smashing Pumpkins 20
# Weather Report 20
# Weezer 20
# Led Zeppelin 21
# Miles Davis 21
# Jimi Hendrix 21
# Rage Against the Machine 21
# R.E.M. 21
# B.B. King & Eric Clapton 21
# Eric Clapton 21
# Pink Floyd 21
# Santana 21
# Stevie Ray Vaughan 21
# The Rolling Stones 21
# Marty Robbins 22
# Dr. John 22
# Jason Rebello 22
# No-Neck Blues Band 22
# Ry Cooder 22
# Ry Cooder & Manuel Galbán 22
# Ace of Base 22
# Barbra Streisand 22
# Black Eyed Peas 22
# Charlie Musselwhite 22
# Dave Grusin 22
# Garth Brooks 22
# Gillian Welch 22
# John Lee Hooker 22
# John Mayall & The Bluesbreakers 22
# Louis Jordan 22
# Loyko 22
# Maroon 5 22
# Michael Jackson 22
# Muddy Waters 22
# Nina Simone 22
# Ralph Towner 22
# Red Hot Chili Peppers 22
# Rickie Lee Jones 22
# Sarah Brightman 22
# T-Bone Walker 22
# Taj Mahal 22
# Texas 22
# The Calling 22
# TIm Kearns 22
# Tom Waits 22
# Tracy Chapman 22
# Travis 22
# Wu-Tang Clan 22
# Marty Robbins 23
# Rage Against the Machine 23
# Green Day 23
# Jimi Hendrix 23
# Ozzy Osbourne 23
# Pearl Jam 23
# Radiohead 23
# The Beatles 23
# AC/DC 23
# Eric Clapton 23
# Iggy Pop 23
# Iron Maiden 23
# Joe Cocker 23
# Lauryn Hill 23
# Led Zeppelin 23
# Linkin Park 23
# Meat Loaf 23
# Mogwai 23
# Nirvana 23
# Pantera 23
# Phil Collins 23
# Portishead 23
# Red Hot Chili Peppers 23
# The Rolling Stones 23
# The Smashing Pumpkins 23
# Weather Report 23
# Dr. John 24
# Jason Rebello 24
# Loyko 24
# Ry Cooder 24
# Andre Gurov 24
# Charles Mingus 24
# Dave Grusin 24
# Dexter Gordon 24
# Duke Ellington 24
# John Coltrane 24
# John Lee Hooker 24
# John Mayall & The Bluesbreakers 24
# Miles Davis 24
# Muddy Waters 24
# Nina Simone 24
# Sonny Rollins 24
# Taj Mahal 24
# Tom Waits 24
# Wayne Shorter 24
# Alice Cooper 24
# Audioslave 24
# Betty Wright 24
# Black Eyed Peas 24
# Bob Dylan 24
# Bruce Dickinson 24
# Bruce Springsteen 24
# Charlie Musselwhite 24
# Charlie Parker 24
# Combustible Edison 24
# Cream 24
# Crosby, Stills, Nash & Young 24
# David Bowie 24
# Dream Theater 24
# Dusty Springfield 24
# Eels 24
# Eric Clapton 24
# Foo Fighters 24
# Glen Campbell 24
# Incubus 24
# Jon Brion 24
# Keith Jarrett 24
# KMFDM 24
# Lalo Schifrin 24
# Lenny Kravitz 24
# Louis Jordan 24
# Lynyrd Skynyrd 24
# Marty Robbins 24
# Medeski, Martin and Wood 24
# No-Neck Blues Band 24
# Oscar Peterson 24
# Ralph Towner 24
# Red Hot Chili Peppers 24
# Rickie Lee Jones 24
# Ry Cooder & Manuel Galbán 24
# Sly & The Family Stone 24
# Stevie Wonder 24
# T-Bone Walker 24
# The Beach Boys 24
# The Beatles 24
# The Doors 24
# The Rolling Stones 24
# The Waterboys 24
# Dream Theater 25
# Dr. John 25
# Marty Robbins 25
# Alicia de Larrocha 25
# Avril Lavigne 25
# Beth Orton 25
# Bob Dylan 25
# Bob Marley & The Wailers 25
# Creedence Clearwater Revival 25
# Deep Purple 25
# dEUS 25
# Dexter Gordon 25
# Dido 25
# Duke Ellington 25
# Eric Dolphy 25
# Evanescence 25
# Fatso Jetson 25
# Five for Fighting 25
# Franz Ferdinand 25
# Freddie Hubbard 25
# Frou Frou 25
# Fuel 25
# Gary Moore 25
# Green Day 25
# Hamilton, Tom / Thomas Buckner 25
# Hutch Demouilpied 25
# Iron Maiden 25
# Jamiroquai 25
# Jason Moran 25
# Kiss 25
# Linkin Park 25
# Lynyrd Skynyrd 25
# Maceo Parker 25
# Mark Lanegan 25
# Maroon 5 25
# Miles Davis 25
# Mississippi Jook Band 25
# Muse 25
# Nancy Sinatra & Lee Hazlewood 25
# Nina Simone 25
# Nine Inch Nails 25
# Oasis 25
# Red Hot Chili Peppers 25
# Scorpions 25
# Steely Dan 25
# System of a Down 25
# Travis 25
# Jimi Hendrix 26
# Tok Tok Tok 26
# Aina 26
# Eric Clapton 26
# Led Zeppelin 26
# Stevie Ray Vaughan 26
# Dream Theater 26
# Santana 26
# B.B. King & Eric Clapton 26
# Blur 26
# Bush 26
# Cab Calloway 26
# Diana Krall 26
# Hoobastank 26
# Miles Davis 26
# Prefuse 73 26
# AC/DC 26
# Adam Green 26
# Aesop Rock 26
# Allison Crowe 26
# Ani DiFranco 26
# Anouar Brahem 26
# Beth Orton 26
# Bill Evans 26
# Billie Holiday 26
# Black Moon 26
# Blind Melon 26
# Bloodhound Gang 26
# Bob Dylan 26
# Broken Social Scene 26
# Buddy Holly 26
# Built to Spill 26
# Collective Soul 26
# Coolio 26
# Cream 26
# Cyne 26
# Derek and the Dominos 26
# Dispatch 26
# Django Reinhardt 26
# Duran Duran 26
# Ella Fitzgerald 26
# Elliott Smith 26
# Erykah Badu 26
# Esbjörn Svensson Trio 26
# Fleetwood Mac 26
# Four Tet 26
# Frank Zappa 26
# Fu Manchu 26
# Fun Lovin' Criminals 26
# Gang Starr 26
# Gillian Welch 26
# Guns N' Roses 26
# Hella 26
# Henry Mancini 26
# Janet Jackson 26
# Joanna Newsom 26
# John Pizzarelli 26
# Johnny Cash 26
# Les Savy Fav 26
# Lucinda Williams 26
# M. Ward 26
# Mariah Carey 26
# Marty Robbins 26
# Melvins 26
# Metallica 26
# Modern Jazz Quartet 26
# Neil Finn 26
# Neil Young 26
# Norah Jones 26
# Pantera 26
# Pete Yorn 26
# Pixies 26
# Plug 26
# Primal Scream 26
# Rage Against the Machine 26
# Red Hot Chili Peppers 26
# Richard Galliano 26
# Sarah Brightman 26
# Serge Gainsbourg 26
# Shellac 26
# Slipknot 26
# Soil 26
# Soundgarden 26
# Stan Getz & Charlie Byrd 26
# Stephen Malkmus 26
# Stereolab 26
# Sublime 26
# The Blood Brothers 26
# The Cure 26
# The Go-Go's 26
# The Jimi Hendrix Experience 26
# The Prodigy 26
# The Rolling Stones 26
# The Smashing Pumpkins 26
# Thee Michelle Gun Elephant 26
# U2 26
# Uncle Tupelo 26
# Ween 26
# Wu-Tang Clan 26
# Zoot Woman 26
# Aina 27
# Aerosmith 27
# Alice in Chains 27
# Led Zeppelin 27
# Metallica 27
# R.E.M. 27
# U2 27
# ZZ Top 27
# 3 Doors Down 27
# Audioslave 27
# Bruce Springsteen 27
# Coldplay 27
# Dave Matthews Band 27
# David Bowie 27
# Def Leppard 27
# Dido 27
# Dire Straits 27
# Evanescence 27
# Foo Fighters 27
# Guns N' Roses 27
# Maroon 5 27
# Megadeth 27
# Michael Jackson 27
# No Doubt 27
# Pearl Jam 27
# Pink Floyd 27
# Pixies 27
# Placebo 27
# Portishead 27
# Prince 27
# Queen 27
# Radiohead 27
# Rush 27
# System of a Down 27
# The Beatles 27
# The Clash 27
# The Smashing Pumpkins 27
# A Perfect Circle 27
# AC/DC 27
# Air 27
# Alice Cooper 27
# Amon Tobin 27
# Amorphis 27
# Ash 27
# Atmosphere 27
# Babyshambles 27
# Bad Religion 27
# Barenaked Ladies 27
# Beck 27
# Belinda Carlisle 27
# Ben Folds Five 27
# Ben Lee 27
# Beth Orton 27
# Big Punisher 27
# Billie Holiday 27
# Black Sabbath 27
# blink-182 27
# Blondie 27
# Boston 27
# Brand New 27
# Brian May 27
# Bryan Adams 27
# Calexico 27
# Charlie Feathers 27
# Children of Bodom 27
# Cocteau Twins 27
# Crowded House 27
# Cypress Hill 27
# Daft Punk 27
# David Byrne 27
# Dead Kennedys 27
# Deep Purple 27
# Deftones 27
# Die Fantastischen Vier 27
# Disturbed 27
# Doves 27
# Dream Theater 27
# Duran Duran 27
# Electric Light Orchestra 27
# Elvis Costello 27
# Elvis Presley 27
# Embrace 27
# Eric Clapton 27
# Finch 27
# Five for Fighting 27
# Franz Ferdinand 27
# Front 242 27
# Funeral For A Friend 27
# Garbage 27
# Gary Jules 27
# Goo Goo Dolls 27
# Green Day 27
# HIM 27
# Hutch Demouilpied 27
# Ill Niño 27
# In Flames 27
# Iron Maiden 27
# Jack Johnson 27
# Jamiroquai 27
# Janis Ian 27
# Jimmy Eat World 27
# John Pizzarelli 27
# Josie and the Pussycats 27
# Judas Priest 27
# K's Choice 27
# Keane 27
# King Tubby's Meets Scientist 27
# Kiss 27
# Kyuss 27
# Leonard Cohen 27
# Levellers 27
# Limp Bizkit 27
# Linkin Park 27
# Lostprophets 27
# Lynyrd Skynyrd 27
# Madonna 27
# Marcy Playground 27
# Marvin Gaye 27
# Massive Attack 27
# Miles Davis 27
# Moloko 27
# Mr. Bungle 27
# Muse 27
# My Chemical Romance 27
# My Vitriol 27
# N*E*R*D 27
# Natalie Imbruglia 27
# Nickelback 27
# Norah Jones 27
# Oasis 27
# Our Lady Peace 27
# P.O.D. 27
# Pantera 27
# Patti LaBelle 27
# Peter Gabriel 27
# Primal Scream 27
# Prince & The Revolution 27
# Queens of the Stone Age 27
# Rainbow 27
# Ray Charles 27
# Red Hot Chili Peppers 27
# Robert Johnson 27
# Rooney 27
# Sade 27
# Sarah McLachlan 27
# Seven Channels 27
# Shirley Bassey 27
# Simon & Garfunkel 27
# Skunk Anansie 27
# Soilwork 27
# Something Corporate 27
# Sonata Arctica 27
# Soundgarden 27
# Squeeze 27
# Squirrel Nut Zippers 27
# Staind 27
# Stealers Wheel 27
# Steely Dan 27
# Stone Temple Pilots 27
# Supergrass 27
# Talking Heads 27
# The All-American Rejects 27
# The Beach Boys 27
# The Byrds 27
# The Cardigans 27
# The Chemical Brothers 27
# The Cinematic Orchestra 27
# The Crystal Method 27
# The Futureheads 27
# The Jam 27
# The Killers 27
# The La's 27
# The Proclaimers 27
# The Rolling Stones 27
# The Streets 27
# The Strokes 27
# The Verve 27
# The Who 27
# Tool 27
# Tortoise 27
# Transvision Vamp 27
# Tristania 27
# Van Halen 27
# Velvet Revolver 27
# Weezer 27
# Alanis Morissette 28
# Jason Mraz 28
# Apocalyptica 28
# Arch Enemy 28
# Creedence Clearwater Revival 28
# David Gray 28
# Deep Purple 28
# Dizzy Gillespie 28
# DragonForce 28
# Dubadelic 28
# Eagles 28
# Eels 28
# Eric Clapton 28
# Goo Goo Dolls 28
# Green Day 28
# Hoof 28
# Jeff Buckley 28
# Nightwish 28
# Nirvana 28
# Norah Jones 28
# Queen 28
# Radiohead 28
# Scorpions 28
# Semisonic 28
# Sheryl Crow 28
# Stevie Wonder 28
# Stone Sour 28
# The Smashing Pumpkins 28
# The Smiths 28
# The White Stripes 28
# Thin Lizzy 28
# Tool 28
# Tori Amos 28
# U2 28
# 3 Doors Down 28
# 4 Non Blondes 28
# Abdullah Ibrahim 28
# AC/DC 28
# Aerosmith 28
# Alabama 3 28
# Alice Cooper 28
# Alien Ant Farm 28
# Allison Crowe 28
# Alter Bridge 28
# Anastacia 28
# Anouk 28
# Atmosphere 28
# Bad Company 28
# Barenaked Ladies 28
# Beastie Boys 28
# Ben Kweller 28
# Beth Orton 28
# Billy Joel 28
# Black Sabbath 28
# blink-182 28
# Blur 28
# Bob Dylan 28
# Bob Marley & The Wailers 28
# Bonnie Tyler 28
# Bruce Springsteen 28
# Bryan Adams 28
# Buddy Holly 28
# Cake 28
# Chet Baker 28
# Children of Bodom 28
# Clannad 28
# Coal Chamber 28
# Coldplay 28
# Collective Soul 28
# Counting Crows 28
# Cream 28
# Crosby, Stills & Nash 28
# Dave Matthews & Tim Reynolds 28
# Dave Matthews Band 28
# David Axelrod 28
# David Bowie 28
# David Lee Roth 28
# Days of the New 28
# De-Phazz 28
# Deborah Harry 28
# Def Leppard 28
# Default 28
# Deftones 28
# dEUS 28
# Diana Krall 28
# Dido 28
# Dire Straits 28
# Dispatch 28
# Disturbed 28
# Do Make Say Think 28
# Duran Duran 28
# Eddie Cochran 28
# Electric Light Orchestra 28
# Electronic 28
# Ella Fitzgerald 28
# Eminem 28
# Eva Cassidy 28
# Faith No More 28
# Five for Fighting 28
# Fleetwood Mac 28
# Foo Fighters 28
# Foreigner 28
# Frank Sinatra & Tommy Dorsey 28
# Franz Ferdinand 28
# Fu Manchu 28
# Fuel 28
# Gary Moore 28
# Goldfinger 28
# Gomez 28
# Guns N' Roses 28
# Herbie Hancock 28
# Hoobastank 28
# Hugh Masekela 28
# Iced Earth 28
# Immortal 28
# In Flames 28
# Iron Maiden 28
# Jamie Cullum 28
# Jane's Addiction 28
# Janet Jackson 28
# Jethro Tull 28
# Jewel 28
# Jimmy Eat World 28
# Joe Satriani 28
# Joe Zawinul 28
# Kansas 28
# Led Zeppelin 28
# Lee Morgan 28
# Leftfield 28
# Len 28
# Les Nubians 28
# Levellers 28
# Limp Bizkit 28
# Live 28
# Living Colour 28
# Liz Phair 28
# Love Sculpture 28
# Lynyrd Skynyrd 28
# Madness 28
# Madvillain 28
# Manowar 28
# Marillion 28
# Marilyn Manson 28
# Maroon 5 28
# Marty Robbins 28
# Matchbox Twenty 28
# Megadeth 28
# Metallica 28
# Mezzoforte 28
# Michael Jackson 28
# Miles Davis 28
# Mono 28
# Mountain 28
# Muddy Waters 28
# Naglfar 28
# Neil Young 28
# Nickelback 28
# No Doubt 28
# Oasis 28
# Pearl Jam 28
# Pedestrian 28
# Pelding 28
# Peter Gabriel 28
# Phil Collins 28
# Pink Floyd 28
# Pixies 28
# Primus 28
# Prince 28
# Prince & The Revolution 28
# Queens of the Stone Age 28
# R.E.M. 28
# Rancid 28
# Ratt 28
# Red Hot Chili Peppers 28
# Reel Big Fish 28
# Rob Zombie 28
# Robbie Williams 28
# Robert Plant 28
# Roxy Music 28
# Rufus Wainwright 28
# Santa Esmeralda 28
# Santana 28
# Sarah McLachlan 28
# Sex Pistols 28
# Skunk Anansie 28
# Slayer 28
# Sloan 28
# Soundgarden 28
# Steely Dan 28
# Steve Earle 28
# Stina Nordenstam 28
# Stray Cats 28
# Styx 28
# Sum 41 28
# Supertramp 28
# System of a Down 28
# T. Rex 28
# Tenacious D 28
# The Beach Boys 28
# The Beatles 28
# The Byrds 28
# The Cars 28
# The Cranberries 28
# The Cure 28
# The Darkness 28
# The Donnas 28
# The Doors 28
# The Hives 28
# The Jam 28
# The Kinks 28
# The Pogues 28
# The Police 28
# The Rolling Stones 28
# The Surfaris 28
# The Undertones 28
# The Ventures 28
# The Verve 28
# The Yardbirds 28
# Toots and The Maytals 28
# Tower of Power 28
# Van Halen 28
# Vanessa Carlton 28
# Weezer 28
# ZZ Top 28
# Thievery Corporation 30
# Incubus 30
# Weezer 30
# Abdullah Ibrahim 30
# Air 30
# Al Jarreau 30
# Alanis Morissette 30
# At the Drive-In 30
# Avril Lavigne 30
# Beatsteaks 30
# Belle and Sebastian 30
# Biffy Clyro 30
# Black Candy 30
# Black Sabbath 30
# Blur 30
# Bruce Springsteen 30
# Bryan Adams 30
# Butthole Surfers 30
# Calexico 30
# Collective Soul 30
# Counting Crows 30
# Cream 30
# Creedence Clearwater Revival 30
# Cris Clarity 30
# David Bowie 30
# Deep Purple 30
# Devin Townsend 30
# Diana Krall 30
# Dizzy Gillespie 30
# Dr. John 30
# Dream Theater 30
# Duran Duran 30
# Eels 30
# Eminem 30
# Eurythmics 30
# EVE 6 30
# Fear Factory 30
# Fleetwood Mac 30
# Foo Fighters 30
# Frank Sinatra 30
# Franz Ferdinand 30
# Gary Moore 30
# George Michael 30
# Goo Goo Dolls 30
# Grandaddy 30
# Groundhogs 30
# Guns N' Roses 30
# Hans Zimmer 30
# Helloween 30
# Indigo Girls 30
# Iron Maiden 30
# Jellyfish 30
# Jim Brown 30
# John Mayer 30
# Judas Priest 30
# Kiss 30
# Kula Shaker 30
# Lacuna Coil 30
# Led Zeppelin 30
# Lord Rockingham's XI 30
# Loverboy 30
# Lynyrd Skynyrd 30
# Madness 30
# Marvin Gaye 30
# Massive Attack 30
# Meat Loaf 30
# Metallica 30
# Mick Harvey 30
# Mike & The Mechanics 30
# Miles Davis 30
# Moby 30
# Mötley Crüe 30
# Muse 30
# Natalie Imbruglia 30
# Nine Inch Nails 30
# No Doubt 30
# Norah Jones 30
# Oasis 30
# Our Lady Peace 30
# OutKast 30
# Paul Hardcastle 30
# Paul Weller 30
# Pearl Jam 30
# Penguin Cafe Orchestra 30
# Pink 30
# Placebo 30
# Prince 30
# Queen 30
# R.E.M. 30
# Rage Against the Machine 30
# Red Hot Chili Peppers 30
# Ry Cooder 30
# Sean Paul 30
# Sex Pistols 30
# Skunk Anansie 30
# Sonata Arctica 30
# Soundgarden 30
# Steve Oliver 30
# Steve Vai 30
# Stevie Wonder 30
# Sunny Day Real Estate 30
# System of a Down 30
# The Byrds 30
# The Cinematic Orchestra 30
# The Cranberries 30
# The Cure 30
# The Doors 30
# The J. Geils Band 30
# The Kingsmen 30
# The Mighty Mighty Bosstones 30
# The Rolling Stones 30
# The Ronettes 30
# The Smashing Pumpkins 30
# Thin Lizzy 30
# Third Man 30
# Tindersticks 30
# Tito & Tarantula 30
# Tok Tok Tok 30
# Tracy Chapman 30
# Wu-Tang Clan 30
# Tok Tok Tok 31
# Art Pepper 31
# Barenaked Ladies 31
# blink-182 31
# Bruce Springsteen 31
# Buckcherry 31
# Cannonball Adderley 31
# Chet Baker 31
# Coldplay 31
# David Bowie 31
# Dexter Gordon 31
# Donald Byrd 31
# Foo Fighters 31
# Fred Astaire 31
# Garbage 31
# George Shearing 31
# Goo Goo Dolls 31
# Green Day 31
# Guns N' Roses 31
# Hank Mobley 31
# Ike Quebec 31
# Iron Maiden 31
# Joe Strummer 31
# Kenny Burrell 31
# Kevin Devine 31
# Last Days of April 31
# Metallica 31
# Michael Jackson 31
# Miles Davis 31
# Mirah 31
# Mr. Airplane Man 31
# Peter Gabriel 31
# Ramones 31
# Silver Jews 31
# Sonny Rollins 31
# Stanley Turrentine 31
# The Horace Silver Quintet 31
# The Kinks 31
# The Police 31
# The Thrills 31
# The Vines 31
# The Who 31
# Wayne Shorter 31
# Wes Montgomery 31
# Zero 7 31
# Dream Theater 32
# Aerosmith 32
# Steve Vai 32
# Dire Straits 32
# Stevie Ray Vaughan 32
# Suzie Higgie 32
# Desert Sessions 32
# Miles Davis 32
# Joe Satriani 32
# Chet Baker 32
# Herbie Hancock 32
# A Perfect Circle 32
# Alice in Chains 32
# Billie Holiday 32
# Fireworks Night 32
# Guns N' Roses 32
# Ike Quebec 32
# John Coltrane 32
# Morcheeba 32
# Oasis 32
# Stanley Turrentine 32
# The Beatles 32
# The Blues Brothers 32
# The Jimi Hendrix Experience 32
# The Mules 32
# Weezer 32
# AC/DC 32
# Aimee Mann 32
# Alanis Morissette 32
# Allison Crowe 32
# Anastacia 32
# Art Pepper 32
# Backyard Babies 32
# Ben Harper 32
# Bob Dylan 32
# Buckcherry 32
# Calexico 32
# Cannonball Adderley 32
# Charles Mingus 32
# Christian Kleine 32
# David Bowie 32
# Deep Purple 32
# Dexter Gordon 32
# Diana Krall 32
# Dizzy Gillespie 32
# Donald Byrd 32
# Duke Ellington 32
# Dusty Springfield 32
# Dutch Swing College Band 32
# Elbow 32
# Elvis Presley 32
# Esbjörn Svensson Trio 32
# Foo Fighters 32
# Frank Sinatra 32
# Free 32
# Fugazi 32
# George Shearing 32
# Gillian Welch 32
# Grant Green 32
# Guster 32
# Hank Mobley 32
# Horace Silver 32
# Hot Boogie Chillun 32
# I-F 32
# James Taylor 32
# Jimi Hendrix 32
# John Martyn 32
# Kate Bush 32
# Kenny Burrell 32
# King Pin 32
# Kiss 32
# Last Days of April 32
# Lenny Kravitz 32
# Linkin Park 32
# Liquid Tension Experiment 32
# Marillion 32
# Metallica 32
# Michael Nyman 32
# Natalie Imbruglia 32
# Nina Simone 32
# Nine Inch Nails 32
# No Doubt 32
# NOFX 32
# Norah Jones 32
# Oscar Peterson 32
# Pat Metheny 32
# Porcupine Tree 32
# Primitive Radio Gods 32
# Radiohead 32
# Roger McGuinn 32
# Smith 32
# Sofa Surfers 32
# Soilwork 32
# Sonny Rollins 32
# Sparklehorse 32
# Stabbing Westward 32
# Steppenwolf 32
# Steve Reich 32
# Stevie Wonder 32
# Swollen Members 32
# Talvin Singh 32
# The 69 Eyes 32
# The Byrds 32
# The Darkness 32
# The Dave Brubeck Quartet 32
# The Electric Prunes 32
# The Horace Silver Quintet 32
# The Pastels 32
# The Police 32
# The Rolling Stones 32
# The Smashing Pumpkins 32
# The Stranglers 32
# The White Stripes 32
# Thelonious Monk 32
# Thin Lizzy 32
# Tom Waits 32
# Travis 32
# Turbonegro 32
# Ugly Casanova 32
# Vangelis 32
# Warren Zevon 32
# Wayne Shorter 32
# Wes Montgomery 32
# Tower of Power 33
# Norah Jones 33
# Fiona Apple 33
# Rage Against the Machine 33
# Spock's Beard 33
# Stanley Jordan 33
# Kasey Chambers 33
# Joni Mitchell & James Taylor 33
# Supreme Beings of Leisure 33
# Dido 33
# Red Hot Chili Peppers 33
# Four Tet 33
# Air 33
# Frou Frou 33
# Godspeed You! Black Emperor 33
# Metallica 33
# Radiohead 33
# Thievery Corporation 33
# Brand New 33
# Cat Power 33
# Jack Johnson 33
# Jimi Hendrix 33
# múm 33
# Sigur Rós 33
# Sufjan Stevens 33
# The Album Leaf 33
# The Microphones 33
# The Postal Service 33
# Tori Amos 33
# Guns N' Roses 33
# Led Zeppelin 33
# Miles Davis 33
# Allison Crowe 33
# Beastie Boys 33
# Dream Theater 33
# Foo Fighters 33
# Herbie Hancock 33
# Jamie Cullum 33
# Nina Simone 33
# Soundgarden 33
# System of a Down 33
# The Rolling Stones 33
# Aerosmith 33
# Aesop Rock 33
# All 33
# Apocalyptica 33
# Avenged Sevenfold 33
# Bad Company 33
# Barenaked Ladies 33
# Belle and Sebastian 33
# Big Band 33
# Blur 33
# Brenda Lee 33
# Cheeseburger 33
# Chet Baker 33
# Chingy 33
# Christina Aguilera 33
# Control Machete 33
# Crosby, Stills, Nash & Young 33
# Damien Jurado 33
# Dark Tranquillity 33
# David Bowie 33
# Death 33
# Deru 33
# Diana Krall 33
# DJ Shadow 33
# Django Reinhardt 33
# Duran Duran 33
# Ella Fitzgerald 33
# Enanitos Verdes 33
# Eric Clapton 33
# Eurythmics 33
# EVE 6 33
# Faith No More 33
# Fear Factory 33
# Frank Zappa 33
# Free 33
# Garbage 33
# Garth Brooks 33
# Giant Sand 33
# Incubus 33
# Iron & Wine 33
# Iron Maiden 33
# Jamiroquai 33
# Joe Zawinul 33
# John Coltrane 33
# Johnny Cash 33
# Lali Puna 33
# Lenny Kravitz 33
# Limp Bizkit 33
# Lovage 33
# Manic Street Preachers 33
# McCoy Tyner 33
# Megadeth 33
# Mr. Scruff 33
# Muse 33
# Nickelback 33
# Nitin Sawhney 33
# Oasis 33
# Ocean Colour Scene 33
# Our Lady Peace 33
# Ozzy Osbourne 33
# Pat Metheny 33
# Pete Townshend 33
# Pixies 33
# Procol Harum 33
# Queensrÿche 33
# R.E.M. 33
# Rammstein 33
# Ranma 33
# RJD2 33
# Slayer 33
# Sneaker Pimps 33
# Sugarcult 33
# Sum 41 33
# The Allman Brothers Band 33
# The Ataris 33
# The Doors 33
# The Jimi Hendrix Experience 33
# The Libertines 33
# The Men of Porn 33
# The Moody Blues 33
# The Roots 33
# The Shamen 33
# The Tragically Hip 33
# The Velvet Underground 33
# The Verve Pipe 33
# The White Stripes 33
# Thyrfing 33
# Tom Waits 33
# Tool 33
# Turbonegro 33
# U2 33
# Yellowcard 33
# Miles Davis 34
# Mr. Big 34
# Nina Simone 34
# Nat King Cole 34
# Aerosmith 34
# Miles Davis & Marcus Miller 34
# Miles Davis and John Lee Hooker 34
# Foo Fighters 34
# Deep Purple 34
# Goo Goo Dolls 34
# Allison Crowe 34
# Ash 34
# Dire Straits 34
# Jimi Hendrix 34
# Radiohead 34
# Red Hot Chili Peppers 34
# ...And You Will Know Us by the Trail of Dead 34
# A Perfect Circle 34
# Air 34
# Alice Cooper 34
# Audioslave 34
# Auf der Maur 34
# AZ 34
# Beck 34
# Ben Harper 34
# Beth Gibbons 34
# Big Brother & The Holding Company 34
# Brant Bjork 34
# Caetano Veloso 34
# Chet Baker 34
# Chris Barber Jazz & Blues Band 34
# Coheed and Cambria 34
# Coldplay 34
# Creedence Clearwater Revival 34
# Daft Punk 34
# Damien Rice 34
# Das Pop 34
# Dashboard Confessional 34
# David Bowie 34
# Death Cab for Cutie 34
# Django Reinhardt 34
# Don Henley 34
# Earl Hines 34
# Elvis Presley 34
# Everclear 34
# Frank Sinatra 34
# Fuel 34
# Garbage 34
# Gene 34
# Giant Sand 34
# Goldfinger 34
# Green Day 34
# Guns N' Roses 34
# Guns On The Roof 34
# Hole 34
# Jamiroquai 34
# Joe Zawinul 34
# John Coltrane 34
# John Petrucci & Jordan Rudess 34
# King Crimson 34
# Kylie Minogue 34
# Led Zeppelin 34
# Les Soloistes De L'Opera National De Lyon 34
# Louis Armstrong 34
# Mark Knopfler 34
# Matchbox Twenty 34
# Mercy Machine 34
# Moby 34
# Monster Magnet 34
# Nancy Sinatra 34
# Nick Drake 34
# Nightwish 34
# Oasis 34
# Peace Orchestra 34
# Peter Gabriel 34
# Phoenix 34
# Prince 34
# Queen 34
# Red Snapper 34
# Remy Zero 34
# Rickie Lee Jones 34
# Seelenluft 34
# Sigur Rós 34
# Stereophonics 34
# The Arcade Fire 34
# The Beatles 34
# The Cinematic Orchestra 34
# The Futureheads 34
# The Kinks 34
# The KLF 34
# The Police 34
# The Pretenders 34
# The Stone Roses 34
# The Streets 34
# The Strokes 34
# The White Stripes 34
# The Yardbirds 34
# Thee Michelle Gun Elephant 34
# Travis 34
# U2 34
# Van Morrison 34
# Various Artists 34
# Velvet Revolver 34
# Weather Report 34
# Whitesnake 34
# Zero 7 34
# Mr. Big 35
# Deep Purple 35
# Dire Straits 35
# Def Leppard 35
# De La Soul 35
# Frank Zappa 35
# Miles Davis 35
# Bob Marley 35
# Chet Baker 35
# Coldplay 35
# Dizzy Gillespie 35
# Elliott Smith 35
# Eric Truffaz 35
# Freddie Hubbard 35
# John Coltrane 35
# Musical Youth 35
# 3 Doors Down 35
# AC/DC 35
# Aerosmith 35
# Alice in Chains 35
# Anastacia 35
# Anouk 35
# Aretha Franklin 35
# Audioslave 35
# Avril Lavigne 35
# Barenaked Ladies 35
# Beautiful Creatures 35
# Beck 35
# Belle and Sebastian 35
# Ben Folds Five 35
# Better Than Ezra 35
# Blues Traveler 35
# Bob Dylan 35
# Buckcherry 35
# Built to Spill 35
# Cake 35
# Candlebox 35
# Chris Cornell 35
# Cinderella 35
# Collective Soul 35
# Counting Crows 35
# Creed 35
# Creedence Clearwater Revival 35
# David Bowie 35
# Days of the New 35
# Dead Kennedys 35
# Dexter Gordon 35
# Disturbed 35
# Eels 35
# Ella Fitzgerald 35
# EVE 6 35
# Everclear 35
# Filter 35
# Foo Fighters 35
# Fuel 35
# Goldfinger 35
# Goo Goo Dolls 35
# Grandaddy 35
# Green Day 35
# Guns N' Roses 35
# Hundred Reasons 35
# Incubus 35
# James Taylor 35
# Janis Joplin 35
# Jurassic 5 35
# Kid Rock 35
# Kingdom Come 35
# Lee Morgan 35
# Less Than Jake 35
# Lit 35
# Live 35
# Lynyrd Skynyrd 35
# Marianne Faithfull 35
# MDFMK 35
# Metallica 35
# Ministry 35
# Mirah 35
# Moby 35
# Mogwai 35
# Neil Diamond 35
# Neil Young 35
# Neutral Milk Hotel 35
# Nick Drake 35
# Nine Inch Nails 35
# Nirvana 35
# Our Lady Peace 35
# OutKast 35
# Pat Benatar 35
# Pearl Jam 35
# Pixies 35
# Queen 35
# Queens of the Stone Age 35
# R.E.M. 35
# Rage Against the Machine 35
# Red Hot Chili Peppers 35
# Rob Zombie 35
# Saliva 35
# Scritti Politti 35
# Seven Mary Three 35
# Sheryl Crow 35
# Skid Row 35
# Soul Asylum 35
# Soundgarden 35
# Span 35
# Spin Doctors 35
# Spoon 35
# Staind 35
# Stevie Wonder 35
# Stone Temple Pilots 35
# Sum 41 35
# System of a Down 35
# Testament 35
# The Beatles 35
# The Black Crowes 35
# The Darkness 35
# The Fall 35
# The Hypnomen 35
# The Kinks 35
# The Offspring 35
# The Pogues 35
# The Polyphonic Spree 35
# The Rolling Stones 35
# The Verve Pipe 35
# The Wallflowers 35
# The Who 35
# Tomahawk 35
# U2 35
# Velvet Revolver 35
# Warrant 35
# Weezer 35
# Wilco 35
# Woody Shaw 35
# Bob Seger 36
# Something Corporate 36
# Team America: World Police 36
# Opeth 36
# Rammstein 36
# Joe Satriani 36
# Knowles 36
# The Black Crowes 36
# AC/DC 36
# Air 36
# Al Jarreau 36
# Antônio Carlos Jobim 36
# Atmosphere 36
# Badly Drawn Boy 36
# Bauhaus 36
# Ben Folds Five 36
# Billie Holiday 36
# Blackalicious 36
# Bob Dylan 36
# Bob Marley 36
# Buena Vista Social Club 36
# Calexico 36
# Chet Baker 36
# Counting Crows 36
# Dave Matthews Band 36
# Don Cherry 36
# Dr. John 36
# Duke Ellington 36
# Eagles 36
# Ella Fitzgerald 36
# Eric Clapton 36
# Five for Fighting 36
# Gary Moore 36
# George Michael 36
# Herbie Hancock 36
# Iron Maiden 36
# Jack Johnson 36
# James Brown 36
# James Taylor 36
# Jamey Aebersold 36
# Jimi Hendrix 36
# Joe Sample 36
# John Coltrane 36
# John Lee Hooker 36
# John Scofield 36
# Joni Mitchell 36
# Lewis Parker 36
# Live 36
# Lou Reed 36
# Louisiana Red 36
# Marty Robbins 36
# Massive Attack 36
# Mike Scott 36
# Miss Kittin & The Hacker 36
# Moby 36
# Morcheeba 36
# Nick Cave and the Bad Seeds 36
# Nina Simone 36
# NOFX 36
# Norah Jones 36
# Oasis 36
# Oglio Records 36
# Pat Metheny 36
# Paul Weller 36
# Pearl Jam 36
# Porn Music 36
# Portishead 36
# R.E.M. 36
# Red Hot Chili Peppers 36
# Red House Painters 36
# Santana 36
# Sonic Youth 36
# Sonny Clark 36
# Staind 36
# Stan Getz, Antonio Carlos Jobi 36
# Steely Dan 36
# Stereolab 36
# The Blues Brothers 36
# The Doors 36
# The Flaming Lips 36
# The Jon Spencer Blues Explosion 36
# The Rolling Stones 36
# The Velvet Underground 36
# The Wallflowers 36
# Tom Waits 36
# Tortoise 36
# Tower of Power 36
# Wayman Tisdale 36
# Dire Straits 37
# Weather Report 37
# The Classic Chill Out Album 37
# James Taylor 37
# The Kleptones 37
# David Hudson and Friends 37
# Ben Folds Five 37
# Joe Satriani 37
# Spin Doctors 37
# Level 42 37
# Jane's Addiction 37
# Rage Against the Machine 37
# Aerosmith 37
# Aimee Mann 37
# Al Jarreau 37
# Andrea Parker 37
# Beck 37
# Ben Folds 37
# Black Cat White Cat 37
# Broken Social Scene 37
# Can 37
# Cassandra Wilson 37
# Count Basie 37
# Def Leppard 37
# Depeche Mode 37
# Duran Duran 37
# Elvis Presley 37
# Erlend Øye 37
# Fela Kuti 37
# Frou Frou 37
# Gorillaz 37
# Incubus 37
# John Scofield 37
# Miles Davis 37
# Mission of Burma 37
# Mouse on Mars 37
# Neko Case 37
# Nina Simone 37
# Oasis 37
# Ozzy Osbourne 37
# Pearl Jam 37
# Phish 37
# Red Hot Chili Peppers 37
# Rufus Wainwright 37
# Sahara Hotnights 37
# Spoon 37
# The Arcade Fire 37
# The Postal Service 37
# The Streets 37
# The Von Bondies 37
# Yusef Lateef 37
# Counting Crows 38
# Nina Simone 38
# Crash Test Dummies 38
# The Flaming Lips 38
# The Classic Chill Out Album 38
# Bright Eyes 38
# Doves 38
# Elliott Smith 38
# Jamiroquai 38
# Nick Drake 38
# OutKast 38
# PJ Harvey 38
# Radiohead 38
# Spoon 38
# Talking Heads 38
# The Beach Boys 38
# The Beta Band 38
# The Kinks 38
# The Moody Blues 38
# The Rolling Stones 38
# The Stone Roses 38
# The Strokes 38
# The Velvet Underground 38
# A Number Of Names 38
# Abscess 38
# Air 38
# Al Di Meola 38
# Allison Crowe 38
# Anouar Brahem 38
# Astor Piazzolla 38
# At the Drive-In 38
# Badly Drawn Boy 38
# Beastie Boys 38
# Beck 38
# Belle and Sebastian 38
# Ben Folds 38
# Ben Folds Five 38
# Ben Kweller 38
# Björk 38
# Black Star 38
# Blur 38
# Bob Dylan 38
# Bruce Springsteen 38
# Charles Mingus 38
# Chet Baker 38
# Cream 38
# Crosby, Stills, Nash & Young 38
# Damien Rice 38
# Dave Brubeck 38
# Dave Douglas 38
# Dave Matthews Band 38
# David Bowie 38
# Deftones 38
# Diana Krall 38
# Dido 38
# Dixie Chicks 38
# Django Reinhardt 38
# Don Byron 38
# Don Henley 38
# Dr. John 38
# Echo & the Bunnymen 38
# Ed Harcourt 38
# Édith Piaf 38
# Eels 38
# Elvis Presley 38
# Fleetwood Mac 38
# Gallon Drunk 38
# Gavin Friday 38
# Gotan Project 38
# Grandaddy 38
# Interpol 38
# Iron & Wine 38
# James Brown 38
# Jeremy Enigk 38
# Joe Sample 38
# John Cage 38
# John Fred & His Playboy Band 38
# John Zorn 38
# Joy Division 38
# Karlheinz Stockhausen 38
# Kazuyuki K. Null - James Plotk 38
# Kenny Burrell 38
# King Crimson 38
# Kocani Orkestar 38
# Kraftwerk 38
# Kyoto Jazz Massive 38
# Lali Puna 38
# Lamb 38
# Led Zeppelin 38
# Lee "Scratch" Perry 38
# Limp Bizkit 38
# Madonna 38
# Marvin Gaye 38
# Massive Attack 38
# MC Solaar 38
# Megadeth 38
# Metallica 38
# Miles Davis 38
# Modest Mouse 38
# Mogwai 38
# Moneybrother 38
# Neil Young 38
# Neutral Milk Hotel 38
# New Flesh For Old 38
# Nine Inch Nails 38
# Nitin Sawhney 38
# Orchestra Baobab 38
# Ozzy Osbourne 38
# Papa M 38
# Pavement 38
# Peter Gabriel 38
# Phish 38
# Pixies 38
# Primal Scream 38
# Prince 38
# Queen 38
# Queens of the Stone Age 38
# R.E.M. 38
# Red Snapper 38
# Richard Ashcroft 38
# Rilo Kiley 38
# Sack & Blumm 38
# Santana 38
# Sigur Rós 38
# Simon & Garfunkel 38
# Stan Getz 38
# Stereolab 38
# Stevie Ray Vaughan 38
# Suzanne Vega 38
# The Allman Brothers Band 38
# The Beatles 38
# The Byrds 38
# The Charlatans 38
# The Clash 38
# The Cure 38
# The Doors 38
# The Fall 38
# The Kings Of Infinite Space 38
# The Magnetic Fields 38
# The Polyphonic Spree 38
# The Smiths 38
# The Unicorns 38
# The Verve 38
# The Walkmen 38
# The White Stripes 38
# Tool 38
# Tori Amos 38
# TV on the Radio 38
# U2 38
# Wilco 38
# Yesterday's New Quintet 38
# Yo La Tengo 38
# 菅野よう子 38
# Crash Test Dummies 39
# Soft Machine 39
# Ben Folds Five 39
# The Beatles 39
# ...And You Will Know Us by the Trail of Dead 39
# Aerosmith 39
# Alice Cooper 39
# Amon Tobin 39
# Audioslave 39
# Barry White 39
# Beastie Boys 39
# Bill Withers 39
# Black Sabbath 39
# Blur 39
# Broken Social Scene 39
# Chicago 39
# Chromeo 39
# Coparck 39
# Cut Chemist Meets Shortkut 39
# David Bowie 39
# Deep Purple 39
# Deltron 3030 39
# Diana Ross and the Supremes 39
# Edwin Starr 39
# Electric Light Orchestra 39
# Elvis Presley 39
# Eminem 39
# Eric Clapton 39
# Frank Zappa 39
# Garbage 39
# Goldfrapp 39
# Jamiroquai 39
# Jan Garbarek Group 39
# Janis Ian 39
# Kansas 39
# KingBathmat 39
# Ludwig van Beethoven 39
# Maceo Parker 39
# Marilyn Monroe 39
# Massive Attack 39
# Matchbox Twenty 39
# Medeski, Martin and Wood 39
# Monte Cazazza 39
# My Morning Jacket 39
# Nina Nastasia 39
# Norman Greenbaum 39
# Paris Combo 39
# Parliament 39
# Pet Shop Boys 39
# Potuznik 39
# Primus 39
# Prince 39
# Queen 39
# Ralph Towner 39
# Rancid 39
# Rilo Kiley 39
# Saltamontes 39
# Santana 39
# Scarlet Soho 39
# Simon & Garfunkel 39
# Sparklehorse 39
# Styx 39
# Subsonica 39
# Supertramp 39
# The Avalanches 39
# The Black Crowes 39
# The Byrds 39
# The Decemberists 39
# The Emotions 39
# The Future Sound of London 39
# The Get Up Kids 39
# The Jon Spencer Blues Explosion 39
# The Soft Pink Truth 39
# The Walkmen 39
# The White Stripes 39
# Van McCoy 39
# Vilhjalmur Vilhjalmsson 39
# Wild Cherry 39
# Ben Folds Five 40
# Live 40
# Katie Melua 40
# Spin Doctors 40
# Aerosmith 40
# Beck 40
# Everclear 40
# Jack Johnson 40
# Miles Davis 40
# Queens of the Stone Age 40
# The Smashing Pumpkins 40
# Air 40
# Al Jarreau 40
# Ben Harper 40
# Blackalicious 40
# Coldplay 40
# Collective Soul 40
# Counting Crows 40
# Deep Purple 40
# dEUS 40
# Dr. John 40
# Eagles 40
# Ella Fitzgerald 40
# Eric Clapton 40
# Green Day 40
# Guns N' Roses 40
# Iron Maiden 40
# James Brown 40
# James Taylor 40
# Lynyrd Skynyrd 40
# Massive Attack 40
# Metallica 40
# Mike Scott 40
# Muse 40
# Nine Inch Nails 40
# Norah Jones 40
# Oasis 40
# Pink Floyd 40
# Rage Against the Machine 40
# Red Hot Chili Peppers 40
# Stevie Wonder 40
# Tesla 40
# The Arcade Fire 40
# The Blues Brothers 40
# The Cranberries 40
# The Offspring 40
# The Police 40
# The Wallflowers 40
# Tom Waits 40
# Van Morrison 40
# Weezer 40
# "Weird Al" Yankovic 40
# 3 Doors Down 40
# A Tribe Called Quest 40
# a-ha 40
# Alien Ant Farm 40
# Ani DiFranco 40
# Anita Baker 40
# ARE weapons 40
# Ash 40
# Atmosphere 40
# Audioslave 40
# Augustus Pablo 40
# Barenaked Ladies 40
# Barry White 40
# Bauhaus 40
# Beautiful Creatures 40
# Belinda Carlisle 40
# Beth Orton 40
# Billy Joel 40
# Blind Guardian 40
# blink-182 40
# Blur 40
# Bob Dylan 40
# bob hund 40
# Bob Marley 40
# Bonnie 'Prince' Billy 40
# Bruce Springsteen 40
# Bryan Adams 40
# Buckcherry 40
# Buena Vista Social Club 40
# Califone 40
# Claude Debussy 40
# Coil 40
# Cowboy Junkies 40
# Crash Test Dummies 40
# Creed 40
# Dave Grusin 40
# Dave Matthews Band 40
# Davey Graham 40
# David Bowie 40
# David Gray 40
# Deep Blue Something 40
# Desmond Dekker 40
# Dizzy Gillespie 40
# DJ Shadow 40
# Django Reinhardt 40
# Don Cherry 40
# DragonForce 40
# Dream Theater 40
# Drexciya 40
# Duke Ellington 40
# DumDums 40
# Duran Duran 40
# Eddie Cochran 40
# Elliott Smith 40
# Evanescence 40
# Filter 40
# Five for Fighting 40
# Foo Fighters 40
# France Gall 40
# Frank Sinatra 40
# Fred Astaire 40
# Freddie Hubbard 40
# Frou Frou 40
# Fuel 40
# Fugees 40
# Gamma Ray 40
# Garbage 40
# Gary Jules 40
# Gary Moore 40
# George Michael 40
# Gin Blossoms 40
# Goo Goo Dolls 40
# Herbie Hancock 40
# Hoobastank 40
# Jack Johnson & Ben Harper 40
# Jazz Jamaica All Stars 40
# Jeff Beck 40
# Jeff Buckley 40
# Jewel 40
# Jim Beard 40
# Jimi Hendrix 40
# Joan Osborne 40
# Joe Sample 40
# John Coltrane 40
# John Hassel and Brian Eno 40
# John Hiatt & The Guilty Dogs 40
# John Lee Hooker 40
# John Mayer 40
# Jonathan Richman And The Modern Lovers 40
# Joni Mitchell 40
# Judas Priest 40
# Jurassic 5 40
# Kaffe Matthews 40
# Kasey Chambers 40
# Komeda 40
# Led Zeppelin 40
# Lenny 40
# Lenny Kravitz 40
# Liquid Tension Experiment 40
# Lou Reed 40
# Ludwig van Beethoven 40
# Marty Robbins 40
# Matchbox Twenty 40
# Michael Jackson 40
# Miles Davis Quintet 40
# Miss Kittin & The Hacker 40
# Moby 40
# Momus 40
# Monty Python 40
# Morcheeba 40
# Natalie Imbruglia 40
# Neil Young 40
# Nick Cave and the Bad Seeds 40
# Nick Drake 40
# Nickelback 40
# Nirvana 40
# NOFX 40
# Our Lady Peace 40
# Paul van Dyk 40
# Pearl Jam 40
# Portishead 40
# Potuznik 40
# Prince 40
# R.E.M. 40
# Radiohead 40
# Rammstein 40
# RDB 40
# Red House Painters 40
# Roni Size / Reprazent 40
# Roy Ayers 40
# Santana 40
# Sarah McLachlan 40
# Scorpions 40
# Semisonic 40
# Seven Channels 40
# Sheryl Crow 40
# Skam Records Presents 40
# Skid Row 40
# Soft Machine 40
# Sonic Youth 40
# Sonny Clark 40
# Soundgarden 40
# Sparklehorse 40
# St. Germain 40
# Staind 40
# Stan Getz 40
# Stan Getz, Antonio Carlos Jobi 40
# Steely Dan 40
# Stereolab 40
# Steve Vai 40
# Stevie Ray Vaughan 40
# Stone Temple Pilots 40
# Talking Heads 40
# Texas 40
# The Ballistic Brothers 40
# The Beatles 40
# The Black Crowes 40
# The Books 40
# The Clash 40
# The Cure 40
# The Darkness 40
# The Dirty Dozen Brass Band 40
# The Doors 40
# The Elephant Table Album 40
# The Flaming Lips 40
# The Herbaliser 40
# The Jackson 5 40
# The Jon Spencer Blues Explosion 40
# The Pastels 40
# The Presidents of the United States of America 40
# The Proclaimers 40
# The Rolling Stones 40
# The Stooges 40
# The Style Council 40
# The Tragically Hip 40
# The White Stripes 40
# Thievery Corporation 40
# Tim McGraw 40
# Tomahawk 40
# Tool 40
# Tortoise 40
# Tracy Chapman 40
# Travis 40
# Turbonegro 40
# Two Lone Swordsmen 40
# Van Halen 40
# Wayman Tisdale 40
# Willis Jackson 40
# Wire 40
# Yes 40
# Yo La Tengo 40
# Neutral Milk Hotel 41
# 311 41
# Aimee Mann 41
# Air 41
# Alice in Chains 41
# Amon Tobin 41
# Anastacia 41
# Annetenna 41
# Astrud Gilberto 41
# Ben Folds 41
# Ben Lee 41
# Björk 41
# Blood Ruby 41
# Bonnie 'Prince' Billy 41
# Bright Eyes 41
# Carly Simon 41
# Chromeo 41
# Coparck 41
# De La Soul 41
# Dire Straits 41
# Dizzy Gillespie 41
# Don Byron 41
# Dusty Springfield 41
# Eels 41
# Erykah Badu 41
# Fiona Apple 41
# Frankie Goes to Hollywood 41
# Gallon Drunk 41
# Henry Mancini 41
# HIM 41
# Hot Hot Heat 41
# Ist 41
# Jamiroquai 41
# Joan Jett and the Blackhearts 41
# John Frusciante 41
# Joni Mitchell 41
# Jurassic 5 41
# Kate Bush 41
# Kent 41
# Lamb 41
# Liars 41
# Live 41
# Maceo Parker 41
# Manu Chao 41
# Marty Robbins 41
# Marvin Gaye 41
# Massive Attack 41
# Monte Cazazza 41
# Mum 41
# Natasha Bedingfield 41
# Nina Simone 41
# Nirvana 41
# No Doubt 41
# Norah Jones 41
# Ocean Colour Scene 41
# Pat Metheny Group 41
# Peanuts Wilson 41
# Pearl Jam 41
# Pet Shop Boys 41
# Peter Hammill 41
# Pixies 41
# Plaid 41
# Prefuse 73 41
# R.E.M. 41
# Radiohead 41
# Rage Against the Machine 41
# Ralph Towner 41
# Robert Johnson 41
# Röyksopp 41
# Sarah McLachlan 41
# Sergio Mendes 41
# Skeleton Key 41
# Smash Mouth 41
# Sonic Youth 41
# Stone Temple Pilots 41
# Sugababes 41
# System of a Down 41
# The Beach Boys 41
# The Beatles 41
# The Byrds 41
# The Clash 41
# The Killers 41
# The Pastels 41
# The Shins 41
# The Smiths 41
# The Velvet Underground 41
# The White Stripes 41
# Tom Petty and The Heartbreakers 41
# Tori Amos 41
# Tracy Chapman 41
# Tryo 41
# U2 41
# Wire 41
# Yusef Lateef 41
# Jason Luckett 42
# Beck 42
# Etta James 42
# Aerosmith 42
# Bob Dylan 42
# Bryan Adams 42
# David Bowie 42
# Disturbed 42
# Eric Clapton 42
# Jimi Hendrix 42
# Live 42
# Lou Reed 42
# Lynyrd Skynyrd 42
# Nirvana 42
# No Doubt 42
# Paul Weller 42
# Soundgarden 42
# Air 42
# Anthony Braxton 42
# Antipop Consortium 42
# Apollo 2000 42
# Atmosphere 42
# Barry White 42
# Bauhaus 42
# Beautiful Creatures 42
# Beth Orton 42
# Buena Vista Social Club 42
# Coldplay 42
# Counting Crows 42
# De La Soul 42
# Deee-Lite 42
# Deep Purple 42
# Dire Straits 42
# Don Cherry 42
# Doves 42
# Dr. John 42
# Eagles 42
# Eels 42
# Elvis Presley 42
# Faith No More 42
# Fuel 42
# Herbie Hancock 42
# Iron Maiden 42
# James Brown 42
# James Taylor 42
# Jeff Buckley 42
# John Coltrane 42
# Junior Senior 42
# Laibach 42
# Massive Attack 42
# Matchbox Twenty 42
# Metallica 42
# Michael Jackson 42
# Michael Nyman 42
# Michelle Branch 42
# Morcheeba 42
# Muzsikas 42
# Neutral Milk Hotel 42
# Nick Cave and the Bad Seeds 42
# Nine Inch Nails 42
# Nocturnal Emissions 42
# NOFX 42
# Oasis 42
# Portishead 42
# Radiohead 42
# Red Hot Chili Peppers 42
# Red House Painters 42
# Santana 42
# Silver Jews 42
# Silverchair 42
# Simon & Garfunkel 42
# Sofa Surfers 42
# Sonic Youth 42
# St. Petersburg Classics 42
# Staind 42
# Stan Getz, Antonio Carlos Jobi 42
# Status Quo 42
# Steely Dan 42
# Stereolab 42
# Stevie Ray Vaughan 42
# Stone Temple Pilots 42
# System of a Down 42
# Tenacious D 42
# Tesla 42
# The Allman Brothers Band 42
# The Darkness 42
# The Dave Brubeck Quartet 42
# The Dirty Dozen Brass Band 42
# The Doors 42
# The Flaming Lips 42
# The Kinks 42
# The Presidents of the United States of America 42
# The Rolling Stones 42
# The Who 42
# Tom Waits 42
# Tower of Power 42
# Van Morrison 42
# Velvet Revolver 42
# Weezer 42
# Yami Bolo, Sly & Robbie 42
# Zero 7 42
# Arctic Monkeys 43
# Jimi Hendrix 43
# Milburn 43
# Chikinki 43
# Nat King Cole 43
# Cassandra Wilson 43
# Coldplay 43
# Duke Ellington 43
# Jack Johnson 43
# James Brown 43
# Michael Bublé 43
# Norah Jones 43
# Pat Metheny 43
# Red Hot Chili Peppers 43
# Thelonious Monk 43
# Al Jarreau 43
# Amon Tobin 43
# Antônio Carlos Jobim 43
# Apocalyptica 43
# Aqualung 43
# Art Tatum 43
# Astrud Gilberto 43
# Ben Harper 43
# Bill Evans 43
# Bill Frisell 43
# Billie Holiday 43
# Bryan Adams 43
# Bud Powell 43
# Charles Mingus 43
# Count Basie 43
# Deep Purple 43
# Django Reinhardt 43
# Dorothy Ashby 43
# Dr. John 43
# Embrace 43
# Eric Clapton 43
# Frank Sinatra 43
# Gary Moore 43
# Jaco Pastorius 43
# Jamie Cullum 43
# Jazzanova 43
# John Coltrane 43
# John Hiatt & The Guilty Dogs 43
# John Scofield 43
# John Zorn 43
# Joni Mitchell 43
# Keith Jarrett 43
# Live 43
# Mahavishnu Orchestra 43
# Marcus Miller 43
# Matchbox Twenty 43
# Michael Jackson VS The Prodigy 43
# Mike Scott 43
# Miles Davis 43
# Moby Vs Jet 43
# Morcheeba 43
# Nick Cave and the Bad Seeds 43
# Nina Simone 43
# NOFX 43
# Oasis 43
# Paul Weller 43
# Ray Charles 43
# Red House Painters 43
# Santana 43
# Sarah Vaughan 43
# Snow Patrol 43
# Soft Machine 43
# Sonny Rollins 43
# Stan Getz 43
# Tesla 43
# The Arcade Fire 43
# The Blues Brothers 43
# The Darkness 43
# Tom Waits 43
# Tower of Power 43
# Travis 43
# Turin Brakes 43
# Wayman Tisdale 43
# Weather Report 43
# Wes Montgomery 43
# 菅野よう子 43
# Stevie Wonder 44
# Jason Luckett 44
# Joni Mitchell 44
# Marvin Gaye 44
# Neil Young 44
# Tracy Chapman 44
# Counting Crows 45
# R.E.M. 45
# Jools Holland & His Rhythm Blues Orchestra 45
# Jamiroquai 45
# Incubus 45
# ...
# Too $hort 1074
# 5th Ward Juvenilez 1074
# Att Will 1074
# Big Syke 1074
# Daz Dillinger 1074
# Dove Shack 1074
# Dru Down 1074
# Foesum 1074
# Havoc & Prodeje 1074
# Ice Cube 1074
# Kurupt 1074
# Mack 10 1074
# Mista Grimm 1074
# Tha Eastsidaz 1074
# Twinz 1074
# Bruno Mars 1075
# Hooplakidz 1075
# Journey 1075
# Lady Gaga 1075
# Lofty 1075
# Rosé 1075
# Nativity! Cast 1076
# The Mighty Mighty Bosstones 1076
# Vindaloo Singh 1076
# Jack Black 1076
# Minecraft 1076
# Third Eye Blind 1076
# Weezer 1076
# Will Smith 1076
# Green Day 1077
# Nativity! Cast 1077
# N.W.A. 1077
# The Notorious B.I.G. 1077
# Dr. Dre 1077
# Oasis 1077
# Nicki Minaj 1077
# Eazy-E 1077
# Geto Boys 1077
# Cypress Hill 1077
# Eiffel 65 1077
# Sum 41 1077
# Flo Rida 1077
# Gang Starr 1077
# High School Musical Cast 1077
# Lady Gaga 1077
# Lucas Grabeel 1077
# Mack 10 1077
# Naughty By Nature 1077
# Pitbull 1077
# Snoop Dogg 1077
# TLC 1077
# Troy 1077
# Twinz 1077
# Warren G 1077
# 2nd II None 1077
# 2Pac 1077
# Andy And The Odd Socks 1077
# Big Syke 1077
# Def Leppard 1077
# Digital Underground 1077
# Dilated Peoples 1077
# Eminem 1077
# Eric B. & Rakim 1077
# House of Pain 1077
# Ice Cube 1077
# Jessie J 1077
# KAROL G 1077
# Kesha 1077
# Kurupt 1077
# Mobb Deep 1077
# Onyx 1077
# Pat Benatar 1077
# Poison 1077
# Rob Base & DJ EZ Rock 1077
# Shade Sheist 1077
# Slick Rick 1077
# The Cult 1077
# The Pharcyde 1077
# Third Eye Blind 1077
# Usher 1077
# Van Halen 1077
# Vanessa Hudgens 1077
# Whitesnake 1077
# NOFX 1078
# Daft Punk 1078
# Eminem 1078
# Nicki Minaj 1078
# Pitbull 1078
# Lady Gaga 1078
# Saah 1078
# The Offspring 1078
# Kesha 1078
# Mr. Kensington 1078
# Oscar Kowalski 1078
# TLC 1078
# Tommaso Farinetti 1078
# Usher 1078
# Arrowsmith 1078
# blink-182 1078
# Dr. Dre 1078
# Eren Önsoy 1078
# Evening Primrose 1078
# Jessie J 1078
# Katy Perry 1078
# Lennart Altgenug 1078
# Peter Belec 1078
# River Camille 1078
# SONBAHAR 1078
# The Notorious B.I.G. 1078
# The Weeknd 1078
# Timbaland 1078
# 2Pac 1078
# Adrien de la Salle 1078
# Alanna Crouch 1078
# Anna Simonetta 1078
# April Chung 1078
# Big Pun 1078
# Douglas Parth 1078
# Eazy-E 1078
# Emma Jackson 1078
# Eric B. & Rakim 1078
# Flo Rida 1078
# Forest Friend 1078
# Geto Boys 1078
# Jonathan L'Espérance 1078
# Jordi Forniés 1078
# Joseph Nimoh 1078
# Juan Pablo Garcia 1078
# Kanye West 1078
# Little Symphony 1078
# Mobb Deep 1078
# Nativity! Cast 1078
# Nelly Furtado 1078
# Nikolas Belalis 1078
# Stephen Weber 1078
# Warren G 1078
# Wu-Tang Clan 1078
# Eric Clapton 1079
# Eric Clapton 1080
# James Morrison 1080
# McFly 1080
# Crazy Frog 1080
# Oasis 1080
# Parry Gripp 1080
# Busted 1080
# Huey Lewis & The News 1080
# Madonna 1080
# Sting 1080
# ThnxCya 1080
# Billy Joel 1080
# Bob Marley & The Wailers 1080
# Bruce Springsteen 1080
# Calvin Harris 1080
# Jack Black 1080
# Kaiser Chiefs 1080
# The Feeling 1080
# The Weeknd 1080
# ABBA 1080
# Alphabeat 1080
# Belinda Carlisle 1080
# Bruno Mars 1080
# Cartoons 1080
# Cher 1080
# Chicken Dance 1080
# Counting Crows 1080
# Crazy Music Channel 1080
# Daft Punk 1080
# Darren Checkley 1080
# Daryl Hall & John Oates 1080
# Deep Purple 1080
# Diana Ross 1080
# Eiffel 65 1080
# Elton John 1080
# Five 1080
# George Michael 1080
# Gorillaz 1080
# Hans Zimmer 1080
# Harold Faltermeyer 1080
# Jack Johnson 1080
# Jessie J 1080
# Julie Andrews 1080
# Kate Nash 1080
# Kim Carnes 1080
# Lady Gaga 1080
# Los Del Rio 1080
# Mark Knopfler 1080
# Mark Mothersbaugh 1080
# Mcap Steve 1080
# Ocean Colour Scene 1080
# Paul Hand 1080
# Peter Combe 1080
# Queen 1080
# Razorlight 1080
# Scouting for Girls 1080
# Sixpence None the Richer 1080
# SK Shlomo 1080
# Stereophonics 1080
# Sublime 1080
# Take That 1080
# The Beatles 1080
# The Fratellis 1080
# The Goo Goo Dolls 1080
# The Kooks 1080
# The Proclaimers 1080
# The White Stripes 1080
# Weezer 1080
# Green Day 1081
# NOFX 1081
# Rancid 1081
# The Shadows 1081
# The Brainrot World 1081
# Daft Punk 1081
# Bowling for Soup 1081
# Fatboy Slim 1081
# Foo Fighters 1081
# Gorillaz 1081
# LFO 1081
# Mark Morrison 1081
# Neon Jungle 1081
# No Doubt 1081
# Portugal. The Man 1081
# Red Hot Chili Peppers 1081
# RocViBabot 1081
# Santana 1081
# Supergrass 1081
# The Notorious B.I.G. 1081
# Vengaboys 1081
# The Offspring 1082
# Eric Clapton 1082
# Bowling for Soup 1082
# GoldFord 1082
# Green Day 1082
# Mark Morrison 1082
# Plain White T's 1082
# Rancid 1082
# Sex Pistols 1082
# Sixpence None the Richer 1082
# The Beatles 1082
# Third Eye Blind 1082
# The Offspring 1083
# Submotion Orchestra 1083
# My Chemical Romance 1083
# Sum 41 1083
# Andrew W.K. 1083
# Rise Against 1083
# Sublime 1083
# The All-American Rejects 1083
# The Mighty Mighty Bosstones 1083
# A Day to Remember 1083
# AFI 1083
# Against Me! 1083
# Alien Ant Farm 1083
# Fall Out Boy 1083
# Goldfinger 1083
# Good Charlotte 1083
# Jack Black 1083
# Jimmy Eat World 1083
# Kidnap 1083
# Millencolin 1083
# Paramore 1083
# Ramones 1083
# Rancid 1083
# Ricky Desktop 1083
# Set It Off 1083
# The White Stripes 1083
# Yellowcard 1083
# Zebrahead 1083
# The Offspring 1084
# Crazy Frog 1084
# Saja Boys 1084
# HUNTR/X 1084
# Bowling for Soup 1084
# Buzzcocks 1084
# Ramones 1084
# Rancid 1084
# Rise Against 1084
# TWICE 1084
# Yellowcard 1084
# +44 1084
# Bodyjar 1084
# Dianilis 1084
# Jimmy Eat World 1084
# Mark Mothersbaugh 1084
# Queen 1084
# Simple Plan 1084
# Social Distortion 1084
# Sparrow Sleeps 1084
# The All-American Rejects 1084
# The Ataris 1084
# The Clash 1084
# The Distillers 1084
# ThnxCya 1084
# Transplants 1084
# The Gaslight Anthem 1085
# Bowling for Soup 1085
# HUNTR/X 1085
# Saja Boys 1085
# TWICE 1085
# The Offspring 1085
# The Cranberries 1085
# Kylie Minogue 1085
# Michael Bublé 1085
# Rumi 1085
# Sia 1085
# Adam Christopher 1085
# Amber Leigh Irish 1085
# Ashlight Revival 1085
# Brenda Lee 1085
# Brett Eldredge 1085
# Buckingham Nicks 1085
# Coldplay 1085
# Fleetwood Mac 1085
# Foo Fighters 1085
# Gene Autry 1085
# Joan Jett & The Blackhearts 1085
# Jokers 1085
# Kelly Clarkson 1085
# Marcelo Zarvos 1085
# Matt Johnson 1085
# MeloMance 1085
# MilkyyMelodies 1085
# Mud 1085
# Otis Redding 1085
# Queen 1085
# Red Hot Chili Peppers 1085
# Straight No Chaser 1085
# The Drifters 1085
# The Killers 1085
# Wizzard 1085
# Yuko 1085
# HUNTR/X 1086
# The Offspring 1086
# Foo Fighters 1086
# Saja Boys 1086
# TWICE 1086
# Glen Campbell 1086
# The Jackson 5 1086
# Fleetwood Mac 1086
# Frank Sinatra 1086
# Rumi 1086
# The Cure 1086
# Train 1086
# Alvin & The Chipmunks 1086
# Andy Williams 1086
# Boney M. 1086
# Bruce Springsteen 1086
# Destiny's Child 1086
# Gene Autry 1086
# Heart 1086
# José Feliciano 1086
# Mariah Carey 1086
# MeloMance 1086
# Muse 1086
# Nickelback 1086
# Oasis 1086
# Pink Martini 1086
# Santana 1086
# Shakin' Stevens 1086
# The Beatles 1086
# The Clash 1086
# The Cranberries 1086
# The Killers 1086
# The Rolling Stones 1086
# Tom Middleton 1086
# U2 1086
# Wham! 1086
# HUNTR/X 1087
# Saja Boys 1087
# Andy And The Odd Socks 1087
# TWICE 1087
# *NSYNC 1087
# Jokers 1087
# MeloMance 1087
# Rumi 1087
# Jessica Simpson 1087
# Tony Bennett 1087
# Bob Dylan 1087
# Boney M. 1087
# Britney Spears 1087
# Bruce Springsteen 1087
# Darlene Love 1087
# Daryl Hall & John Oates 1087
# Destiny's Child 1087
# Elvis Presley 1087
# Gayla Peevey 1087
# Gene Autry 1087
# Il Divo 1087
# John Williams 1087
# Johnny Cash 1087
# José Feliciano 1087
# Kelly Clarkson 1087
# Kenny G 1087
# Leona Lewis 1087
# Luis Miguel 1087
# Luther Vandross 1087
# Marcelo Zarvos 1087
# Maria Mena 1087
# Mariah Carey 1087
# Meghan Trainor 1087
# New Kids on the Block 1087
# Only Boys Aloud 1087
# Perry Como 1087
# Run–D.M.C. 1087
# Shakin' Stevens 1087
# Susan Boyle 1087
# Tom Odell 1087
# Whitney Houston 1087
# Andy And The Odd Socks 1088
# The Shadows 1088
# TWICE 1088
# Saja Boys 1088
# After School 1088
# Cher 1088
# Cliff Richard & The Shadows 1088
# Elton John 1088
# Gene Autry 1088
# Slade 1088
# Vince Gill 1088
# Wham! 1088
# Wizzard 1088
# HUNTR/X 1089
# Saja Boys 1089
# TWICE 1089
# Rumi 1089
# Marcelo Zarvos 1089
# MeloMance 1089
# Jokers 1089
# HUNTR/X 1090
# Saja Boys 1090
# Oscar Kowalski 1090
# TWICE 1090
# Emma Jackson 1090
# Evening Primrose 1090
# Jokers 1090
# Arrowsmith 1090
# La Louve 1090
# Mr. Kensington 1090
# Peter Belec 1090
# Rumi 1090
# Still Restless 1090
# Adrien de la Salle 1090
# Against Me! 1090
# Aija Alsiņa 1090
# Anastasiya Ihnatovich 1090
# Antonio Ministeri 1090
# April Chung 1090
# Bowling for Soup 1090
# Deborah Offenhauser 1090
# Green Day 1090
# Guilherme Veroneze 1090
# Led Zeppelin 1090
# Marcelo Zarvos 1090
# My Chemical Romance 1090
# Nikolas Belalis 1090
# Paramore 1090
# Rich Mortimer 1090
# Rose Riebl 1090
# Sarah Houston 1090
# The All-American Rejects 1090
# The Interrupters 1090
# The Offspring 1090
# The Rolling Stones 1090
# Yellowcard 1090
# The Gaslight Anthem 1091
# The Shadows 1091
# Bon Jovi 1091
# Bowling for Soup 1091
# Jack Black 1091
# Pulp 1091
# Razorlight 1091
# Bobby Darin 1091
# Fall Out Boy 1091
# Ritchie Valens 1091
# Sum 41 1091
# The Offspring 1091
# Alien Ant Farm 1091
# Blur 1091
# Crazy Frog 1091
# Fountains of Wayne 1091
# Good Charlotte 1091
# HUNTR/X 1091
# James Morrison 1091
# Kate Nash 1091
# Lustra 1091
# McFly 1091
# MeloMance 1091
# Oasis 1091
# Otis Redding 1091
# Rumi 1091
# The All-American Rejects 1091
# The Feeling 1091
# The Kooks 1091
# Yusuf / Cat Stevens 1091
# Green Day 1092
# Fall Out Boy 1092
# Against Me! 1092
# Geto Boys 1092
# The Offspring 1092
# blink-182 1092
# Bowling for Soup 1092
# HUNTR/X 1092
# Jack Black 1092
# Ramones 1092
# Sex Pistols 1092
# Sum 41 1092
# The Notorious B.I.G. 1092
# Cypress Hill 1092
# Mobb Deep 1092
# Nas 1092
# Red Hot Chili Peppers 1092
# The All-American Rejects 1092
# The Clash 1092
# U2 1092
# Vindaloo Singh 1092
# Wu-Tang Clan 1092
# AFI 1092
# Billie Joe Armstrong 1092
# Blur 1092
# Buzzcocks 1092
# Crazy Frog 1092
# Dead Kennedys 1092
# Deez Nuts 1092
# Dr. Dre 1092
# Eazy-E 1092
# Eric B. & Rakim 1092
# Foo Fighters 1092
# Ice Cube 1092
# Jimmy Eat World 1092
# Jokers 1092
# Less Than Jake 1092
# Marcelo Zarvos 1092
# Marky Mark and the Funky Bunch 1092
# MeloMance 1092
# N.W.A. 1092
# Ol' Dirty Bastard 1092
# OutKast 1092
# Rancid 1092
# Rise Against 1092
# Rob Base & DJ EZ Rock 1092
# Rumi 1092
# Run–D.M.C. 1092
# Simple Plan 1092
# The Interrupters 1092
# The Killers 1092
# Third Eye Blind 1092
# Tone-Loc 1092
# TWICE 1092
# Weezer 1092
# Zebrahead 1092
# Jack Black 1093
# Five 1093
# Foo Fighters 1093
# Fleetwood Mac 1093
# Jimmy Eat World 1093
# Oasis 1093
# The Offspring 1093
# blink-182 1093
# Blur 1093
# Cartoons 1093
# Good Charlotte 1093
# Joan Jett & The Blackhearts 1093
# My Chemical Romance 1093
# Ramones 1093
# The All-American Rejects 1093
# The Clash 1093
# The Cure 1093
# ThnxCya 1093
# Tina Turner 1093
# Alien Ant Farm 1093
# All Time Low 1093
# Black Sabbath 1093
# Fall Out Boy 1093
# Ghost 1093
# Goldfinger 1093
# Green Day 1093
# Heart 1093
# Lit 1093
# Lustra 1093
# Metallica 1093
# Muse 1093
# Paramore 1093
# Queen 1093
# Red Hot Chili Peppers 1093
# Rise Against 1093
# Sarah Spring 1093
# Sublime 1093
# The Cranberries 1093
# The Killers 1093
# The Mighty Mighty Bosstones 1093
# The Struts 1093
# The White Stripes 1093
# The Who 1093
# The Wurzels 1093
# Yellowcard 1093
# Five 1094
# Miss Saigon Original Cast 1094
# Mad Dog Mcrea 1094
# Backstreet Boys 1094
# Jack Black 1094
# Cypress Hill 1094
# HUNTR/X 1094
# Queen 1094
# Snoop Dogg 1094
# Fleetwood Mac 1094
# N.W.A. 1094
# Red Hot Chili Peppers 1094
# Against Me! 1094
# Black Sabbath 1094
# Digital Underground 1094
# Dr. Dre 1094
# Eazy-E 1094
# Gang Starr 1094
# Geto Boys 1094
# Onyx 1094
# OutKast 1094
# The Cure 1094
# The Notorious B.I.G. 1094
# The Offspring 1094
# The Police 1094
# Warren G 1094
# Xzibit 1094
# Green Day 1095
# Five 1095
# The Offspring 1095
# Snoop Dogg 1095
# Warren G 1095
# Biz Markie 1095
# Cage the Elephant 1095
# Cypress Hill 1095
# Dr. Dre 1095
# Jack Black 1095
# Ol' Dirty Bastard 1095
# Pras 1095
# The Notorious B.I.G. 1095
# Third Eye Blind 1095
# Twenty One Pilots 1095
# Young Mc 1095
# Blur 1095
# Bon Jovi 1095
# Dru Down 1095
# Eazy-E 1095
# Foo Fighters 1095
# Kaleo 1095
# Kings of Leon 1095
# Lil 1/2 Dead 1095
# Linkin Park 1095
# Lynyrd Skynyrd 1095
# N.W.A. 1095
# Nas 1095
# Nipsey Hussle 1095
# Nirvana 1095
# Pearl Jam 1095
# Rage Against the Machine 1095
# Seetrushkin 1095
# Survivor 1095
# System of a Down 1095
# Twinz 1095
# Wheatus 1095
# Andy And The Odd Socks 1096
# Jack Black 1096
# Green Day 1096
# Crazy Frog 1096
# Naughty By Nature 1096
# Elton John 1096
# Luniz 1096
# Nick Cope 1096
# OutKast 1096
# Snoop Dogg 1096
# The Chemical Brothers 1096
# Xzibit 1096
# Foo Fighters 1097
# Everclear 1097
# Knife Party 1097
# blink-182 1097
# DJ Jazzy Jeff & The Fresh Prince 1097
# Joan Jett & The Blackhearts 1097
# Matchbox Twenty 1097
# Skrillex 1097
# Spin Doctors 1097
# The Offspring 1097
# The Strokes 1097
# All Time Low 1097
# Andy Stewart 1097
# Counting Crows 1097
# Creed 1097
# Dead Kennedys 1097
# Eazy-E 1097
# EVE 6 1097
# Fountains of Wayne 1097
# Green Day 1097
# Guttermouth 1097
# Hundred Reasons 1097
# James Morrison 1097
# Jimmy Eat World 1097
# Lenny Kravitz 1097
# Lynyrd Skynyrd 1097
# Me First and the Gimme Gimmes 1097
# Muse 1097
# My Chemical Romance 1097
# Naughty By Nature 1097
# No Doubt 1097
# Porter Robinson 1097
# Puddle of Mudd 1097
# Queen 1097
# Queens of the Stone Age 1097
# Richard Cheese 1097
# Scatman John 1097
# Semisonic 1097
# Smash Mouth 1097
# Soundgarden 1097
# Stereophonics 1097
# The Chemical Brothers 1097
# The Cranberries 1097
# The Cure 1097
# The Killers 1097
# The Mighty Mighty Bosstones 1097
# The Notorious B.I.G. 1097
# The Struts 1097
# Third Eye Blind 1097
# Vertical Horizon 1097
# Yellowcard 1097
# Less Than Jake 1098
# Green Day 1098
# Jack Black 1098
# Aqua 1098
# The Offspring 1098
# Five 1098
# Reel Big Fish 1098
# Bowling for Soup 1098
# Fall Out Boy 1098
# Pat Benatar 1098
# Counting Crows 1098
# Flevans 1098
# McFly 1098
# Against Me! 1098
# Alien Ant Farm 1098
# Andrew Lloyd Webber 1098
# blink-182 1098
# Blur 1098
# Brooklyn Funk Essentials 1098
# Goldfinger 1098
# Good Charlotte 1098
# Halestorm 1098
# Ice Nine Kills 1098
# Kate Nash 1098
# Krewella 1098
# Lou Bega 1098
# My Chemical Romance 1098
# Rancid 1098
# Simple Plan 1098
# The All-American Rejects 1098
# The Feeling 1098
# The Fratellis 1098
# The Kooks 1098
# Third Eye Blind 1098
# Yellowcard 1098
# Zebrahead 1098
# The Goo Goo Dolls 1099
# Fleetwood Mac 1099
# 3 Doors Down 1099
# Jack Black 1099
# Five 1099
# Pink Floyd 1099
# Arctic Monkeys 1099
# blink-182 1099
# Crazy Frog 1099
# Green Day 1099
# Kaleo 1099
# Linkin Park 1099
# Måneskin 1099
# Neal Hefti & his Orchestra and Chorus 1099
# The Chemical Brothers 1099
# The Mighty Mighty Bosstones 1099
# The Offspring 1099
# Third Eye Blind 1099
# TV Themes 1099
# Wheatus 1099
# Green Day 1100
# The Goo Goo Dolls 1100
# Five 1100
# Jack Black 1100
# The Chemical Brothers 1100
# Luke Bryan 1100
# One Project 1100
# The Offspring 1100
# 3 Doors Down 1101
# The Goo Goo Dolls 1101
# Third Eye Blind 1101
# Jack Black 1101
# Five 1101
# Fleetwood Mac 1101
# Good Charlotte 1101
# The All-American Rejects 1101
# Alien Ant Farm 1101
# All Time Low 1101
# blink-182 1101
# Fall Out Boy 1101
# Lit 1101
# Luke Bryan 1101
# Lustra 1101
# Paramore 1101
# The Clash 1101
# The Offspring 1101
# Yellowcard 1101
# 3 Doors Down 1102
# Flevans 1102
# Jack Black 1102
# Kloom Jay 1102
# David Landau 1102
# Lou Bega 1102
# Crazy Frog 1102
# Third Eye Blind 1102
# Five 1103
# Crazy Frog 1103
# David Landau 1103
# Foo Fighters 1103
# Halestorm 1103
# Iron Maiden 1103
# Jack Black 1103
# Kiss 1103
# Nirvana 1103
# Sublime 1103
# System of a Down 1103
# [spunge] 1103
# Albo's Music Room 1103
# Alien Ant Farm 1103
# Crazy Town 1103
# Creedence Clearwater Revival 1103
# Def Leppard 1103
# Guano Apes 1103
# Heart 1103
# Joan Jett & The Blackhearts 1103
# Linkin Park 1103
# Megadeth 1103
# Miles Davis 1103
# Mötley Crüe 1103
# Pat Benatar 1103
# Queen 1103
# Reel 2 Real 1103
# Scorpions 1103
# Slayer 1103
# The Clash 1103
# The Darkness 1103
# The Dave Brubeck Quartet 1103
# The White Stripes 1103
# Fleetwood Mac 1104
# Glen Campbell 1104
# Pink Floyd 1104
# McFly 1104
# AC/DC 1104
# Black Sabbath 1104
# Creedence Clearwater Revival 1104
# David Bowie 1104
# Eagles 1104
# Nirvana 1104
# Prince 1104
# Radiohead 1104
# Roxette 1104
# The Animals 1104
# The Rolling Stones 1104
# The White Stripes 1104
# The Who 1104
# Roxette 1105
# Goldfinger 1105
# The Offspring 1105
# Jack Black 1105
# Nena 1105
# Alanis Morissette 1105
# Santana 1105
# 4 Non Blondes 1105
# Blues Traveler 1105
# Chumbawamba 1105
# Depeche Mode 1105
# Nirvana 1105
# Supergrass 1105
# The Cardigans 1105
# The Cranberries 1105
# Wheatus 1105
# Rage Against the Machine 1106
# Jack Black 1106
# Belinda Carlisle 1106
# Roxette 1106
# Queen 1106
# Nightwish 1106
# Sum 41 1106
# Halestorm 1106
# The Gaslight Anthem 1106
# Avenged Sevenfold 1106
# BENEE 1106
# Blacktop Mojo 1106
# Dayglow 1106
# Dirty Honey 1106
# Fall Out Boy 1106
# Fleetwood Mac 1106
# Iron Maiden 1106
# Jamieson Shaw 1106
# Kenny G 1106
# Kumi Tanioka 1106
# La Roux 1106
# Led Zeppelin 1106
# Linkin Park 1106
# Neil Diamond 1106
# Panjabi MC 1106
# Pink Floyd 1106
# Snap! 1106
# Sublime 1106
# System of a Down 1106
# Lene Marlin 1107
# The Clash 1107
# Jack Black 1107
# Roxette 1107
# Crazy Frog 1107
# TV Themes 1107
# BENEE 1107
# The Beatles 1107
# Aqua 1107
# Dirty Honey 1107
# Paul Russell 1107
# Belinda Carlisle 1107
# C418 1107
# Dayglow 1107
# Goldfinger 1107
# Jamieson Shaw 1107
# Madonna 1107
# The B-52's 1107
# The Chemical Brothers 1107

# %%
#BLOCK 1.3 - Find + Track Genres
#Time was a product of Claude, my code kept on stopping due to too many requests, so I asked how I could get around my API's limit and
#using a sleep was the suggestion and it thankfully worked
import urllib.parse as up
import time

#here I make a dictionary so that if an artist is already in the dictionary it skips the loop and passes onto the next artist.
#for the new artists, it looks up the top tag and puts it as the value in the dictionary with the name of the artist as the key
#sickdict #shows me the dictionary at the end of everything, again i disabled it and put it up here so you know its there but doesn't
#run and doesnt look bad.

sickdict={} 
#makes the empty dictionary for my artists to hide out in 
counter=0 
# starts the counter at 0
for item in listylist: 
#goes through each of the items(artists) in my listylist (Master list of every artist listened to)
    itemencode = up.quote(item) 
    #pencode encodes the name to combat the problem discussed above. (encoding strange characters)
    if item not in sickdict: 
        #checking to see if the artist we found is in the dictionary above, if yes skip to the else condition
        toptagsreq=requests.get(f'{url}?method=artist.gettoptags&artist={itemencode}&api_key={YOUR_API_KEY}&format=json')
        # gets the top tag for an artist specified in the F STRING {itemencode} blob
        toptagget=toptagsreq.json() 
        #here both toptagget and toptagsreq get reassigned from before (This is what I meant before)
        tags = toptagget['toptags']['tag'] 
        #gets all of the tags for a given artist {itemencode} blob above
        tag = tags[0]['name'] if len(tags) > 0 else 'unknown' 
        # returns the top tag for the artist, returns unknown if no tags exist
        sickdict[item]= tag 
        # puts item in the dictionary as a key, with the tag variable as the value
        print(item,tag,counter) # Print statement again, just disabling this line so that you know it's there but it doesnt run
    else: 
        pass
    #these lines make it so that i'm just moving on in the case that item is already in the dictionary, doesnt waste time
    counter+=1 
    #advances the counter by 1 to move onto the next artist.
    time.sleep(0.3) 
    #AI SUGGESTION, this is just so that the API doesn't take too many requests and give me a JSONDecodeError,
# Out:
# Aerosmith hard rock 0
# Metallica metallica 1
# Miles Davis jazz 2
# Guns N' Roses hard rock 3
# Dream Theater Progressive metal 4
# R.E.M. rock 5
# Radiohead rock 6
# Moby electronic 7
# Joe Satriani guitar virtuoso 8
# Led Zeppelin classic rock 9
# Counting Crows rock 10
# Free classic rock 11
# Red Hot Chili Peppers rock 12
# Jimi Hendrix classic rock 13
# Badly Drawn Boy indie 14
# The Rolling Stones classic rock 15
# Portishead trip-hop 16
# Matchbox Twenty rock 17
# Jamiroquai funk 18
# The Beatles classic rock 19
# Goo Goo Dolls rock 20
# Ben Folds Five piano rock 21
# Dido pop 22
# Eels indie 23
# Stevie Wonder soul 24
# The Jimi Hendrix Experience Psychedelic Rock 25
# David Bowie glam rock 26
# Dire Straits classic rock 27
# Rage Against the Machine alternative rock 28
# A Perfect Circle alternative rock 29
# Dan Reed Network rock 30
# Beck alternative 31
# Nine Inch Nails industrial 32
# Ben Harper singer-songwriter 33
# Fun Lovin' Criminals funk 34
# Barenaked Ladies rock 35
# Jeff Buckley singer-songwriter 36
# Norah Jones jazz 37
# Buckcherry hard rock 38
# Foo Fighters rock 39
# King's X Progressive rock 40
# The Doors classic rock 41
# The Police rock 42
# Queen classic rock 43
# (hed) Planet Earth rapcore 44
# The Cure post-punk 45
# U2 rock 46
# Bruce Springsteen rock 47
# Nirvana Grunge 48
# The Smashing Pumpkins alternative rock 49
# Pink Floyd Progressive rock 50
# Coldplay rock 51
# Herbie Hancock jazz 52
# The Classic Chill Out Album unknown 53
# Air electronic 54
# Lenny Kravitz rock 55
# The Velvet Underground psychedelic 56
# Beth Orton female vocalists 57
# Judas Priest heavy metal 58
# Tom Waits blues 59
# Deep Purple hard rock 60
# Desert Sessions Stoner Rock 61
# Pearl Jam Grunge 62
# Weezer alternative rock 63
# Rammstein industrial metal 64
# Neil Young classic rock 65
# Def Leppard hard rock 66
# Fugees Hip-Hop 67
# Nickelback rock 68
# Pink pop 69
# Massive Attack trip-hop 70
# Various Artists unknown 71
# The Kleptones mashup 72
# Feeder rock 73
# Linkin Park Nu Metal 74
# Blur britpop 75
# Muse alternative rock 76
# Nick Cave and the Bad Seeds post-punk 77
# Frank Sinatra jazz 78
# Van Morrison singer-songwriter 79
# Sonic Youth experimental 80
# James Taylor folk 81
# No Doubt rock 82
# Diana Krall jazz 83
# Level 42 80s 84
# Mr. Big hard rock 85
# Everclear alternative rock 86
# Frankie Goes to Hollywood new wave 87
# Bob Marley reggae 88
# Santana rock 89
# The White Stripes rock 90
# Bob Dylan folk 91
# Jools Holland piano 92
# PJ Harvey female vocalists 93
# Audioslave alternative rock 94
# Creed rock 95
# Dave Weckl jazz 96
# Nina Simone jazz 97
# Stereolab electronic 98
# 3 Doors Down alternative rock 99
# Chet Baker jazz 100
# Dizzy Gillespie bebop 101
# George Michael pop 102
# Marcus Miller jazz 103
# Pixies alternative rock 104
# Bob Seger classic rock 105
# Disturbed Nu Metal 106
# Electric Wizard doom metal 107
# Elvis Presley rock n roll 108
# Eric Clapton blues 109
# Weather Report jazz 110
# Faith No More alternative rock 111
# Fleetwood Mac classic rock 112
# Roachford soul 113
# System of a Down alternative metal 114
# A alternative rock 115
# Quincy Jones jazz 116
# Ella Fitzgerald jazz 117
# John Mayer singer-songwriter 118
# Morcheeba trip-hop 119
# James Brown funk 120
# Ash britpop 121
# Nick Drake folk 122
# Zero 7 chillout 123
# Beastie Boys Hip-Hop 124
# Black Sabbath heavy metal 125
# Lou Reed rock 126
# Michael Jackson pop 127
# Oleander alternative rock 128
# Talking Heads new wave 129
# [unknown] unknown 130
# John Coltrane jazz 131
# Simon & Garfunkel folk 132
# Cutting Crew 80s 133
# Depeche Mode electronic 134
# Madonna pop 135
# Neal Morse Progressive rock 136
# Pantera thrash metal 137
# Alanis Morissette female vocalists 138
# Pavement indie rock 139
# Soundgarden Grunge 140
# The Wallflowers rock 141
# De La Soul Hip-Hop 142
# The Divine Comedy indie 143
# Boards of Canada ambient 144
# David Lee Roth hard rock 145
# John Patitucci jazz 146
# Meat Loaf rock 147
# Cream classic rock 148
# Tindersticks chamber pop 149
# Collective Soul alternative rock 150
# One Minute Silence Nu Metal 151
# Crash Test Dummies rock 152
# Elvis Costello new wave 153
# Incubus alternative rock 154
# Kraftwerk electronic 155
# Liquid Tension Experiment Progressive metal 156
# Placebo alternative rock 157
# Yngwie Malmsteen heavy metal 158
# B.B. King & Eric Clapton blues 159
# Bryan Adams rock 160
# Eagles classic rock 161
# Firebird blues rock 162
# Lynyrd Skynyrd Southern Rock 163
# The Beta Band indie 164
# The Who classic rock 165
# Alice Cooper hard rock 166
# Autechre idm 167
# Bon Jovi rock 168
# Brian Eno ambient 169
# Phil Collins Big Band jazz 170
# The Verve britpop 171
# Tower of Power funk 172
# Yo La Tengo indie rock 173
# Curtis Mayfield soul 174
# Peter Gabriel Progressive rock 175
# Steve Vai guitar virtuoso 176
# Chick Corea jazz 177
# EVE 6 alternative rock 178
# Garbage rock 179
# Natalie Merchant female vocalists 180
# AC/DC hard rock 181
# Aretha Franklin soul 182
# Billie Holiday jazz 183
# Django Reinhardt jazz 184
# my bloody valentine shoegaze 185
# Oasis britpop 186
# Sting rock 187
# Best Jazz Ever unknown 188
# Bruce Dickinson heavy metal 189
# Enuff Z'Nuff hard rock 190
# Iggy Pop punk 191
# Madness ska 192
# The Byrds classic rock 193
# The Clash punk 194
# Derek & Clive comedy 195
# Spiritualized space rock 196
# Whitesnake hard rock 197
# Eva Cassidy jazz 198
# Johann Sebastian Bach Classical 199
# Steppenwolf classic rock 200
# Supreme Beings of Leisure trip-hop 201
# Suzie Higgie unknown 202
# The Stone Roses britpop 203
# Thievery Corporation chillout 204
# Tracy Chapman female vocalists 205
# Anastacia pop 206
# Aphex Twin electronic 207
# Leonard Cohen folk 208
# The Jon Spencer Blues Explosion blues rock 209
# The Stranglers new wave 210
# Brant Bjork Stoner Rock 211
# Prince funk 212
# Sublime ska 213
# Tok Tok Tok jazz 214
# Dr. John blues 215
# Gorillaz electronic 216
# Hootie & The Blowfish rock 217
# Joni Mitchell & James Taylor folk 218
# Jurassic 5 Hip-Hop 219
# Staind alternative rock 220
# Tenacious D rock 221
# The Battle of Los Angeles unknown 222
# The Fall post-punk 223
# The James Taylor Quartet rock 224
# Travis britpop 225
# Ani DiFranco folk 226
# Björk electronic 227
# DumDums Need to Rate 228
# Kid Rock rock 229
# Marilyn Manson industrial 230
# Suzanne Vega female vocalists 231
# The Cranberries rock 232
# Belle and Sebastian indie 233
# Elliott Smith singer-songwriter 234
# Eminem rap 235
# Fiona Apple female vocalists 236
# Moloko trip-hop 237
# Natalie Imbruglia pop 238
# Sigur Rós post-rock 239
# Steve Miller Band classic rock 240
# The Future Sound of London ambient 241
# Buena Vista Social Club latin 242
# David Hudson and Friends world 243
# DJ Krush trip-hop 244
# Doves indie 245
# Eurythmics new wave 246
# Live alternative rock 247
# Serge Gainsbourg french 248
# The Hollies 60s 249
# Kings of Leon rock 253
# Blind Guardian Power metal 261
# Charles Mingus jazz 262
# Fear Factory industrial metal 270
# Iron Maiden heavy metal 273
# Jaco Pastorius jazz 274
# Joy Division post-punk 276
# Megadeth thrash metal 278
# Pain of Salvation Progressive metal 279
# Queensrÿche Progressive metal 280
# Shaman folk metal 282
# Silverchair Grunge 283
# Slayer thrash metal 284
# Smith classic rock 285
# The Electric Prunes Psychedelic Rock 287
# The Quantic Soul Orchestra funk 289
# Crusaders jazz 301
# Grassroots unknown 302
# The Delfonics soul 303
# Grandmaster Flash and The Furious Five Hip-Hop 305
# Run-D.M.C. Hip-Hop 306
# Starsailor britpop 309
# Keane britpop 312
# Backyard Babies hard rock 319
# David Gray singer-songwriter 321
# dEUS alternative 322
# Echo & the Bunnymen post-punk 323
# Enigma new age 326
# HammerFall Power metal 327
# Kula Shaker britpop 328
# Primal Scream rock 331
# Kyuss Stoner Rock 338
# Tito & Tarantula rock 341
# Dave Matthews Band rock 345
# Uncle Seth Canadian 351
# Alice in Chains Grunge 352
# Creedence Clearwater Revival classic rock 355
# Daft Punk electronic 356
# ABBA pop 362
# AFI punk rock 363
# Big Brother & The Holding Company Psychedelic Rock 366
# Black Rebel Motorcycle Club rock 367
# Cake alternative 371
# Christina Aguilera pop 372
# Crazy Town rapcore 373
# Electric Six rock 377
# Halo Sludge 383
# Hawkwind space rock 384
# Ivy indie 387
# John Vanderslice indie 388
# Levellers folk rock 391
# Limp Bizkit Nu Metal 392
# Marillion Progressive rock 395
# My Chemical Romance rock 398
# New Order new wave 399
# Queens of the Stone Age Stoner Rock 403
# Roxy Music glam rock 405
# Sash! dance 407
# Skindred reggae metal 408
# Skunk Anansie rock 409
# Soulfly thrash metal 411
# Tabu Ley congo 413
# The Cars new wave 415
# The Small Faces 60s 417
# The Vines rock 418
# The Zutons indie 419
# Yellowcard pop punk 420
# Yes Progressive rock 421
# Grandaddy indie rock 424
# Sunny Day Real Estate emo 425
# Billy Joel classic rock 427
# Cat Power indie 428
# Faust krautrock 430
# Gallon Drunk Garage Rock 431
# Gomez indie 432
# Piano Magic post-rock 433
# 36 Crazyfists metalcore 437
# Ben Christophers singer-songwriter 440
# Biz Markie Hip-Hop 441
# Bob Marley & The Wailers reggae 443
# Bobby Vinton oldies 444
# Bochum Welt idm 445
# Charles Trénet french 447
# David Broza israeli 449
# Deftones Nu Metal 451
# Dirty Three post-rock 453
# Enya new age 455
# Evanescence Gothic Rock 456
# Everything But the Girl trip-hop 457
# Failure space rock 458
# Fatboy Slim electronic 459
# Flim ambient 461
# Frankie Valli And The Four Seasons 60s 462
# Guided by Voices Lo-Fi 463
# Hatebreed hardcore 464
# HIM Love Metal 465
# Howlin` Maggie 90s 466
# Iced Earth Power metal 467
# Indigo Girls folk 468
# JC Chasez pop 470
# Jimmy Buffett singer-songwriter 471
# Kate Bush female vocalists 473
# Kylie Minogue pop 474
# Lene Marlin pop 475
# Lilys shoegaze 476
# Mercury Rev dream pop 479
# Michelle Branch pop 480
# Parliament funk 488
# Peace Orchestra downtempo 490
# Penguin Cafe Orchestra instrumental 491
# Pinback indie rock 492
# Rush Progressive rock 496
# Sex Pistols punk 497
# Shawn Colvin female vocalists 498
# Shawn Mullins singer-songwriter 499
# Something Corporate piano rock 500
# Steely Dan Jazz Rock 501
# Styrofoam indietronica 503
# Swollen Members Hip-Hop 504
# Teknotika 90s 506
# The Ataris pop punk 507
# The Darkness hard rock 508
# The Kinks classic rock 509
# The Magnetic Fields indie pop 510
# The Microphones Lo-Fi 511
# The Offspring punk rock 512
# The Shins indie 513
# Theatre of Tragedy Gothic Metal 515
# Therion symphonic metal 516
# Tori Amos female vocalists 517
# Trail of Tears Gothic Metal 518
# Unwritten Law punk rock 519
# Whiskeytown Alt-country 522
# Wilco Alt-country 523
# Yellowjackets jazz 524
# test artist 1 cigital2 530
# Albert Collins blues 532
# Avantasia Power metal 533
# Ayreon Progressive metal 534
# Betty Wright soul 536
# blink-182 punk rock 537
# Devin Townsend Progressive metal 539
# Elmore James blues 541
# Evergrey Progressive metal 543
# Guy Barker trumpet 544
# Guy Davis blues 545
# Jefferson Airplane Psychedelic Rock 546
# Joe Lynn Turner hard rock 547
# John Abercrombie jazz 549
# John Mayall blues 550
# Johnny Winter blues 551
# Junior Wells blues 552
# Kamelot Power metal 553
# Leo Kottke folk 554
# Louisiana Red blues 555
# Moskovskaya ska 557
# Nightwish symphonic metal 558
# Omara Portuondo cuban 559
# Robert Johnson blues 561
# Savatage heavy metal 563
# Savoy Brown blues rock 564
# Sonata Arctica Power metal 565
# Sue Foley blues 566
# Ten Years After blues rock 567
# The Last Poets spoken word 568
# Bloc Party indie 571
# Boston classic rock 574
# Crosby, Stills, Nash & Young classic rock 577
# Emerson, Lake & Palmer Progressive rock 579
# Firehouse hard rock 580
# Giant Sand Alt-country 581
# John Mellencamp rock 582
# Journey classic rock 583
# Kansas Progressive rock 584
# Palace indie 588
# Scorpions hard rock 591
# Spoon indie rock 592
# Stevie Ray Vaughan blues 593
# The Angels of Light folk 594
# The Doobie Brothers classic rock 595
# Will Oldham singer-songwriter 596
# Rachael Yamagata female vocalists 598
# Otis Redding soul 600
# Van Halen hard rock 603
# Kingdom Come hard rock 605
# Paul McCartney & Wings classic rock 610
# Less Than Jake ska punk 615
# Nigel Kennedy Classical 616
# Reel Big Fish ska 617
# Semisonic alternative rock 618
# Snow Patrol indie 619
# The Presidents of the United States of America alternative rock 621
# Thunder hard rock 623
# WANDS J-rock 624
# Abdullah Ibrahim jazz 630
# Alice Coltrane jazz 632
# Anouk rock 634
# Art Pepper jazz 635
# Carla Bley jazz 640
# Charlie Parker jazz 642
# Descendents punk 644
# Eric Dolphy jazz 648
# Erik Truffaz jazz 649
# Franz Ferdinand indie rock 651
# Freddie Hubbard jazz 652
# Green Day punk rock 656
# Jack Johnson acoustic 657
# Jimmy Eat World alternative rock 658
# Madeleine Peyroux jazz 660
# Madlib Hip-Hop 661
# Ooberman liverpool 666
# Paul Motian jazz 667
# Richie Sambora rock 674
# Robbie Williams pop 675
# Supertramp Progressive rock 677
# The Allman Brothers Band Southern Rock 680
# The Killers indie 683
# The Pogues folk 684
# The Strokes indie rock 685
# The Tragically Hip Canadian 686
# Tony Williams jazz 688
# Ben Kweller indie 691
# Bush Grunge 698
# Stone Temple Pilots Grunge 716
# The Flaming Lips alternative 719
# Tool Progressive metal 722
# Zwan alternative rock 724
# Calexico Alt-country 733
# Ministry industrial metal 743
# Peaches Electroclash 745
# Robert Miles trance 752
# The Wildhearts hard rock 756
# Tom Lehrer comedy 759
# Monty Python comedy 773
# Alien Sex Fiend deathrock 776
# American Head Charge Nu Metal 777
# Derek and the Dominos blues rock 784
# Johnny Carroll rockabilly 788
# Pat Metheny jazz 789
# Sleeper britpop 791
# Stiphane Pompouganc chillout 792
# Suede britpop 793
# Marty Robbins country 808
# Jason Rebello jazz 810
# No-Neck Blues Band experimental 811
# Ry Cooder blues 812
# Ry Cooder & Manuel Galbán latin 813
# Ace of Base pop 814
# Barbra Streisand female vocalists 815
# Black Eyed Peas Hip-Hop 816
# Charlie Musselwhite blues 817
# Dave Grusin jazz 818
# Garth Brooks country 819
# Gillian Welch Alt-country 820
# John Lee Hooker blues 821
# John Mayall & The Bluesbreakers blues 822
# Louis Jordan jazz 823
# Loyko Gypsy 824
# Maroon 5 pop rock 825
# Muddy Waters blues 827
# Ralph Towner jazz 829
# Rickie Lee Jones female vocalists 831
# Sarah Brightman female vocalists 832
# T-Bone Walker blues 833
# Taj Mahal blues 834
# Texas pop 835
# The Calling rock 836
# TIm Kearns All 837
# Wu-Tang Clan Hip-Hop 841
# Ozzy Osbourne heavy metal 846
# Joe Cocker classic rock 854
# Lauryn Hill soul 855
# Mogwai post-rock 859
# Phil Collins pop 862
# Andre Gurov turntablism 872
# Dexter Gordon jazz 875
# Duke Ellington jazz 876
# Sonny Rollins jazz 883
# Wayne Shorter jazz 886
# Combustible Edison lounge 896
# Dusty Springfield soul 901
# Glen Campbell country 905
# Jon Brion Soundtrack 907
# Keith Jarrett jazz 908
# KMFDM industrial 909
# Lalo Schifrin jazz 910
# Medeski, Martin and Wood jazz 915
# Oscar Peterson jazz 917
# Sly & The Family Stone funk 922
# The Beach Boys classic rock 925
# The Waterboys folk rock 929
# Alicia de Larrocha Classical 933
# Avril Lavigne pop rock 934
# Fatso Jetson Stoner Rock 946
# Five for Fighting alternative 947
# Frou Frou electronic 950
# Fuel alternative rock 951
# Gary Moore blues rock 952
# Hamilton, Tom / Thomas Buckner unknown 954
# Hutch Demouilpied jazz 955
# Jason Moran jazz 958
# Kiss hard rock 959
# Maceo Parker funk 962
# Mark Lanegan singer-songwriter 963
# Mississippi Jook Band jug band 966
# Nancy Sinatra & Lee Hazlewood 60s 968
# Aina Power metal 979
# Cab Calloway jazz 988
# Hoobastank alternative rock 990
# Prefuse 73 electronic 992
# Adam Green singer-songwriter 994
# Aesop Rock Hip-Hop 995
# Allison Crowe female vocalists 996
# Anouar Brahem jazz 998
# Bill Evans jazz 1000
# Black Moon Hip-Hop 1002
# Blind Melon Grunge 1003
# Bloodhound Gang alternative rock 1004
# Broken Social Scene indie rock 1006
# Buddy Holly rockabilly 1007
# Built to Spill indie rock 1008
# Coolio rap 1010
# Cyne Hip-Hop 1012
# Dispatch indie 1014
# Duran Duran new wave 1016
# Erykah Badu soul 1019
# Esbjörn Svensson Trio jazz 1020
# Four Tet electronic 1022
# Frank Zappa Progressive rock 1023
# Fu Manchu Stoner Rock 1024
# Gang Starr Hip-Hop 1026
# Hella math rock 1029
# Henry Mancini jazz 1030
# Janet Jackson pop 1031
# Joanna Newsom folk 1032
# John Pizzarelli jazz 1033
# Johnny Cash country 1034
# Les Savy Fav post-punk 1035
# Lucinda Williams singer-songwriter 1036
# M. Ward folk 1037
# Mariah Carey pop 1038
# Melvins Sludge 1040
# Modern Jazz Quartet jazz 1042
# Neil Finn New Zealand 1043
# Pete Yorn singer-songwriter 1047
# Plug Drum and bass 1049
# Richard Galliano jazz 1053
# Shellac noise rock 1056
# Slipknot Nu Metal 1057
# Soil Nu Metal 1058
# Stan Getz & Charlie Byrd jazz 1060
# Stephen Malkmus indie rock 1061
# The Blood Brothers post-hardcore 1064
# The Go-Go's new wave 1066
# The Prodigy electronic 1068
# Thee Michelle Gun Elephant Garage Rock 1071
# Uncle Tupelo Alt-country 1073
# Ween experimental 1074
# Zoot Woman electronic 1076
# ZZ Top blues rock 1084
# Amon Tobin electronic 1118
# Amorphis Progressive metal 1119
# Atmosphere Hip-Hop 1121
# Babyshambles british 1122
# Bad Religion punk rock 1123
# Belinda Carlisle pop 1126
# Ben Lee singer-songwriter 1128
# Big Punisher Hip-Hop 1130
# Blondie new wave 1134
# Brand New emo 1136
# Brian May rock 1137
# Charlie Feathers rockabilly 1140
# Children of Bodom Melodic Death Metal 1141
# Cocteau Twins dream pop 1142
# Crowded House rock 1143
# Cypress Hill Hip-Hop 1144
# David Byrne new wave 1146
# Dead Kennedys punk 1147
# Die Fantastischen Vier german 1150
# Electric Light Orchestra classic rock 1155
# Embrace emo 1158
# Finch post-hardcore 1160
# Front 242 ebm 1163
# Funeral For A Friend post-hardcore 1164
# Gary Jules singer-songwriter 1166
# Ill Niño Nu Metal 1171
# In Flames Melodic Death Metal 1172
# Janis Ian folk 1176
# Josie and the Pussycats pop 1179
# K's Choice rock 1181
# King Tubby's Meets Scientist dub 1183
# Lostprophets alternative rock 1190
# Marcy Playground alternative rock 1193
# Marvin Gaye soul 1194
# Mr. Bungle experimental 1198
# My Vitriol alternative rock 1201
# N*E*R*D Hip-Hop 1202
# Our Lady Peace alternative rock 1207
# P.O.D. Nu Metal 1208
# Patti LaBelle soul 1210
# Prince & The Revolution funk 1213
# Rainbow hard rock 1215
# Ray Charles jazz 1216
# Rooney indie 1219
# Sade soul 1220
# Sarah McLachlan female vocalists 1221
# Seven Channels hard rock 1222
# Shirley Bassey jazz 1223
# Soilwork Melodic Death Metal 1226
# Squeeze new wave 1230
# Squirrel Nut Zippers swing 1231
# Stealers Wheel classic rock 1233
# Supergrass britpop 1236
# The All-American Rejects rock 1238
# The Cardigans pop 1241
# The Chemical Brothers electronic 1242
# The Cinematic Orchestra jazz 1243
# The Crystal Method electronic 1244
# The Futureheads indie rock 1245
# The Jam punk 1246
# The La's britpop 1248
# The Proclaimers Scottish 1249
# The Streets Hip-Hop 1251
# Tortoise post-rock 1256
# Transvision Vamp rock 1257
# Tristania Gothic Metal 1258
# Velvet Revolver hard rock 1260
# Jason Mraz acoustic 1263
# Apocalyptica symphonic metal 1264
# Arch Enemy Melodic Death Metal 1265
# DragonForce Power metal 1270
# Dubadelic dub 1271
# Hoof trance 1277
# Sheryl Crow female vocalists 1286
# Stone Sour hard rock 1288
# The Smiths post-punk 1290
# Thin Lizzy hard rock 1292
# 4 Non Blondes rock 1297
# Alabama 3 alternative 1301
# Alien Ant Farm alternative rock 1303
# Alter Bridge alternative rock 1305
# Bad Company classic rock 1309
# Bonnie Tyler pop 1320
# Clannad celtic 1327
# Coal Chamber Nu Metal 1328
# Crosby, Stills & Nash folk rock 1333
# Dave Matthews & Tim Reynolds acoustic 1334
# David Axelrod jazz 1336
# Days of the New Grunge 1339
# De-Phazz lounge 1340
# Deborah Harry new wave 1341
# Default alternative rock 1343
# Do Make Say Think post-rock 1351
# Eddie Cochran rockabilly 1353
# Electronic electronic 1355
# Foreigner classic rock 1363
# Frank Sinatra & Tommy Dorsey jazz 1364
# Goldfinger punk rock 1369
# Hugh Masekela jazz 1374
# Immortal black metal 1376
# Jamie Cullum jazz 1379
# Jane's Addiction alternative rock 1380
# Jethro Tull Progressive rock 1382
# Jewel female vocalists 1383
# Joe Zawinul jazz 1386
# Lee Morgan jazz 1389
# Leftfield electronic 1390
# Len pop 1391
# Les Nubians soul 1392
# Living Colour hard rock 1396
# Liz Phair female vocalists 1397
# Love Sculpture blues rock 1398
# Madvillain Hip-Hop 1401
# Manowar heavy metal 1402
# Mezzoforte jazz 1410
# Mono post-rock 1413
# Mountain hard rock 1414
# Naglfar black metal 1416
# Pedestrian anticon 1422
# Pelding denmark 1423
# Primus funk metal 1428
# Rancid punk 1433
# Ratt hard rock 1434
# Rob Zombie industrial metal 1437
# Robert Plant classic rock 1439
# Rufus Wainwright singer-songwriter 1441
# Santa Esmeralda Disco 1442
# Sloan Canadian 1448
# Steve Earle country 1451
# Stina Nordenstam female vocalists 1452
# Stray Cats rockabilly 1453
# Styx classic rock 1454
# Sum 41 punk rock 1455
# T. Rex glam rock 1458
# The Donnas rock 1467
# The Hives Garage Rock 1469
# The Surfaris Surf 1475
# The Undertones punk 1476
# The Ventures Surf 1477
# The Yardbirds classic rock 1479
# Toots and The Maytals reggae 1480
# Vanessa Carlton pop 1483
# Al Jarreau jazz 1491
# At the Drive-In post-hardcore 1493
# Beatsteaks punk rock 1495
# Biffy Clyro alternative rock 1497
# Black Candy Garage Rock 1498
# Butthole Surfers noise rock 1503
# Cris Clarity All 1509
# Groundhogs blues rock 1531
# Hans Zimmer Soundtrack 1533
# Helloween Power metal 1534
# Jellyfish power pop 1537
# Jim Brown reggae 1538
# Lacuna Coil Gothic Metal 1543
# Lord Rockingham's XI 50s 1545
# Loverboy rock 1546
# Mick Harvey singer-songwriter 1553
# Mike & The Mechanics 80s 1554
# Mötley Crüe hard rock 1557
# OutKast Hip-Hop 1565
# Paul Hardcastle Smooth Jazz 1566
# Paul Weller rock 1567
# Sean Paul dancehall 1578
# Steve Oliver Smooth Jazz 1583
# The J. Geils Band classic rock 1593
# The Kingsmen Garage Rock 1594
# The Mighty Mighty Bosstones ska 1595
# The Ronettes 60s 1597
# Third Man techno 1600
# Cannonball Adderley jazz 1612
# Donald Byrd jazz 1617
# Fred Astaire jazz 1619
# George Shearing jazz 1621
# Hank Mobley jazz 1625
# Ike Quebec jazz 1626
# Joe Strummer punk 1628
# Kenny Burrell jazz 1629
# Kevin Devine singer-songwriter 1630
# Last Days of April emo 1631
# Mirah female vocalists 1635
# Mr. Airplane Man Garage Rock 1636
# Ramones punk 1638
# Silver Jews Lo-Fi 1639
# Stanley Turrentine jazz 1641
# The Horace Silver Quintet jazz 1642
# The Thrills indie 1645
# Wes Montgomery jazz 1649
# Fireworks Night folk 1665
# The Blues Brothers blues 1673
# The Mules indie 1675
# Aimee Mann female vocalists 1678
# Christian Kleine idm 1690
# Dutch Swing College Band jazz 1699
# Elbow indie 1700
# Fugazi post-hardcore 1706
# Grant Green jazz 1709
# Guster indie 1710
# Horace Silver jazz 1712
# Hot Boogie Chillun psychobilly 1713
# I-F electro 1714
# John Martyn folk 1717
# King Pin melodic hardcore 1720
# Michael Nyman piano 1728
# NOFX punk rock 1733
# Porcupine Tree Progressive rock 1737
# Primitive Radio Gods alternative 1738
# Roger McGuinn folk rock 1740
# Sofa Surfers trip-hop 1742
# Sparklehorse indie 1745
# Stabbing Westward industrial rock 1746
# Steve Reich minimalism 1748
# Talvin Singh electronic 1751
# The 69 Eyes Gothic Rock 1752
# The Dave Brubeck Quartet jazz 1755
# The Pastels indie pop 1758
# Thelonious Monk jazz 1764
# Turbonegro death punk 1768
# Ugly Casanova indie 1769
# Vangelis electronic 1770
# Warren Zevon singer-songwriter 1771
# Spock's Beard Progressive rock 1778
# Stanley Jordan jazz 1779
# Kasey Chambers country 1780
# Godspeed You! Black Emperor post-rock 1788
# múm electronic 1796
# Sufjan Stevens folk 1798
# The Album Leaf post-rock 1799
# The Postal Service indie 1801
# All punk rock 1818
# Avenged Sevenfold metalcore 1820
# Big Band Big Band 1824
# Brenda Lee oldies 1826
# Cheeseburger Garage Rock 1827
# Chingy Hip-Hop 1829
# Control Machete Hip-Hop 1831
# Damien Jurado folk 1833
# Dark Tranquillity Melodic Death Metal 1834
# Death death metal 1836
# Deru idm 1837
# DJ Shadow trip-hop 1839
# Enanitos Verdes Rock en Espanol 1843
# Iron & Wine folk 1855
# Lali Puna electronic 1861
# Lovage trip-hop 1864
# Manic Street Preachers rock 1865
# McCoy Tyner jazz 1866
# Mr. Scruff electronic 1868
# Nitin Sawhney chillout 1871
# Ocean Colour Scene britpop 1873
# Pete Townshend classic rock 1877
# Procol Harum Progressive rock 1879
# Ranma anime 1883
# RJD2 Hip-Hop 1884
# Sneaker Pimps trip-hop 1886
# Sugarcult punk rock 1887
# The Libertines indie rock 1893
# The Men of Porn Stoner Rock 1894
# The Moody Blues Progressive rock 1895
# The Roots Hip-Hop 1896
# The Shamen electronic 1897
# The Verve Pipe alternative rock 1900
# Thyrfing viking metal 1902
# Nat King Cole jazz 1911
# Miles Davis & Marcus Miller jazz 1913
# Miles Davis and John Lee Hooker blues 1914
# ...And You Will Know Us by the Trail of Dead indie rock 1924
# Auf der Maur alternative rock 1929
# AZ Hip-Hop 1930
# Beth Gibbons trip-hop 1933
# Caetano Veloso mpb 1936
# Chris Barber Jazz & Blues Band dixieland 1938
# Coheed and Cambria Progressive rock 1939
# Damien Rice singer-songwriter 1943
# Das Pop belgian 1944
# Dashboard Confessional indie 1945
# Death Cab for Cutie indie 1947
# Don Henley classic rock 1949
# Earl Hines jazz 1950
# Gene britpop 1956
# Guns On The Roof punk 1961
# Hole Grunge 1962
# John Petrucci & Jordan Rudess Progressive rock 1966
# King Crimson Progressive rock 1967
# Les Soloistes De L'Opera National De Lyon unknown 1970
# Louis Armstrong jazz 1971
# Mark Knopfler rock 1972
# Mercy Machine unknown 1974
# Monster Magnet Stoner Rock 1976
# Nancy Sinatra 60s 1977
# Phoenix indie 1983
# Red Snapper trip-hop 1986
# Remy Zero alternative rock 1987
# Seelenluft electronic 1989
# Stereophonics rock 1991
# The Arcade Fire indie rock 1992
# The KLF electronic 1997
# The Pretenders rock 1999
# Eric Truffaz jazz 2026
# Musical Youth reggae 2029
# Beautiful Creatures hard rock 2040
# Better Than Ezra alternative rock 2044
# Blues Traveler blues rock 2045
# Candlebox Grunge 2050
# Chris Cornell Grunge 2051
# Cinderella hard rock 2052
# Filter alternative rock 2066
# Hundred Reasons post-hardcore 2074
# Janis Joplin blues 2077
# Lit alternative rock 2083
# Marianne Faithfull female vocalists 2086
# MDFMK industrial 2087
# Neil Diamond singer-songwriter 2093
# Neutral Milk Hotel folk 2095
# Pat Benatar rock 2101
# Saliva hard rock 2110
# Scritti Politti new wave 2111
# Seven Mary Three alternative rock 2112
# Skid Row hard rock 2114
# Soul Asylum alternative rock 2115
# Span hard rock 2117
# Spin Doctors rock 2118
# Testament thrash metal 2125
# The Black Crowes Southern Rock 2127
# The Hypnomen psychedelic 2130
# The Polyphonic Spree indie 2134
# Tomahawk experimental 2139
# Warrant hard rock 2142
# Woody Shaw jazz 2145
# Team America: World Police Soundtrack 2148
# Opeth Progressive metal 2149
# Knowles unknown 2152
# Antônio Carlos Jobim Bossa Nova 2157
# Bauhaus post-punk 2160
# Blackalicious Hip-Hop 2163
# Don Cherry free jazz 2171
# Jamey Aebersold jazz 2185
# Joe Sample jazz 2187
# John Scofield jazz 2190
# Joni Mitchell folk 2191
# Lewis Parker Hip-Hop 2192
# Mike Scott singer-songwriter 2198
# Miss Kittin & The Hacker Electroclash 2199
# Oglio Records unknown 2207
# Porn Music drjazzmrfunkmusic 2211
# Red House Painters slowcore 2215
# Sonny Clark jazz 2218
# Stan Getz, Antonio Carlos Jobi unknown 2220
# Wayman Tisdale Smooth Jazz 2233
# Andrea Parker trip-hop 2249
# Ben Folds singer-songwriter 2251
# Black Cat White Cat balkan 2252
# Can krautrock 2254
# Cassandra Wilson jazz 2255
# Count Basie jazz 2256
# Erlend Øye electronic 2261
# Fela Kuti afrobeat 2262
# Mission of Burma post-punk 2268
# Mouse on Mars idm 2269
# Neko Case Alt-country 2270
# Phish Jam 2275
# Sahara Hotnights rock 2278
# The Von Bondies Garage Rock 2283
# Yusef Lateef jazz 2284
# Bright Eyes indie 2290
# A Number Of Names electro 2308
# Abscess death metal 2309
# Al Di Meola jazz 2311
# Astor Piazzolla tango 2314
# Black Star Hip-Hop 2324
# Dave Brubeck jazz 2333
# Dave Douglas jazz 2334
# Dixie Chicks country 2340
# Don Byron jazz 2342
# Ed Harcourt singer-songwriter 2346
# Édith Piaf french 2347
# Gavin Friday pop 2352
# Gotan Project tango 2353
# Interpol post-punk 2355
# Jeremy Enigk singer-songwriter 2358
# John Cage Avant-Garde 2360
# John Fred & His Playboy Band 60s 2361
# John Zorn jazz 2362
# Karlheinz Stockhausen Avant-Garde 2364
# Kazuyuki K. Null - James Plotk unknown 2365
# Kocani Orkestar Gypsy 2368
# Kyoto Jazz Massive acid jazz 2370
# Lamb trip-hop 2372
# Lee "Scratch" Perry dub 2374
# MC Solaar Hip-Hop 2379
# Modest Mouse indie rock 2383
# Moneybrother swedish 2385
# New Flesh For Old Hip-Hop 2388
# Orchestra Baobab african 2391
# Papa M post-rock 2393
# Richard Ashcroft britpop 2404
# Rilo Kiley indie 2405
# Sack & Blumm folktronica 2406
# Stan Getz jazz 2410
# The Charlatans britpop 2417
# The Kings Of Infinite Space indie rock 2422
# The Unicorns indie 2426
# The Walkmen indie rock 2428
# TV on the Radio indie 2432
# Yesterday's New Quintet jazz 2435
# 菅野よう子 Soundtrack 2437
# Soft Machine Progressive rock 2439
# Barry White soul 2447
# Bill Withers soul 2449
# Chicago classic rock 2453
# Chromeo electronic 2454
# Coparck dutch 2455
# Cut Chemist Meets Shortkut turntablism 2456
# Deltron 3030 Hip-Hop 2459
# Diana Ross and the Supremes soul 2460
# Edwin Starr soul 2461
# Goldfrapp electronic 2468
# Jan Garbarek Group jazz 2470
# KingBathmat Progressive rock 2473
# Ludwig van Beethoven Classical 2474
# Marilyn Monroe jazz 2476
# Monte Cazazza industrial 2480
# My Morning Jacket indie rock 2481
# Nina Nastasia folk 2482
# Norman Greenbaum classic rock 2483
# Paris Combo jazz 2484
# Pet Shop Boys synthpop 2486
# Potuznik austrian 2487
# Saltamontes indie rock 2494
# Scarlet Soho electronic 2496
# Subsonica italian 2500
# The Avalanches electronic 2502
# The Decemberists indie 2505
# The Emotions soul 2506
# The Get Up Kids emo 2508
# The Soft Pink Truth electronic 2510
# Van McCoy Disco 2513
# Vilhjalmur Vilhjalmsson icelandic 2514
# Wild Cherry funk 2515
# Katie Melua jazz 2518
# Tesla hard rock 2557
# "Weird Al" Yankovic comedy 2567
# A Tribe Called Quest Hip-Hop 2569
# a-ha new wave 2570
# Anita Baker soul 2573
# ARE weapons Electroclash 2574
# Augustus Pablo dub 2578
# bob hund swedish 2590
# Bonnie 'Prince' Billy folk 2592
# Califone folk 2597
# Claude Debussy Classical 2598
# Coil industrial 2599
# Cowboy Junkies Alt-country 2600
# Davey Graham folk 2605
# Deep Blue Something rock 2608
# Desmond Dekker ska 2609
# Drexciya techno 2616
# France Gall french 2626
# Gamma Ray Power metal 2633
# Gin Blossoms alternative rock 2638
# Jack Johnson & Ben Harper acoustic 2642
# Jazz Jamaica All Stars jazz 2643
# Jeff Beck classic rock 2644
# Jim Beard jazz fusion 2647
# Joan Osborne female vocalists 2649
# John Hassel and Brian Eno unknown 2652
# John Hiatt & The Guilty Dogs rock 2653
# Jonathan Richman And The Modern Lovers proto-punk 2656
# Kaffe Matthews ambient 2660
# Komeda indie pop 2662
# Lenny pop 2664
# Miles Davis Quintet jazz 2672
# Momus singer-songwriter 2675
# Paul van Dyk trance 2686
# RDB Bhangra 2694
# Roni Size / Reprazent Drum and bass 2696
# Roy Ayers funk 2697
# Skam Records Presents unknown 2704
# St. Germain acid jazz 2711
# The Ballistic Brothers chillout 2722
# The Books experimental 2725
# The Dirty Dozen Brass Band jazz 2729
# The Elephant Table Album unknown 2731
# The Herbaliser trip-hop 2733
# The Jackson 5 soul 2734
# The Stooges proto-punk 2740
# The Style Council new wave 2741
# Tim McGraw country 2745
# Two Lone Swordsmen idm 2752
# Willis Jackson jazz 2755
# Wire post-punk 2756
# 311 alternative 2760
# Annetenna rock 2766
# Astrud Gilberto Bossa Nova 2767
# Blood Ruby shoegaze 2771
# Carly Simon female vocalists 2774
# Hot Hot Heat indie rock 2789
# Ist free improvisation 2790
# Joan Jett and the Blackhearts rock 2792
# John Frusciante experimental 2793
# Kent swedish 2797
# Liars experimental 2799
# Manu Chao reggae 2802
# Mum electronic 2807
# Natasha Bedingfield pop 2808
# Pat Metheny Group jazz 2814
# Peanuts Wilson rockabilly 2815
# Peter Hammill Progressive rock 2818
# Plaid idm 2820
# Röyksopp electronic 2827
# Sergio Mendes Bossa Nova 2829
# Skeleton Key alternative rock 2830
# Smash Mouth rock 2831
# Sugababes pop 2834
# Tom Petty and The Heartbreakers classic rock 2846
# Tryo reggae 2849
# Jason Luckett acoustic 2853
# Etta James blues 2855
# Anthony Braxton free jazz 2871
# Antipop Consortium Hip-Hop 2872
# Apollo 2000 doctor who 2873
# Deee-Lite dance 2883
# Junior Senior dance 2900
# Laibach industrial 2901
# Muzsikas folk 2909
# Nocturnal Emissions industrial 2913
# St. Petersburg Classics Classical 2926
# Status Quo classic rock 2929
# Yami Bolo, Sly & Robbie unknown 2952
# Arctic Monkeys indie rock 2954
# Milburn indie rock 2956
# Chikinki indie 2957
# Michael Bublé jazz 2964
# Aqualung indie 2973
# Art Tatum jazz 2974
# Bill Frisell jazz 2978
# Bud Powell jazz 2981
# Dorothy Ashby jazz 2986
# Jazzanova acid jazz 2994
# Mahavishnu Orchestra jazz fusion 3002
# Michael Jackson VS The Prodigy unknown 3005
# Moby Vs Jet unknown 3008
# Sarah Vaughan jazz 3018
# Turin Brakes indie 3030
# Jools Holland & His Rhythm Blues Orchestra unknown 3043
# Jameroquai - Canned Heat unknown 3046
# Jeff Beck with Terry Bozzio & Tony Hymas blues rock 3053
# Joe Walsh classic rock 3054
# Paul McCartney classic rock 3056
# Razorlight indie 3058
# Scissor Sisters pop 3059
# Kellie Coffey country 3065
# Atom Heart ambient 3066
# Ravi Shankar Indian 3093
# Shuggie Otis soul 3097
# The Crusaders With Randy Crawford soul 3100
# The Pharcyde Hip-Hop 3103
# The Spencer Davis Group 60s 3105
# Violent Femmes alternative 3108
# Bee Gees Disco 3116
# Brian Eno & David Byrne experimental 3119
# Carole King singer-songwriter 3120
# Ravi Shankar and Philip Glass contemporary classical 3132
# Suicide post-punk 3135
# The Crusaders jazz 3137
# The Isley Brothers soul 3139
# The Orb ambient 3142
# Tuxedomoon post-punk 3147
# Neville Clay unknown 3162
# Alpha trip-hop 3171
# Annie Lennox pop 3173
# Aswad reggae 3177
# Baby Mammoth downtempo 3179
# Bo Kaspers Orkester swedish 3184
# Bomb the Bass electronic 3189
# Bonobo downtempo 3190
# Booker T. & the MG's soul 3191
# Boredoms experimental 3192
# Buddy Guy blues 3194
# Cabaret Voltaire industrial 3195
# Captain Beefheart & His Magic Band experimental 3196
# Congo Natty jungle 3198
# Danger Danger hard rock 3200
# Dionne Warwick soul 3205
# DJ Food trip-hop 3207
# Don McLean folk 3210
# Felix da Housecat House 3215
# Fishbone ska 3216
# Future By Design unknown 3221
# Geisha noise rock 3222
# Georg Friedrich Händel Classical 3223
# Happy Mondays madchester 3224
# Jets to Brazil indie rock 3230
# King Tubby dub 3238
# Kix hard rock 3239
# Leonard Nimoy Star Trek 3243
# Mana ERG industrial 3247
# Mike Oldfield Progressive rock 3254
# Mirwais electronic 3255
# Mongolia Folk Music Traditions central asian 3256
# Okavage Slide unknown 3261
# Operation Ivy punk 3262
# Orbital electronic 3263
# Ozomatli latin 3264
# Patti Smith punk 3267
# People Like Us experimental 3270
# Pete Namlook & Klaus Schulze ambient 3272
# Renato Carosone italian 3281
# Rod Stewart classic rock 3282
# SAMY BIRNBACH clinically romantic 3283
# Sensational underground hip-hop 3285
# Siouxsie and the Banshees post-punk 3286
# Skitz UK hip hop 3287
# Spacemen 3 shoegaze 3288
# Steve Earle & The Dukes Alt-country 3291
# Stock, Hausen & Walkman electronic 3293
# Superchunk indie rock 3294
# Sweet glam rock 3296
# t.A.T.u. pop 3298
# Ted McNabb And Company unknown 3300
# The Skatalites ska 3315
# Throbbing Gristle industrial 3319
# Tom Tom Club new wave 3321
# Tosca downtempo 3323
# Ugly Kid Joe hard rock 3326
# Velma electronic 3328
# Voodoo Child electronic 3329
# William Orbit ambient 3331
# Wishmountain techno 3332
# Yngwie J. Malmsteen's Rising Force heavy metal 3333
# Zita Swoon belgian 3334
# Zombie Nation techno 3335
# ハロー！プロジェクト Hello Project 3336
# Anthrax thrash metal 3337
# Groovenik unknown 3338
# Cradle of Filth black metal 3343
# Koяn Nu Metal 3350
# Peter White Smooth Jazz 3364
# Smoke City trip-hop 3367
# Beth Gibbons & Rustin Man trip-hop 3378
# Blaze heavy metal 3381
# Del Tha Funkee Homosapien Hip-Hop 3393
# Kopilot unknown 3418
# Mike Mainieri jazz 3425
# Roky Erickson & the Aliens Garage Rock 3447
# The Coral indie 3469
# The Plimptons Scottish 3474
# Throwing Muses alternative 3476
# Tim Buckley folk 3477
# Tricky trip-hop 3480
# Blue Öyster Cult hard rock 3497
# Bob James jazz 3498
# Chris Botti jazz 3501
# Christian McBride jazz 3502
# David Benoit Smooth Jazz 3508
# Dzihan & Kamien downtempo 3515
# Earl Klugh Smooth Jazz 3516
# Fourplay Smooth Jazz 3519
# George Benson jazz 3521
# Grover Washington Jr. jazz 3522
# Hothouse Flowers irish 3524
# Incognito acid jazz 3525
# Jaga Jazzist jazz 3528
# Jane Monheit jazz 3529
# Jeff Kashiwa Smooth Jazz 3530
# Kenny G jazz 3534
# Lee Ritenour jazz 3535
# Michael Lewis Michael Lewis 3542
# Ramsey Lewis jazz 3554
# Randy Crawford soul 3555
# Richard Elliot Smooth Jazz 3557
# Rory Gallagher blues rock 3558
# Stiltskin rock 3563
# Trashmonk indie 3571
# Afroman rap 3590
# Burt Bacharach easy listening 3592
# Jimmy Cliff reggae 3598
# Milk Inc. dance 3602
# Vanilla Ice rap 3608
# 50 Cent rap 3609
# Basilhs Karras unknown 3615
# Bobby Brown rnb 3621
# Bran Van 3000 electronic 3622
# Christy Moore irish 3626
# Devo new wave 3628
# Dr. Dre Hip-Hop 3631
# Elvenking folk metal 3635
# Fountains of Wayne power pop 3640
# Golden Gate Quartet gospel 3643
# Handsome Boy Modeling School Hip-Hop 3645
# Hooverphonic trip-hop 3646
# Howlin' Wolf blues 3647
# John Lennon classic rock 3657
# Jonathan Richman indie 3659
# Kaki King acoustic 3660
# Lambchop Alt-country 3661
# London Funk Allstars trip-hop 3663
# Mc Janik la belle de mai 3667
# Metric indie 3669
# Mos Def Hip-Hop 3671
# Nico folk 3673
# Notorious B.I.G. Hip-Hop 3675
# Reef rock 3682
# Renegade Soundwave dub 3683
# Robert Pete Williams blues 3684
# Roots Manuva Hip-Hop 3686
# Sage Francis Hip-Hop 3687
# Sisters Of Swing unknown 3690
# Tarnation Alt-country 3698
# Tha Alkaholiks Hip-Hop 3699
# The Breeders alternative 3702
# Wildchild Hip-Hop 3721
# X-Presidents Garage House 3722
# Knorkator fun metal 3724
# Archie Shepp jazz 3726
# Ben Webster jazz 3727
# Dolly Parton country 3733
# Gilberto Gil mpb 3737
# Julie London jazz 3738
# Rubén González cuban 3742
# Stacey Kent jazz 3745
# Stéphane Grappelli jazz 3746
# Alpha Stone space rock 3749
# Anita O'Day jazz 3750
# Benny Goodman jazz 3753
# Block 16 lounge 3754
# Bobby McFerrin jazz 3756
# Buckethead experimental 3759
# Carmen McRae jazz 3761
# Dinah Washington nu jazz 3766
# Gilles Deleuze Philosophie 3770
# Harry Belafonte calypso 3771
# Herman Düne folk 3772
# Ibrahim Ferrer cuban 3774
# Joe Henderson jazz 3778
# June Christy jazz 3779
# Lambert, Hendricks & Ross jazz 3781
# Lena Horne jazz 3782
# Lionel Hampton jazz 3783
# Nancy Wilson jazz 3786
# Oscar Brown Jr. jazz 3789
# Oscar Peterson Trio jazz 3791
# Seal soul 3797
# Shu De throat singing 3798
# Sidney Bechet jazz 3799
# Soft Cell new wave 3800
# Son House blues 3801
# The Music rock 3806
# Todd Rundgren classic rock 3813
# Tommy Flanagan jazz 3814
# Toots Thielemans jazz 3815
# Arrested Development Hip-Hop 3821
# B.B. King blues 3822
# Chuck Berry Rock and Roll 3824
# Devendra Banhart folk 3827
# Ghostface Hip-Hop 3830
# Gipsy Kings Flamenco 3831
# Hi-Tek feat. Buckshot unknown 3832
# Paco de Lucía Flamenco 3841
# Pulp britpop 3846
# Trans-Siberian Orchestra symphonic metal 3857
# Waldeck trip-hop 3858
# Anna Netrebko opera 3872
# Asian Dub Foundation dub 3873
# Benny Goodman & Peggy Lee loved 3875
# Charlie Hunter Trio jazz 3879
# Corners of the Mouth Random 3881
# Eagles of Death Metal Stoner Rock 3884
# Gene Vincent rockabilly 3889
# Helmet alternative metal 3891
# Noam Chomsky spoken word 3901
# Plácido Domingo opera 3904
# Russell Watson Classical 3909
# Slamin' Gladys unknown 3911
# Dee Pattern unknown 3924
# Morrissey indie 3927
# The Cult hard rock 3928
# Michael Andrews Soundtrack 3950
# Derek Sherinian Progressive metal 3962
# Moustaki chanson francaise 3977
# Renee Fleming opera 3982
# Cat Stevens folk 4013
# Courtney Pine jazz 4046
# Duel Stoner Rock 4051
# Emiliana Torrini icelandic 4053
# Erik Satie Classical 4055
# Frédéric Chopin Classical 4058
# John Barry Soundtrack 4062
# José Carreras opera 4066
# Meanwhile, Back in Communist Russia... post-rock 4070
# Ricky Martin pop 4083
# Ronnie Scott's Quintet jazz 4084
# The Troggs classic rock 4092
# Kaskade House 4167
# Motörhead heavy metal 4176
# The Shadows instrumental 4195
# Wheatus alternative rock 4201
# Chris Isaak rock 4205
# Gnarls Barkley funk 4206
# Main drone 4217
# Tears for Fears new wave 4221
# The Flying Burrito Brothers country 4224
# The Lucky Ones punk rock 4225
# The Royal Philharmonic Orchestra Classical 4267
# Chris Barber`S Jazz Band unknown 4274
# Francis Courchinoux Progressive metal 4276
# INXS rock 4278
# Loose Ends soul 4280
# The Gladiators reggae 4281
# The Pointer Sisters Disco 4282
# Finley Quaye reggae 4345
# Pat Metheny, Dave Holland, Roy Haynes guitar 4351
# Stanley Clarke jazz 4353
# Antonio Vivaldi Classical 4359
# Bond instrumental 4363
# Bryn Terfel Classical 4364
# Common Hip-Hop 4368
# Dominic Miller jazz 4370
# Gustav Holst Classical 4379
# Henryk Górecki contemporary classical 4380
# Jeno Jando Classical 4383
# Larry Carlton jazz 4390
# Luciano Ligabue rock 4394
# Ludwig van Beethoven - Berliner Philharmoniker - Herbert Von Karajan unknown 4395
# Mescalito trip-hop 4398
# Ronny Jordan acid jazz 4405
# Tchaikowsky-Mozart-Rachmaninov-Grieg-Beethoven-Schumann unknown 4412
# The Dandy Warhols indie 4415
# Golden Earring classic rock 4447
# Paul Simon singer-songwriter 4484
# Inspiral Carpets madchester 4488
# Duke Ellington and Johnny Hodg unknown 4491
# Steve Greenbaum jazz 4495
# Bill Haley And The Comets rockabilly 4513
# Enrique Iglesias and Tom Jones unknown 4517
# Melissa Etheridge rock 4518
# Sam Cooke soul 4520
# The Drifters soul 4521
# Anal Cunt grindcore 4544
# Charlie Haden & Pat Metheny jazz 4570
# Colin Hay acoustic 4572
# Nelson hard rock 4582
# Absolute Beginner hip hop 4591
# Blumentopf german 4598
# Bonnie Somerville female vocalists 4599
# Cary Brothers indie 4600
# Dali's Dilemma Progressive metal 4603
# Divinyls new wave 4608
# Faithless electronic 4612
# Feist female vocalists 4614
# Gonzales piano 4618
# I Monster trip-hop 4621
# John Williams Soundtrack 4625
# Kings of Convenience acoustic 4626
# Kruder & Dorfmeister electronic 4627
# Mylo electronic 4633
# Star One Progressive metal 4643
# SXSW Interactive Conference unknown 4646
# UNKLE trip-hop 4653
# Ark Progressive metal 4663
# Bozzio Levin Stevens Progressive rock 4668
# Dimmu Borgir black metal 4671
# Marty Friedman guitar virtuoso 4680
# Orphaned Land Progressive metal 4685
# The Mars Volta Progressive rock 4698
# Roni Size - New Forms unknown 4705
# Millencolin punk rock 4706
# 2 Unlimited eurodance 4708
# Black Box dance 4710
# Cher pop 4712
# Dexy's Midnight Runners new wave 4713
# DjSalt unknown 4715
# Elton John pop 4716
# Jackie Wilson soul 4720
# Jimmy Smith jazz 4721
# Los Lobos rock 4725
# Rahsaan Roland Kirk jazz 4729
# The B-52's new wave 4731
# The Bluebells new wave 4732
# The Supremes soul 4735
# Grateful Dead Psychedelic Rock 4770
# Meredith Brooks female vocalists 4773
# Snoop Dogg Hip-Hop 4778
# Ice Cube Hip-Hop 4780
# 213 G-funk 4781
# Amerie rnb 4782
# Busta Rhymes Hip-Hop 4787
# Cam'ron Hip-Hop 4788
# D12 rap 4789
# Fabolous Hip-Hop 4790
# Gwen Stefani pop 4791
# JAY-Z Hip-Hop 4792
# Kanye West Hip-Hop 4793
# Lil Jon & The East Side Boyz Crunk 4794
# Mase rap 4796
# Missy Elliott Hip-Hop 4797
# Nelly Hip-Hop 4799
# Obie Trice Hip-Hop 4801
# Warren G G-funk 4804
# Wyclef Jean Hip-Hop 4805
# Xzibit Hip-Hop 4806
# Talib Kweli Hip-Hop 4812
# Fink indie 4823
# Toto rock 4825
# Big Star power pop 4834
# Brazilian Girls electronic 4838
# DJ Vadim ninja tune 4847
# Freddie Mercury classic rock 4851
# Grassskirt lounge 4853
# Guano Apes alternative rock 4855
# Hard-Fi indie 4856
# Jennifer Lopez pop 4859
# Jimmy Smith and Wes Montgomery jazz 4860
# John Legend soul 4861
# Kim Wilde 80s 4863
# Koop jazz 4864
# Method Man Hip-Hop 4868
# Randy Brecker jazz 4879
# Richard Bona jazz 4882
# Ron Sexsmith singer-songwriter 4883
# The American Analog Set indie rock 4895
# The Living End punk rock 4900
# Tom Browne funk 4909
# Tom Vek indie 4911
# William Shatner spoken word 4915
# Zakir Hussain tabla 4916
# REM & Natalie Merchant unknown 4938
# Adrian Belew Progressive rock 4978
# Coleman Hawkins jazz 4982
# Gentle Giant Progressive rock 4984
# Schaffer the Darklord nerdcore 5001
# The Marshall Tucker Band Southern Rock 5005
# Zoot Sims jazz 5010
# Benny Goodman Orchestra jazz 5029
# Benny Goodman & His Orchestra jazz 5035
# Rob Dougan electronic 5044
# Boozoo Bajou downtempo 5060
# Edguy Power metal 5065
# Renaissance Progressive rock 5077
# Tor Norbye, Carl Quinn, Dick Wall podcast 5090
# Elnog unknown 5113
# Vince Guaraldi Trio jazz 5141
# Adriano Celentano italian 5161
# Ahmad Jamal jazz 5162
# Andy Williams oldies 5165
# Backstreet Boys pop 5169
# Basement Jaxx electronic 5170
# Bedlam hard rock 5171
# Belly alternative 5173
# Bomfunk MC's electronic 5175
# Charlie Rouse jazz 5178
# Dar Williams folk 5182
# David Guetta House 5183
# Dennis Brown reggae 5186
# Dick Dale surf rock 5189
# Drive-By Truckers Southern Rock 5190
# Gerry Mulligan jazz 5201
# Hubert Laws jazz 5205
# Illinois Jacquet with Joe Defrancesco unknown 5207
# Joe Pass jazz 5213
# Joshua Redman jazz 5216
# Keiko Lee jazz 5217
# Lou Donaldson jazz 5222
# Lucie Silvas female vocalists 5223
# Maroons Quannum 5226
# Mel Tormé jazz 5227
# Mongo Santamaria latin jazz 5228
# Nightmares on Wax trip-hop 5229
# Percy Faith & His Orchestra instrumental 5235
# Pete Jolly jazz 5236
# Roy Hargrove jazz 5243
# Sparks new wave 5249
# Steve Morse guitar virtuoso 5255
# Stevie Ray Vaughan and Double Trouble blues 5257
# Ted Leo and the Pharmacists indie rock 5258
# The Glenn Miller Orchestra jazz 5264
# Tom Jones feat. Blue & Keith Airey unknown 5270
# NEU! krautrock 5293
# A+ unknown 5294
# Betty Carter & Ray Bryant USA 5298
# Ellis Marsalis jazz 5303
# Isaac Hayes soul 5307
# Julie Dreyfus Soundtrack 5308
# Mary Chapin Carpenter country 5310
# The 5.6.7.8's japanese 5317
# Tom Scott jazz 5319
# 布袋寅泰 japanese 5321
# RZA Hip-Hop 5338
# RZA/Charles Bernstein unknown 5339
# Cherry Poppin' Daddies swing 5349
# Halfway to Gone Stoner Rock 5354
# Circa Survive experimental 5357
# Lemon Jelly electronic 5360
# PG DVERI punk 5362
# Afterlife chillout 5364
# Audio Bullys electronic 5365
# Rootjoose cornwall 5384
# The Cat Empire ska 5390
# 2Pac rap 5391
# Audio Bullys Feat. Nancy Sinatra electronic 5392
# Destiny's Child rnb 5396
# Fat Joe Hip-Hop 5399
# Ja Rule rap 5403
# Jonathan Coulton comedy 5405
# Merankorii dark ambient 5408
# MF DOOM Hip-Hop 5409
# Morphine jazz 5410
# Nas Hip-Hop 5411
# Nouvelle Vague Bossa Nova 5412
# Ryan Prebble acoustic 5414
# Twista rap 5416
# LL Cool J Hip-Hop 5422
# Orgy industrial 5448
# Pyotr Ilyich Tchaikovsky Classical 5449
# Redman Hip-Hop 5452
# Swordfishtrombones Czech 5456
# Micatone acid jazz 5468
# Bill Monroe bluegrass 5475
# Chico Buarque mpb 5480
# Danko Jones hard rock 5482
# Danny Wilson pop 5483
# Edu Lobo Bossa Nova 5487
# Elis Regina mpb 5488
# Elza Soares samba 5489
# Europe hard rock 5492
# Glenn Frey 80s 5496
# Memphis Slim blues 5511
# Midnight Oil rock 5512
# Never the Bride rock 5516
# Social Distortion punk rock 5533
# Spyro Gyra jazz 5535
# The Mamas & the Papas classic rock 5541
# White Lion hard rock 5547
# Genesis Progressive rock 5569
# P. Diddy Hip-Hop 5571
# 9 Lazy 9 downtempo 5575
# Billy Talent punk rock 5579
# Captain Future japanese 5582
# Chambao Flamenco 5583
# Craig Armstrong Soundtrack 5584
# Joss Stone soul 5588
# Lonestar country 5591
# Machinae Supremacy sid metal 5593
# Kinema chillout 5626
# louis logic Hip-Hop 5628
# House of Pain Hip-Hop 5659
# International Pony electronic 5662
# Unorganized Crime pop punk 5664
# Boots Brown And His Blockbusters jazz 5667
# Ella Fitzgerald With Duke Ellington And His Orchestra Big Band 5676
# John Handy jazz 5682
# John Hendricks hip hop 5683
# Les McCann & Eddie Harris jazz 5686
# Peggy Lee jazz 5696
# Symphony X Progressive metal 5707
# The Beautiful South pop 5709
# Wild Bill Davis organ 5716
# DJ Tomekk Hip-Hop 5723
# The The new wave 5735
# Puff Daddy Hip-Hop 5740
# Bobby Montez jazz 5747
# DJ Jazzy Jeff Hip-Hop 5750
# Hot Action Cop rapcore 5753
# Judith Holofernes german 5757
# Juno Reactor & Don Davis Soundtrack 5758
# Kenny Parker electric blues 5760
# Propellerheads big beat 5764
# Sisterlove chillout 5768
# The Guess Who classic rock 5774
# Venetian Snares breakcore 5779
# Laura Nyro singer-songwriter 5787
# ↑THE HIGH-LOWS↓ japanese 5797
# Angerbox Grunge 5799
# Black Label Society heavy metal 5801
# Bobby Womack soul 5802
# Bongzilla Sludge 5803
# Cathedral doom metal 5805
# Dave Holland jazz 5807
# Donny Hathaway soul 5809
# Dozer Stoner Rock 5810
# El Caco Stoner Rock 5812
# Figment UK hip-hop 5815
# Gang of Four post-punk 5818
# Masters of Reality Stoner Rock 5820
# Mastodon Progressive metal 5821
# Melanie C pop 5822
# Mountain Mirrors Progressive rock 5823
# Mustasch Stoner Rock 5824
# Nebula Stoner Rock 5825
# Orange Goblin Stoner Rock 5826
# Saint Vitus doom metal 5834
# Steeleye Span folk 5835
# The Atomic Bitchwax Stoner Rock 5836
# Unida Stoner Rock 5839
# User techno 5840
# Andrew Strong soul 5856
# Maria Doyle unknown 5857
# Niamh Kavanagh irish 5858
# Robert Arkins soul 5859
# Angeline Ball Soundtrack 5860
# Angeline Ball/Maria Doyle unknown 5861
# of Montreal indie pop 5879
# Chris Rea blues 5883
# Roxette pop 5899
# My Brightest Diamond female vocalists 5906
# The Only Ones new wave 5941
# Flamin' Groovies Garage Rock 5961
# Wise Guys a capella 5992
# Roger Waters Progressive rock 6008
# Duke Ellington, Charles Mingus and Max Roach jazz 6116
# Stanley Clarke, Larry Carlton, Billy Cobham, Deron Johnson jazz fusion 6132
# 39 Clocks post-punk 6137
# Eva Cassidy & Chuck Brown soul 6157
# Sam the Sham & The Pharaohs Garage Rock 6160
# Strawberry Alarm Clock Psychedelic Rock 6161
# The Blues Magoos Garage Rock 6162
# The Syndicate of Sound Garage Rock 6166
# Deacon Blue 80s 6195
# Love Psychedelic Rock 6199
# Lee van Laer unknown 6226
# Romane gypsy jazz 6239
# Amy Winehouse soul 6258
# Anouar Brahem Trio jazz 6259
# David Murray jazz 6267
# Enrico Rava jazz 6270
# John McLaughlin jazz 6274
# Marcus Strickland saxophone 6277
# Mose Allison jazz 6283
# Noel Zancanella instrumental hip-hop 6284
# Oliver Nelson jazz 6286
# Soulive funk 6291
# The Brecker Brothers jazz 6292
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 38
#      36 counter+=1
#      37 #advances the counter by 1 to move onto the next artist.
# ---> 38 time.sleep(0.3)
#      39 #AI SUGGESTION, this is just so that the API doesn't take too many requests and give me a JSONDecodeError,
#
# KeyboardInterrupt:

# %%
#_________________________________________________________________________________________________________________________________________
#BLOCK 1.4 - Classify Genres
#As per the Code you gave me, instead of running a loop, i used np.where statements after converting my sick dictionary to a dataframe
#and used pandas to change all of the tags 
sickdf=pd.DataFrame(list(sickdict.items()),columns=['artist','tags'])
#converts the dictionary to a dataframe
sickdf['tags']=sickdf['tags'].str.lower()
#converts all of the items in the tag column into lowercase strings which i use to search
sickdf['genre'] = np.where(sickdf['tags'].str.contains('pop'), 'Pop', 'other')
# creates a new column in sickdf titled 'genre' and also checks if the item contains pop, if so it will rename the item to pop, if not
#initializes the new genres to be titled 'other'
sickdf['genre'] = np.where(sickdf['tags'].str.contains('rock|punk|grunge|ska|alternative|britpop'), 'Rock', sickdf['genre'])
#checks for any of the genres in the 'rock|punk|grunge...' chunk as they are separated by or operators, if it contains any of them, it will 
#rename the tag to 'Rock'. if it doesnt contain any of them it will keep the genre as other
#https://stackoverflow.com/questions/26577516/how-to-test-if-a-string-contains-one-of-the-substrings-in-a-list-in-pandas
sickdf['genre'] = np.where(sickdf['tags'].str.contains('jazz|swing|blues|soul|funk'), 'Jazz', sickdf['genre'])
# If the tag contains 'jazz|swing|blues|soul|funk' it will change the tag to Jazz if so, if not it will keep the genre the same
sickdf['genre'] = np.where(sickdf['tags'].str.contains('electronic|techno|house|ambient|trance|dubstep|trip-hop'), 'Electronic', sickdf['genre'])
# If the tag contains 'electronic|techno|house|ambient|trance|dubstep|trip-hop and will change the tag to Electronic if so,
#if not it will keep the genre the same
sickdf['genre'] = np.where(sickdf['tags'].str.contains('indie'), 'Indie', sickdf['genre'])
# If the tag contains 'indie' and will change the tag to Jazz if so, if not it will keep the genre the same, I know this is not necessary
# but I wanted to make sure all the formatting was homogenous
sickdf['genre'] = np.where(sickdf['tags'].str.contains('metal'), 'Metal', sickdf['genre'])
sickdf['genre'] = np.where(sickdf['tags'].str.contains('classical'), 'Classical', sickdf['genre'])
#Both metal and classical were made for the same reason as Indie above
sickdf['genre'] = np.where(sickdf['tags'].str.contains('hip|hip hop|hop|rap|Hip-Hop'), 'Hip Hop', sickdf['genre'])
# If the tag contains 'hip|hip hop|hop|rap|Hip-Hop' and will change the tag to Hip Hop if so, if not it will keep the genre the same as other
sickdf['genre'] = np.where(sickdf['tags'].str.contains('folk|country|americana'), 'folk', sickdf['genre'])
sickdf
#returns the dataframe
#_________________________________________________________________________________________________________________________________________
#BLOCK 1.5 - Get Data for DataFrame
dataframe=[]
chartnumber=0
url = "http://ws.audioscrobbler.com/2.0/"
YOUR_API_KEY = '915b23d080ae463f6850ac8cec3aefb6'
#Essentially my entire goal is to go through each week, find the total share of each genre during the week, and put it
# into a list that I can turn into a dataframe.

for chart in charts['weeklychartlist']['chart']:
    fromdate = charts['weeklychartlist']['chart'][chartnumber]['from'] 
    #sets date to begin at for the weeklisteningdata search
    todate = charts['weeklychartlist']['chart'][chartnumber]['to']
    #sets end date for the weeklisteningdata
    weeklisteningdata = requests.get(f'{url}?method=user.getweeklyartistchart&user=rj&api_key={YOUR_API_KEY}&format=json&to={todate}&from={fromdate}')
    #the above line gets the weekly artist chart for the week specified by the fromdate and todate variables
    weekjson=weeklisteningdata.json() 
    #gets the above request as a JSON print
    weekartists=weekjson['weeklyartistchart']['artist'][:250] 
    #gets first 250 artists, representative of most of the listening for the week
    #essentially this next for loop tracks each weeks total genreplays and total plays in general
    genreplays={} 
    #creates an empty dictionary for every week in the loop, use this to see genre shares for each of the weeks
    totalplays=0 
    #initializes the total plays so we can see out of the total plays per week, how many were each genre
    for musician in weekartists: 
        #cycles through each of the top 250 artists per week
        name=musician['name'] 
        #gets artist's name
        plays=int(musician['playcount']) 
        #how many times they were played during this week, gets added to total plays and then calculated as a share of listening 
        search = sickdf[sickdf['artist'] == name]
        tag = search['genre'].values[0] if len(search) > 0 else 'other'
        #gets the name of the artist from the sick dictionary returns the genre as a tag
        if tag not in genreplays: 
            #if a tag is not in the dictionary, initialize it
            genreplays[tag]=0 
            #including this to initialize each of the genres within the dict
        genreplays[tag]=genreplays.get(tag) + plays 
        #silly refresher but i forgot how to do this https://www.digitalocean.com/community/tutorials/python-add-to-dictionary
        totalplays+=plays 
        #adds the # of plays to total plays, measures how much the listener is listening per week
        print(musician['name'],tag, f'week{chartnumber}') # Another print statement so i disabled,prints the musician, their tag, and the chart week number

    # essentially this for loop is putting ALL of my stuff into the empty list so that I can put it into a dataframe
    for genre, plays in genreplays.items(): 
        #gets both genre and playshare from my dictionary (pretty much key and vlaue)
        dataframe.append({'Week':fromdate,'Genre':genre, 'Play Share': plays/totalplays,'Total Plays':totalplays}) 
        #appends all of these different pairs into my datafram with the key as the Title of the column and the 
        #fromdate is in a disgusting format, gonna look this up to change it, https://stackoverflow.com/questions/17594298/date-time-formats-in-python
    chartnumber+=1
    #advances the chart number up by 1
    time.sleep(0.3) 
dataframe
# Out:
# Aerosmith Rock week0
# Metallica Metal week0
# Miles Davis Jazz week0
# Guns N' Roses Rock week0
# Dream Theater Metal week0
# R.E.M. Rock week0
# Radiohead Rock week0
# Moby Electronic week0
# Joe Satriani other week0
# Led Zeppelin Rock week0
# Counting Crows Rock week0
# Free Rock week0
# Red Hot Chili Peppers Rock week0
# Jimi Hendrix Rock week0
# Badly Drawn Boy Indie week0
# The Rolling Stones Rock week0
# Portishead Hip Hop week0
# Matchbox Twenty Rock week0
# Jamiroquai Jazz week0
# The Beatles Rock week0
# Goo Goo Dolls Rock week0
# Ben Folds Five Rock week0
# Dido Pop week0
# Eels Indie week0
# Stevie Wonder Jazz week0
# The Jimi Hendrix Experience Rock week0
# David Bowie Rock week0
# Dire Straits Rock week0
# Rage Against the Machine Rock week0
# A Perfect Circle Rock week0
# Dan Reed Network Rock week0
# Beck Rock week0
# Nine Inch Nails other week0
# Ben Harper other week0
# Fun Lovin' Criminals Jazz week0
# Barenaked Ladies Rock week0
# Jeff Buckley other week0
# Norah Jones Jazz week0
# Buckcherry Rock week0
# Foo Fighters Rock week0
# King's X Rock week0
# The Doors Rock week0
# The Police Rock week0
# Queen Rock week0
# (hed) Planet Earth Hip Hop week0
# The Cure Rock week0
# U2 Rock week0
# Bruce Springsteen Rock week0
# Nirvana Rock week0
# The Smashing Pumpkins Rock week0
# Pink Floyd Rock week0
# Coldplay Rock week0
# Herbie Hancock Jazz week0
# The Classic Chill Out Album other week0
# Air Electronic week0
# Lenny Kravitz Rock week0
# The Velvet Underground other week0
# Beth Orton other week0
# Judas Priest Metal week0
# Tom Waits Jazz week0
# Deep Purple Rock week0
# Desert Sessions Rock week0
# Pearl Jam Rock week0
# Weezer Rock week0
# Rammstein Metal week0
# Neil Young Rock week0
# Def Leppard Rock week0
# Fugees Hip Hop week0
# Nickelback Rock week0
# Pink Pop week0
# Massive Attack Hip Hop week0
# Various Artists other week0
# The Kleptones other week0
# Feeder Rock week0
# Linkin Park Metal week0
# Blur Rock week0
# Muse Rock week0
# Nick Cave and the Bad Seeds Rock week0
# Frank Sinatra Jazz week0
# Van Morrison other week0
# Sonic Youth other week0
# James Taylor folk week0
# No Doubt Rock week0
# Diana Krall Jazz week0
# Level 42 other week0
# Mr. Big Rock week0
# Everclear Rock week0
# Frankie Goes to Hollywood other week0
# Bob Marley other week0
# Santana Rock week0
# The White Stripes Rock week0
# Bob Dylan folk week0
# Jools Holland other week0
# PJ Harvey other week0
# Audioslave Rock week0
# Creed Rock week0
# Dave Weckl Jazz week0
# Nina Simone Jazz week0
# Stereolab Electronic week0
# 3 Doors Down Rock week0
# Chet Baker Jazz week0
# Dizzy Gillespie other week0
# George Michael Pop week0
# Marcus Miller Jazz week0
# Pixies Rock week0
# Bob Seger Rock week0
# Disturbed Metal week0
# Electric Wizard Metal week0
# Elvis Presley Rock week0
# Eric Clapton Jazz week0
# Weather Report Jazz week0
# Faith No More Rock week0
# Fleetwood Mac Rock week0
# Roachford Jazz week0
# System of a Down Metal week0
# A Rock week0
# Quincy Jones Jazz week0
# Ella Fitzgerald Jazz week0
# John Mayer other week0
# Morcheeba Hip Hop week0
# James Brown Jazz week0
# Ash Rock week0
# Nick Drake folk week0
# Zero 7 other week0
# Beastie Boys Hip Hop week0
# Black Sabbath Metal week0
# Lou Reed Rock week0
# Michael Jackson Pop week0
# Oleander Rock week0
# Talking Heads other week0
# [unknown] other week0
# John Coltrane Jazz week0
# Simon & Garfunkel folk week0
# Cutting Crew other week0
# Depeche Mode Electronic week0
# Madonna Pop week0
# Neal Morse Rock week0
# Pantera Metal week0
# Alanis Morissette other week0
# Pavement Indie week0
# Soundgarden Rock week0
# The Wallflowers Rock week0
# De La Soul Hip Hop week0
# The Divine Comedy Indie week0
# Boards of Canada Electronic week0
# David Lee Roth Rock week0
# John Patitucci Jazz week0
# Meat Loaf Rock week0
# Cream Rock week0
# Tindersticks Pop week0
# Collective Soul Rock week0
# One Minute Silence Metal week0
# Crash Test Dummies Rock week0
# Elvis Costello other week0
# Incubus Rock week0
# Kraftwerk Electronic week0
# Liquid Tension Experiment Metal week0
# Placebo Rock week0
# Yngwie Malmsteen Metal week0
# B.B. King & Eric Clapton Jazz week0
# Bryan Adams Rock week0
# Eagles Rock week0
# Firebird Jazz week0
# Lynyrd Skynyrd Rock week0
# The Beta Band Indie week0
# The Who Rock week0
# Alice Cooper Rock week0
# Autechre other week0
# Bon Jovi Rock week0
# Brian Eno Electronic week0
# Phil Collins Big Band Jazz week0
# The Verve Rock week0
# Tower of Power Jazz week0
# Yo La Tengo Indie week0
# Curtis Mayfield Jazz week0
# Peter Gabriel Rock week0
# Steve Vai other week0
# Chick Corea Jazz week0
# EVE 6 Rock week0
# Garbage Rock week0
# Natalie Merchant other week0
# AC/DC Rock week0
# Aretha Franklin Jazz week0
# Billie Holiday Jazz week0
# Django Reinhardt Jazz week0
# my bloody valentine other week0
# Oasis Rock week0
# Sting Rock week0
# Best Jazz Ever other week0
# Bruce Dickinson Metal week0
# Enuff Z'Nuff Rock week0
# Iggy Pop Rock week0
# Madness Rock week0
# The Byrds Rock week0
# The Clash Rock week0
# Derek & Clive other week0
# Spiritualized Rock week0
# Whitesnake Rock week0
# Eva Cassidy Jazz week0
# Johann Sebastian Bach Classical week0
# Steppenwolf Rock week0
# Supreme Beings of Leisure Hip Hop week0
# Suzie Higgie other week0
# The Stone Roses Rock week0
# Thievery Corporation other week0
# Tracy Chapman other week0
# Anastacia Pop week0
# Aphex Twin Electronic week0
# Leonard Cohen folk week0
# The Jon Spencer Blues Explosion Jazz week0
# The Stranglers other week0
# Brant Bjork Rock week0
# Prince Jazz week0
# Sublime Rock week0
# Tok Tok Tok Jazz week0
# Dr. John Jazz week0
# Gorillaz Electronic week0
# Hootie & The Blowfish Rock week0
# Joni Mitchell & James Taylor folk week0
# Jurassic 5 Hip Hop week0
# Staind Rock week0
# Tenacious D Rock week0
# The Battle of Los Angeles other week0
# The Fall Rock week0
# The James Taylor Quartet Rock week0
# Travis Rock week0
# Ani DiFranco folk week0
# Björk Electronic week0
# DumDums other week0
# Kid Rock Rock week0
# Marilyn Manson other week0
# Suzanne Vega other week0
# The Cranberries Rock week0
# Belle and Sebastian Indie week0
# Elliott Smith other week0
# Eminem Hip Hop week0
# Fiona Apple other week0
# Moloko Hip Hop week0
# Natalie Imbruglia Pop week0
# Sigur Rós Rock week0
# Steve Miller Band Rock week0
# The Future Sound of London Electronic week0
# Buena Vista Social Club other week0
# David Hudson and Friends other week0
# DJ Krush Hip Hop week0
# Doves Indie week0
# Eurythmics other week0
# Live Rock week0
# Serge Gainsbourg other week0
# The Hollies other week0
# Mr. Big Rock week1
# Liquid Tension Experiment Metal week1
# Joe Satriani other week1
# Kings of Leon Rock week1
# Audioslave Rock week1
# Level 42 other week1
# Muse Rock week1
# Nirvana Rock week1
# Red Hot Chili Peppers Rock week1
# Steppenwolf Rock week1
# 3 Doors Down Rock week1
# Blind Guardian Metal week1
# Charles Mingus Jazz week1
# Coldplay Rock week1
# Deep Purple Rock week1
# Derek & Clive other week1
# Diana Krall Jazz week1
# Dire Straits Rock week1
# Dizzy Gillespie other week1
# Eva Cassidy Jazz week1
# Fear Factory Metal week1
# Fleetwood Mac Rock week1
# Foo Fighters Rock week1
# Iron Maiden Metal week1
# Jaco Pastorius Jazz week1
# Jimi Hendrix Rock week1
# Joy Division Rock week1
# Led Zeppelin Rock week1
# Megadeth Metal week1
# Pain of Salvation Metal week1
# Queensrÿche Metal week1
# Radiohead Rock week1
# Shaman folk week1
# Silverchair Rock week1
# Slayer Metal week1
# Smith Rock week1
# The Byrds Rock week1
# The Electric Prunes Rock week1
# The Jimi Hendrix Experience Rock week1
# The Quantic Soul Orchestra Jazz week1
# U2 Rock week1
# Van Morrison other week1
# Miles Davis Jazz week2
# Desert Sessions Rock week2
# King's X Rock week2
# Buckcherry Rock week2
# Def Leppard Rock week2
# Dream Theater Metal week2
# Joe Satriani other week2
# Mr. Big Rock week2
# B.B. King & Eric Clapton Jazz week2
# Crusaders Jazz week2
# Grassroots other week2
# The Delfonics Jazz week2
# Tok Tok Tok Jazz week4
# Grandmaster Flash and The Furious Five Hip Hop week4
# Run-D.M.C. Hip Hop week4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 39
#      37 todate = charts['weeklychartlist']['chart'][chartnumber]['to']
#      38 #sets end date for the weeklisteningdata
# ---> 39 weeklisteningdata = requests.get(f'{url}?method=user.getweeklyartistchart&user=rj&api_key={YOUR_API_KEY}&format=json&to={todate}&from={fromdate}')
#      40 #the above line gets the weekly artist chart for the week specified by the fromdate and todate variables
#      41 weekjson=weeklisteningdata.json()
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#     507 except BrokenPipeError:
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connection.py:500, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     498 for header, value in headers.items():
#     499     self.putheader(header, value)
# --> 500 self.endheaders()
#     502 # If we're given a body we start sending that in chunks.
#     503 if chunks is not None:
#
# File /opt/anaconda3/lib/python3.13/http/client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1331 else:
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/anaconda3/lib/python3.13/http/client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1091 msg = b"\r\n".join(self._buffer)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#    1098     if hasattr(message_body, 'read'):
#    1099         # Let file-like take precedence over byte-like.  This
#    1100         # is needed to allow the current position of mmap'ed
#    1101         # files to be taken into account.
#
# File /opt/anaconda3/lib/python3.13/http/client.py:1037, in HTTPConnection.send(self, data)
#    1035 if self.sock is None:
#    1036     if self.auto_open:
# -> 1037         self.connect()
#    1038     else:
#    1039         raise NotConnected()
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connection.py:331, in HTTPConnection.connect(self)
#     330 def connect(self) -> None:
# --> 331     self.sock = self._new_conn()
#     332     if self._tunnel_host:
#     333         # If we're tunneling it means we're connected to our proxy.
#     334         self._has_connected_to_proxy = True
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     199 """Establish a socket connection and set nodelay settings on it.
#     200
#     201 :return: New socket connection.
#     202 """
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#     211     raise NameResolutionError(self.host, self, e) from e
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
#_________________________________________________________________________________________________________________________________________
#BLOCK 1.5.5 - Create DataFrame
#actually makes the dataframe and adjusts the date codes and drops the other ugly date column
df = pd.DataFrame(dataframe)
df #calls the function the first time
df['Week']=pd.to_datetime(df['Week'], unit='s') #convert to date, #https://stackoverflow.com/questions/19645706/last-fm-api-date-range
df #calls the function again
df.to_csv('UglyDF2.csv')
# Out:
# /var/folders/ls/kyxsy4zs0c90rvt229n6dzpr0000gn/T/ipykernel_22803/2104301598.py:6: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['Week']=pd.to_datetime(df['Week'], unit='s') #convert to date, #https://stackoverflow.com/questions/19645706/last-fm-api-date-range

# %% [markdown]
# # Above is all the leg work in order to get the DataFrame Titled 'UglyDF.csv'
# I have uploaded that and the complete DataFrame into the project folder. Here I'm calling the Dataframe and combining it with the FRED Data in order to get more variables I can regress. This block also exports my final DataFrame into a csv file titled 'RealFinalDF.csv' which I used to both graph my data as well as run my regressions in R. UglyDF was the initial csv but RealFinalDF is the completed csv, I just wanted to be thorough in my code for the final.

# %%
#BLOCK 1.6 - Call the Ugly DataFrame
#Allows me to start with the data and just manipulate it from here, 
path='/Users/alex/Documents/Pace/Classes/Junior/Spring/Data Analytics/Final Project/final-project-atuosto1/' #my path, I know it will be different
data=pd.read_csv(f'{path}UglyDF2.csv') #brings the data Frame into the notebook from the path
data['Month']=pd.to_datetime(data['Week'], unit='ns').dt.month #changes the Month column so I can sort based on year and month in the future
data['Year']=pd.to_datetime(data['Week'], unit='ns').dt.year #changes the Year column so I can sort based on year and month in the future
data['Play Share (Number)']=data['Play Share'] * data['Total Plays'] #creates a variable so I can see the individual plays for each genre
data #calls the overall data frame into the notebook
#_________________________________________________________________________________________________________________________________________
#BLOCK 1.7 - Getting Fred Data
#In order to make a Fred Dataframe I need to first get the Data, Thankfully this Package allows me to do just that
# pip install fredapi # this entire thing was shown by this https://pypi.org/project/fredapi/ 
from fredapi import Fred 
# gets Fred Package
FREDKEY= '2432515d4bc3acaf9cc6bdbbc8ad8558' 
#gets my fred API key
fred=Fred(api_key=FREDKEY) 
#structures the variable to use my API key when getting data, this was in the documentation
recession=fred.get_series('USREC') 
#recession dummy variable
PCEPI=fred.get_series('PCEPI') 
# PCE variable
UNEMP=fred.get_series('UNRATE') 
#U3 Unemployment rate
UMICH=fred.get_series('UMCSENT') 
#UMICH Consumer sentiment Survey
#_________________________________________________________________________________________________________________________________________
#BLOCK 1.7.5 - Making Fred DataFrame to Merge
#In order to Merge the Fred Data I first need to make another Dataframe with Fred Data in it
freddf=pd.DataFrame(PCEPI)
freddf['REC']=pd.DataFrame(recession) 
#MAKES A COLUMN FOR EACH VARIABLE, this one is titled REC
freddf['UNRATE']=pd.DataFrame(UNEMP) 
#Takes the FRED indicator with the tag 'UNEMP' and puts it in a Pandas Dataframe, measures Unemployment
freddf['PCE']=pd.DataFrame(PCEPI) 
#Takes the FRED indicator with the tag 'PCE' and puts it in a Pandas Dataframe, measures change in price level
freddf['UMICH']=pd.DataFrame(UMICH) 
#Takes the FRED indicator with the tag 'UMICH' and puts it in a Pandas Dataframe, is a survey measuring Consumer Sentiment
freddf.drop(freddf.columns[0],axis=1) 
#Drops the first initial useless column
freddf['Year']=freddf.index 
#Makes a column from the year, given by the index but just so i can match it with freds year data
freddf['Month']=pd.to_datetime(freddf['Year'], unit='ns').dt.month 
#again makes the Month a number so I can sort with it later
freddf['Year']=pd.to_datetime(freddf['Year'], unit='ns').dt.year 
#again makes the Year a number so I can sort with it later
#The following link was used for the dt.month and dt.year changes, https://pandas.pydata.org/docs/reference/api/pandas.Series.fillna.html#:~:text=*%20pandas.Series.ffill.%20*%20pandas.Series.fillna.%20*%20pandas.Series.interpolate.
#freddf # Calls FRED DataFrame so I can see it, not necessary
#_________________________________________________________________________________________________________________________________________
#BLOCK 1.8 - Merge/Clean Merged DataFrame
#this is to put both of the DataFrames into one that I can export and deal with later for the graphs.
finaldf=pd.merge(data,freddf, on=['Year','Month'], how='left') #merges the two datasets based on Year and Month

finaldf #Merges both of the dataframes into one
finaldf = finaldf[finaldf['Year'] >= 2005] #Excludes FRED data before 2005, the Lastfm api only goes until 2005, but the FRED Data goes to 1959
finaldf.drop(columns=0) #drops an empty column
finaldf = finaldf[finaldf['Year'] < 2026] # Excludes some data to be at 20 years, gets rid of the data where we did not have any values.
#finaldf #Calls FinalDF so I can see it, not necessary
#_________________________________________________________________________________________________________________________________________
#BLOCK 1.8.5 - Group Data Into Actual Final DataFrame
#This groups everything into my Final Dataframe that I'm going to export and end up using for the Graphs and Regressions. 
groupedfinal=finaldf[['Genre','Play Share','Play Share (Number)','Total Plays','REC', 'UNRATE','PCE','UMICH','Year','Month','Week']].reset_index().groupby(['Week','Genre']).sum()
groupedfinal
groupedfinal.to_csv('RealFinalDF2.csv')

# %% [markdown]
# # Graphing the data now
# For assignment 2 the graphing was pretty straightforward, I have 5 main graphs. The first is a Spaghetti Graph of average listening share over time for all of the genres I looked at (Classical, Electronic, Hip Hop, Indie, Jazz, Metal, Pop, Rock, and Folk). I wanted to show the top 4 genres (Hip Hop, Jazz, Metal, and Rock) and how their shares of listening have changed over time. The third Graph measures total monthly listening over time, to see how the amount that this individual listens to music changes if at all during recessions. The fourth graph is one that shows average monthly listening to see a 'smoother' trend of listening changes month by month; ultimately this is not a very smooth graph. The final graph shows a heatmap of Average Genre Listens in a given year clearly showing that rock has a higher average listening share than every other genre.

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
#_________________________________________________________________________________________________________________________________________
#BLOCK 2.1 - Load Up Graph Data
graph_path= '/Users/alex/Documents/Pace/Classes/Junior/Spring/Data Analytics/Final Project/final-project-atuosto1/'
graph_data=pd.read_csv(f'{graph_path}/RealFinalDF2.csv')
linegraph=graph_data[['Genre','Play Share','Year']]
#gets all of my data loaded up and sorted how I want it 
#_________________________________________________________________________________________________________________________________________
#BLOCK 2.2 - Make Graph 1 - Spaghetti Graph

groupedgen=linegraph.groupby(['Genre','Year'],as_index=False)['Play Share'].mean() 
#https://www.geeksforgeeks.org/pandas/python-pandas-dataframe-groupby/
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html#:~:text=pandas.DataFrame.groupby-,DataFrame.,as%20a%20(single)%20key.
#just doing this for rock but I'll eventually make a for loop to get this for every single Genre
# groups my data entries by Genre and Year, False means that these won't become the index so i'm able to pull from them for the graph
groupedgen=groupedgen[groupedgen['Genre']!='other']
#excludes other from my data
plt.figure(figsize=(10,5))
#sets size to 10,5
lp=sns.lineplot(x='Year',y='Play Share',data=groupedgen, hue='Genre')
#actually gets my lineplot set up with an x of year, y of play share, data = my grouped, hue separates lines by genre, palette gets my colors
lp.set(xticks=([2005,2007,2009,2011,2013,2015,2017,2019,2021,2023,2025])) 
# plots my years, need to be in a list so there is a fixed number of years https://stackoverflow.com/questions/63723514/userwarning-fixedformatter-should-only-be-used-together-with-fixedlocator
lp.set_xlabel('Year',fontsize=12) 
#sets my x label, I'm using set_xlabel because set(xlabel) doesnt allow me to change the size https://stackoverflow.com/questions/36220829/fine-control-over-the-font-size-in-seaborn-plots
lp.set_ylabel('% of Total Listens',fontsize=12) 
#same as above but just for my y label
plt.title('Average Listening Share Over Time', fontsize=15) 
#makes the title with fontsize 17
recession=graph_data[graph_data['REC']==1]['Year'].unique() 
#gets the unique year for each of the recessions
for year in recession:
     plt.axvspan(year,year+1, color='#C2C2C2',alpha=0.4)
#plots my recession bar if there is a year that has a value ==1 for the recession years
lp.legend(bbox_to_anchor=(1.2, 0.75), loc='upper right')
plt.grid(alpha=0.5)
plt.savefig(graph_path+'/SpaghettiGraph.png', dpi = 500, transparent=False,bbox_inches='tight') 
#https://stackoverflow.com/questions/9651092/my-matplotlib-pyplot-legend-is-being-cut-off, 
# I kept my legend from getting cut off, and bbox_inches keeps that from happening when I export.
plt.show()
#_________________________________________________________________________________________________________________________________________
#BLOCK 2.3 - Make Graph 2 - Less Spaghetti Graph
plt.figure(figsize=(10,5))
#sets the size of the figure I'm using
top4= linegraph[(linegraph['Genre']=='Rock')|(linegraph['Genre']=='Jazz')|
    (linegraph['Genre']=='Metal')|(linegraph['Genre']=='Hip Hop')] 
# get each of the top 4 genres
grouped4=top4.groupby(['Genre','Year'],as_index=False)['Play Share'].mean() 
# groups my top 4 genres by Genre and Year returning values as a mean of each year, False means that these won't become the index so i'm able to pull from them for the graph
colors={'Rock':'#808080','Jazz':'#9B59B6', 'Metal':'#6B3A2A', 'Hip Hop':'#27AE60'} 
# sets my colors into a dictionary seaborn pulls from for the colors, I wanted to keep them the same as the other bad spaghetti graph
lp=sns.lineplot(x='Year',y='Play Share',data=grouped4, hue='Genre', palette=colors)
#actually gets my lineplot set up with an x of year, y of play share, data = my grouped, hue separates lines by genre, palette gets my colors
lp.set(xticks=([2005,2007,2009,2011,2013,2015,2017,2019,2021,2023,2025])) 
# plots my years, need to be in a list so there is a fixed number of years https://stackoverflow.com/questions/63723514/userwarning-fixedformatter-should-only-be-used-together-with-fixedlocator
lp.set_xlabel('Year',fontsize=12) 
#sets my x label, I'm using set_xlabel because set(xlabel) doesnt allow me to change the size https://stackoverflow.com/questions/36220829/fine-control-over-the-font-size-in-seaborn-plots
lp.set_ylabel('% of Total Listens',fontsize=12) 
#same as above but just for my y label
plt.title('Average Listening Share Over Time: Top 4 Genres', fontsize=15) 
#makes the title with fontsize 17
recession=graph_data[graph_data['REC']==1]['Year'].unique() 
#gets the unique year for each of the recessions
for year in recession:
     plt.axvspan(year,year+1, color='#C2C2C2',alpha=0.4)
#shared the recession bars again
lp.legend(bbox_to_anchor=(1.2, 0.65), loc='upper right')
#puts my legend in the upper right corner with some fine tune adjustments in the bbox to anchor line
plt.grid(alpha=0.4)
#plots my gridlines somewhat transparent
plt.savefig(graph_path+'/AveListeningShare.png', dpi = 500, transparent=False,bbox_inches='tight')
#Saves the figure to my graph_path location and adds the title, I wanted a white background so i made the transparent condition false
#and I wanted to include the legend in my export
plt.show()
#_________________________________________________________________________________________________________________________________________
#BLOCK 2.4 - Make Graph 3 - Total Monthly listening Activity
plays_monthly = graph_data.groupby(['Year', 'Month'])['Play Share (Number)'].sum().reset_index()#groups the data by year and month returning the sume of the play shares for each month 
clean=plays_monthly.drop_duplicates().reset_index() 
#cleaning my data for this graph
clean=clean[(clean['Year']!=2005)|(clean['Month']!=2)] 
#excludes february of 2005 as there was a huge outlier in this month
clean=clean[clean['Year']<2025] 
#matches the timeline of the data up with the previous graph
plt.figure(figsize=(10,5)) 
#creates the size for the charts
lp=sns.lineplot(x=clean['Year']+clean['Month']/12,y=clean['Play Share (Number)'],color='#4292C6') 
#https://stackoverflow.com/questions/48693316/find-then-convert-the-year-and-month-to-decimal#:~:text=First%20convert%20total%20years%20and,53%20/%2012%20=%204.41%20years.
#Code above just gets the data to be in a decimal point instead of plotting once a year for the total plays, it was an ugly step function before
lp.set(xticks=([2005,2007,2009,2011,2013,2015,2017,2019,2021,2023,2025])) 
# plots my years, need to be in a list so there is a fixed number of years https://stackoverflow.com/questions/63723514/userwarning-fixedformatter-should-only-be-used-together-with-fixedlocator
lp.set_xlabel('Year',fontsize=12) 
#sets my x label, I'm using set_xlabel because set(xlabel) doesnt allow me to change the size https://stackoverflow.com/questions/36220829/fine-control-over-the-font-size-in-seaborn-plots
lp.set_ylabel('Total Monthly Listens',fontsize=12) 
#same as above but just for my y label
plt.title('Total Monthly Listening Activity Over Time', fontsize=17, horizontalalignment='center', x = 0.487)
for year in recession:
     plt.axvspan(year,year+1, color='#C2C2C2',alpha=0.4)
    #plots my recession bar if there is a year that has a value ==1 for the recession years
plt.grid(alpha=0.5)
#plots my gridlines somewhat transparent
plt.savefig(graph_path+'/MonthTotal.png', dpi = 500, transparent=False, bbox_inches='tight')
#Saves the figure to my graph_path location and adds the title, I wanted a white background so i made the transparent condition false
#and I wanted to include the legend in my export
plt.show()
#_________________________________________________________________________________________________________________________________________
#BLOCK 2.5 - Make Graph 4 - Stacked Graph

fig, ax = plt.subplots(nrows = 2, ncols = 1,figsize=(10,8))
 #creates the size for the chartsgrouped4=top4.groupby(['Genre','Year'],as_index=False)['Play Share'].mean() 
colors={'Rock':'#808080','Jazz':'#9B59B6', 'Metal':'#6B3A2A', 'Hip Hop':'#27AE60'} 
# sets my colors into a dictionary seaborn pulls from for the colors, I wanted to keep them the same as the other bad spaghetti graph
ax1=sns.lineplot(x='Year',y='Play Share',data=grouped4, hue='Genre', palette=colors,ax=ax[0])
#actually gets my lineplot set up with an x of year, y of play share, data = my grouped, hue separates lines by genre, 
#palette gets my colors, ax makes it so that ax1 is plotting on the 0th subplot https://www.geeksforgeeks.org/python/how-to-create-subplots-in-seaborn/
#https://www.geeksforgeeks.org/python/how-to-create-subplots-in-seaborn/
ax1.set(xticks=([2005,2007,2009,2011,2013,2015,2017,2019,2021,2023,2025])) 
# plots my years, need to be in a list so there is a fixed number of years https://stackoverflow.com/questions/63723514/userwarning-fixedformatter-should-only-be-used-together-with-fixedlocator
ax1.set_xlabel('Year',fontsize=12) 
#sets my x label, I'm using set_xlabel because set(xlabel) doesnt allow me to change the size https://stackoverflow.com/questions/36220829/fine-control-over-the-font-size-in-seaborn-plots
ax1.set_ylabel('% of Total Listens',fontsize=12) 
#same as above but just for my y label
ax1.set_title('Average Listening Share Over Time: Top 4 Genres', fontsize=15) 
#makes the title with fontsize 17
recession=graph_data[graph_data['REC']==1]['Year'].unique() 
#gets the unique year for each of the recessions
ax1.legend(bbox_to_anchor=(1.16, 1.025), loc='upper right')
ax1.grid(alpha=0.4)
#plots my gridlines somewhat transparent
ax2=sns.lineplot(x=clean['Year']+clean['Month']/12,y=clean['Play Share (Number)'],color='#4292C6', ax=ax[1])
#difference between this and ax1 is that this one has ax=ax[1] this means that we're printing on the 1st subplot
ax2.set(xticks=([2005,2007,2009,2011,2013,2015,2017,2019,2021,2023,2025])) 
# plots my years, need to be in a list so there is a fixed number of years https://stackoverflow.com/questions/63723514/userwarning-fixedformatter-should-only-be-used-together-with-fixedlocator
ax2.set_xlabel('Year',fontsize=12) 
#sets my x label, I'm using set_xlabel because set(xlabel) doesnt allow me to change the size https://stackoverflow.com/questions/36220829/fine-control-over-the-font-size-in-seaborn-plots
ax2.set_ylabel('Total Monthly Listens',fontsize=12) 
#same as above but just for my y label
ax2.set_title('Total Monthly Listening Activity Over Time', fontsize=15, horizontalalignment='center', x = 0.487)
#sets the title aligned in the center 
ax2.grid(alpha=0.5)
#plots my gridlines somewhat transparent
for year in recession:
     ax1.axvspan(year,year+1, color='#C2C2C2',alpha=0.4)
     ax2.axvspan(year,year+1, color='#C2C2C2',alpha=0.4)
#plots the recession bars for both graphs at the same time
plt.subplots_adjust(hspace=0.35)
#puts a little bit of space vertically in between the two graphs 
plt.savefig(graph_path+'/2Graphs.png', dpi = 500, transparent=False,bbox_inches='tight')
#Saves the figure to my graph_path location and adds the title, I wanted a white background so i made the transparent condition false
#and I wanted to include the legend in my export
#https://stackoverflow.com/questions/9651092/my-matplotlib-pyplot-legend-is-being-cut-off
plt.show()
#_________________________________________________________________________________________________________________________________________
#BLOCK 2.6 - Make Graph 5 - Average Monthtly listening Activity
plays_monthly = graph_data.groupby(['Year', 'Month'])['Total Plays'].mean().reset_index()#groups the data by year and month returning the sume of the play shares for each month 
aveclean=plays_monthly.drop_duplicates().reset_index() #cleaning my data for this graph
aveclean=aveclean[(aveclean['Year']!=2005)|(aveclean['Month']!=2)] #excludes february of 2005 as there was a huge outlier in this month
aveclean=aveclean[aveclean['Year']<2025] #matches the timeline of the data up with the previous graph
plt.figure(figsize=(10,5)) #creates the size for the charts
lp=sns.lineplot(x=aveclean['Year']+aveclean['Month']/12,y=aveclean['Total Plays'],color='#084594') #https://stackoverflow.com/questions/48693316/find-then-convert-the-year-and-month-to-decimal#:~:text=First%20convert%20total%20years%20and,53%20/%2012%20=%204.41%20years.
#stuff above just gets the data to be in a decimal point instead of plotting once a year for the total plays, it was a gross ugly step function before
lp.set(xticks=([2005,2007,2009,2011,2013,2015,2017,2019,2021,2023,2025])) 
# plots my years, need to be in a list so there is a fixed number of years https://stackoverflow.com/questions/63723514/userwarning-fixedformatter-should-only-be-used-together-with-fixedlocator
lp.set_xlabel('Year',fontsize=12) 
#sets my x label, I'm using set_xlabel because set(xlabel) doesnt allow me to change the size https://stackoverflow.com/questions/36220829/fine-control-over-the-font-size-in-seaborn-plots
lp.set_ylabel('Average Monthly Listens',fontsize=12) 
#same as above but just for my y label
plt.title('Average Monthly Listening Activity Over Time', fontsize=17, horizontalalignment='center', x = 0.487)
#plots title and aligns it in the center of my graphs
for year in recession:
     plt.axvspan(year,year+1, color='#C2C2C2',alpha=0.4)
plt.grid(alpha=0.5)
#plots gridlines with an alpha of 0.5
plt.savefig(graph_path+'/MeanMonthlyListen.png', dpi = 500, transparent=False, bbox_inches='tight')
#Saves the figure to my graph_path location and adds the title, I wanted a white background so i made the transparent condition false
#and I wanted to include the legend in my export
plt.show()
#_________________________________________________________________________________________________________________________________________
#BLOCK 2.7 - Make Graph 6 - Heatmap (Average Genre Listening Share by Year)
sns.set(font_scale=1)
#sets the font size for the heatmap
plt.figure(figsize=(8,5))
#makes the general blank figure
heatmap=linegraph[linegraph['Genre']!='other'] 
#makes the heatmap data the linegraph data as well
heatmapdata = heatmap[['Year','Genre', 'Play Share']].drop_duplicates() 
#puts all the data we need into one dataframe specific for the heatma[
hm = heatmapdata.pivot_table(index= 'Genre',columns = 'Year',values = 'Play Share',aggfunc='mean')
#I found this out at the links below, since I have 2 category variables this is considered a 3d pivot table
#that means I had to do the pivot table function instead of just pivot like we had in the lecture
#i also had to use the aggfunc which basically means that each of the index values will be the mean for each year for each Genre
#https://seaborn.pydata.org/generated/seaborn.heatmap.html
#https://stackoverflow.com/questions/69968235/pivot-table-in-proper-order-for-the-heatmap
#https://saturncloud.io/blog/pandas-pivot-table-list-of-aggfunc-a-guide/
plt.title('Average Genre Listening Share by Year', fontsize=19)
#plots the title in a font with a size of 19
sns.heatmap(hm, cmap='Blues', robust= True) 
#gets my data, my continuous mapping, and looks at the robust percentiles (98th% and 2nd% true)
plt.savefig(graph_path+'/Heatmap.png', dpi = 500, transparent=False, bbox_inches='tight')
#Saves the figure to my graph_path location and adds the title, I wanted a white background so i made the transparent condition false
#and I wanted to include the legend in my export
plt.show()
#sns.reset_orig() #this resets the seaborn theme because I nearly had a heart attack when I changed the theme and my other graphs changed
